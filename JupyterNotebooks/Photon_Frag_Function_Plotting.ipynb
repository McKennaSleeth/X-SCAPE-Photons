# %% [markdown]
# ## Plotting of Momentum Fraction of Photons in Jets (Fragmentation Photons)

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.5,14.5))

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')

# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.5,14.5))

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# # XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')


# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$\Delta R$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{d\Delta R}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{d\Delta R}$',fontsize=12)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title(r'$\Delta R$ of Photons in 30-40 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$\Delta R$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{d\Delta R}$',fontsize=12)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %% [markdown]
# ### PTHat 30-40 GeV Photon Momentum Fraction and Delta R

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6,14))

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# # XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')

# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6,14))

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# # XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
# ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')


# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$\Delta R$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title(r'$\Delta R$ of Photons in 30-40 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$\Delta R$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %% [markdown]
# ### PTHat 40-60 GeV Photon Momentum Fraction and Delta R

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,6))

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# # XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$,, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$,, Gaussian smearing)')
# ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax2.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,6))

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, noprompt')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
# photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
# ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# # XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
# ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt const>1')


# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$\Delta R$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# ax2.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.0,14.5))

# XSCAPE pTHat 5-100 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat5_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_100M_smearedphotonjet.txt').T
photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z = np.trapz(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z)
# ax1.errorbar(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, yerr = photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 5-100 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat5_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_100M_smearedphotonjet.txt').T
photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR = np.trapz(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR)
# ax2.errorbar(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, yerr = photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 5-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('pion_pp_pTHat5_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_100M_smearedphotonjet.txt').T
pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z = np.trapz(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z)
# ax1.errorbar(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, yerr = pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 5-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('pion_pp_pTHat5_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_100M_smearedphotonjet.txt').T
pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR = np.trapz(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR)
# ax2.errorbar(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, yerr = pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 5-100 jet pT spectra (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err = np.loadtxt('photon_pp_pTHat5_100_photon_jet_spectra_alldecayoff_noprompt_deltaRcut_constituentcut_10M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, yerr = photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-100 dijets')

# XSCAPE pTHat 15-100 jet pT spectra (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_spectra_alldecayoff_noprompt_deltaRcut_constituentcut_10M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-100 dijets')

# XSCAPE pTHat 25-100 jet pT spectra (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err = np.loadtxt('photon_pp_pTHat25_100_photon_jet_spectra_alldecayoff_noprompt_deltaRcut_constituentcut_10M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, yerr = photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 25-100 dijets')

# XSCAPE pTHat 35-100 jet pT spectra (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err = np.loadtxt('photon_pp_pTHat35_100_photon_jet_spectra_alldecayoff_noprompt_deltaRcut_constituentcut_10M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_pT, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT, yerr = photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_dNdpT_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 35-100 dijets')

# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax1.legend(fontsize=9)
# ax1.set_ylim(1e-2,1e1)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax2.legend(fontsize=9)
# ax2.set_ylim(1e-2,1e1)

# ax3.set_yscale('log')
# ax3.set_title(r'Dijet $p_{T}$ Spectra (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$p_{T}$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN_{jets}}{dp_{T}}$',fontsize=12)
# ax3.legend(fontsize=9)
# ax3.set_xlim(0,50)

# plt.tight_layout()

plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,50)
plt.title(r'Dijet $p_{T}$ Spectra (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
plt.xlabel(r'$p_{T}$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN_{jets}}{dp_{T}}$',fontsize=12)
plt.legend(fontsize=9)

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 7
#       2 import matplotlib.pyplot as plt
#       4 # fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.0,14.5))
#       5
#       6 # XSCAPE pTHat 5-100 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# ----> 7 photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat5_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_100M_smearedphotonjet.txt').T
# ...

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6.0,9.5))

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# ax1.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
# ax2.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# ax1.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
# ax2.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')




# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax1.set_ylim(1e-2,1e1)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax2.set_ylim(1e-1,1e1)
# ax2.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       1 # import numpy  as np
#       2 # import matplotlib.pyplot as plt
#       3
#       4 # fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6.0,9.5))
#       5
#       6 # # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# ----> 7 photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
# ...

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6.0,9.5))

# # XSCAPE pTHat 25-100 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat25_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_100M_smearedphotonjet.txt').T
# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z = np.trapz(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz,photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z)
# ax1.errorbar(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, yerr = photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')

# # XSCAPE pTHat 25-100 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat25_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_100M_smearedphotonjet.txt').T
# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR = np.trapz(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR)
# ax2.errorbar(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, yerr = photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')

# # XSCAPE pTHat 25-100 pion / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('pion_pp_pTHat25_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_100M_smearedphotonjet.txt').T
# pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z = np.trapz(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z)
# ax1.errorbar(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, yerr = pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')

# # XSCAPE pTHat 25-100 pion / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('pion_pp_pTHat25_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_100M_smearedphotonjet.txt').T
# pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR = np.trapz(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR)
# ax2.errorbar(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, yerr = pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')


# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax1.set_ylim(1e-2,1e1)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 30-40 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax2.set_ylim(1e-1,1e1)
# ax2.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6.0,9.5))

# # XSCAPE pTHat 35-100 photon / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err = np.loadtxt('photon_pp_pTHat35_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt40_50_100M_smearedphotonjet.txt').T
# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z = np.trapz(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z)
# ax1.errorbar(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, yerr = photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# # XSCAPE pTHat 35-100 photon / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err = np.loadtxt('photon_pp_pTHat35_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt40_50_100M_smearedphotonjet.txt').T
# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR = np.trapz(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR)
# ax2.errorbar(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, yerr = photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# # XSCAPE pTHat 35-100 pion / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err = np.loadtxt('pion_pp_pTHat35_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt40_50_100M_smearedphotonjet.txt').T
# pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z = np.trapz(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z)
# ax1.errorbar(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, yerr = pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# # XSCAPE pTHat 35-100 pion / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err = np.loadtxt('pion_pp_pTHat35_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt40_50_100M_smearedphotonjet.txt').T
# pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR = np.trapz(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR)
# ax2.errorbar(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, yerr = pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')


# # ax1.set_ylim(1e-13,1e-3)
# # ax1.set_xlim(2.5,17)
# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax1.set_ylim(1e-2,1e1)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in 40-50 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax2.set_ylim(1e-1,1e1)
# ax2.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

# ax1.errorbar(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, yerr = photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, fmt = '-', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')
# ax1.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')
# ax1.errorbar(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, yerr = photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, fmt = '-', color='green', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')
# ax1.errorbar(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, yerr = photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, fmt = '-', color='purple', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# ax2.errorbar(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, yerr = photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, fmt = '-', color='red', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')
# ax2.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')
# ax2.errorbar(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, yerr = photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, fmt = '-', color='green', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')
# ax2.errorbar(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, yerr = photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, fmt = '-', color='purple', capsize=5, label = 'XSCAPE Photons $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# ax3.errorbar(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, yerr = pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z, fmt = '-', color='red', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')
# ax3.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')
# ax3.errorbar(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, yerr = pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z, fmt = '-', color='green', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')
# ax3.errorbar(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, yerr = pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz_err/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z, fmt = '-', color='purple', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')

# ax4.errorbar(pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, yerr = pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err/pion_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR, fmt = '-', color='red', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 5-100 dijets, $10<p_{T}^{jets}<20$')
# ax4.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$')
# ax4.errorbar(pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, yerr = pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err/pion_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR, fmt = '-', color='green', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 25-100 dijets, $30<p_{T}^{jets}<40$')
# ax4.errorbar(pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, yerr = pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR_err/pion_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR, fmt = '-', color='purple', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 35-100 dijets, $40<p_{T}^{jets}<50$')


# ax1.set_yscale('log')
# ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
# ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax1.set_ylim(1e-3,1e1)
# ax1.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title(r'$\Delta R$ of Photons in Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax2.set_xlabel(r'$\Delta R$',fontsize=12)
# ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax2.set_ylim(1e-2,1e1)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Momentum Fraction of Pions in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$z = \frac{p_{T}^{\pi^{+/-}}}{p_{T}^{jets}}$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax3.set_ylim(1e-3,1e1)
# ax3.legend(fontsize=9)

# ax4.set_yscale('log')
# ax4.set_title(r'$\Delta R$ of Pions in Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax4.set_xlabel(r'$\Delta R$',fontsize=12)
# ax4.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax4.set_ylim(1e-2,1e1)
# ax4.legend(fontsize=9)

# plt.tight_layout()

# # plt.ylim(1e-4,1e1)
# # plt.xlim(4,21)
# # plt.yscale('log')

# # plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# # plt.xlabel(r'$\Delta R$',fontsize=12)
# # plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# # plt.legend(fontsize=9)
# # plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# # plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# # plt.show()

# %%
# import numpy  as np
# import matplotlib.pyplot as plt
# # import matplotlib.colors as mcolors

# # custom_cmap = mcolors.LinearSegmentedColormap.from_list(
# #     'WhBuGnYlOrRe', 
# #     ['white', 'blue', 'green', 'yellow','orange','red']
# # )

# # plt.colormaps.register(cmap=custom_cmap)


# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

# photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z_bins = np.linspace(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z.min(), photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z.max(), 20)
# photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR_bins = np.linspace(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR.min(), photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR.max(), 20)

# photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z_edges, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR_edges = np.histogram2d(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, 
#                                         bins=[photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z_bins, photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR_bins], 
#                                         weights=(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_z)*(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR/photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_integral_deltaR))

# im1 = ax1.imshow(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist.T, origin='lower', aspect='auto', 
#            extent=[photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z_edges[0], photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z_edges[-1], photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR_bins[0], photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR_bins[-1]], 
#            cmap='YlGnBu')
# # print(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist.sum())
# # print(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist.shape)
# # print(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist.min())
# # print(photon_jet_xscape_5_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_hist.max())


# fig.colorbar(im1, ax=ax1, label='Normalized Weight')
# ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$')
# ax1.set_ylabel(r'$\Delta R$')
# ax1.set_title(r'2D Projection of Photon z and $\Delta R$ ($\hat{p_{T}}$ = 5-100, $10 < p_{T}^{jet} < 20$ GeV)')

# photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z_bins = np.linspace(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z.min(), photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z.max(), 20)
# photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR_bins = np.linspace(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR.min(), photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR.max(), 20)

# photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_hist, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z_edges, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR_edges = np.histogram2d(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, 
#                                         bins=[photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z_bins, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR_bins], 
#                                         weights=(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z)*(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR))

# im2 = ax2.imshow(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_hist.T, origin='lower', aspect='auto', 
#            extent=[photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z_edges[0], photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z_edges[-1], photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR_bins[0], photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR_bins[-1]], 
#            cmap='YlGnBu')
# fig.colorbar(im2, ax=ax2, label='Normalized Weight')
# ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$')
# ax2.set_ylabel(r'$\Delta R$')
# ax2.set_title(r'2D Projection of Photon z and $\Delta R$ ($\hat{p_{T}}$ = 15-100, $20 < p_{T}^{jet} < 30$ GeV)')

# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z_bins = np.linspace(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z.min(), photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z.max(), 20)
# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR_bins = np.linspace(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR.min(), photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR.max(), 20)

# photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_hist, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z_edges, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR_edges = np.histogram2d(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, 
#                                         bins=[photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z_bins, photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR_bins], 
#                                         weights=(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_z)*(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR/photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_integral_deltaR))

# im3 = ax3.imshow(photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_hist.T, origin='lower', aspect='auto', 
#            extent=[photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z_edges[0], photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z_edges[-1], photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR_bins[0], photon_jet_xscape_25_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR_bins[-1]], 
#            cmap='YlGnBu')
# fig.colorbar(im3, ax=ax3, label='Normalized Weight')
# ax3.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$')
# ax3.set_ylabel(r'$\Delta R$')
# ax3.set_title(r'2D Projection of Photon z and $\Delta R$ ($\hat{p_{T}}$ = 25-100, $30 < p_{T}^{jet} < 40$ GeV)')

# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z_bins = np.linspace(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z.min(), photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z.max(), 20)
# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR_bins = np.linspace(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR.min(), photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR.max(), 20)

# photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_hist, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z_edges, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR_edges = np.histogram2d(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR, 
#                                         bins=[photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z_bins, photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR_bins], 
#                                         weights=(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNdz/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_z)*(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_dNddeltaR/photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_integral_deltaR))

# im4 = ax4.imshow(photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_hist.T, origin='lower', aspect='auto', 
#            extent=[photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z_edges[0], photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_z_edges[-1], photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR_bins[0], photon_jet_xscape_35_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_40_50_deltaR_bins[-1]], 
#            cmap='YlGnBu')
# fig.colorbar(im4, ax=ax4, label='Normalized Weight')
# ax4.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$')
# ax4.set_ylabel(r'$\Delta R$')
# ax4.set_title(r'2D Projection of Photon z and $\Delta R$ ($\hat{p_{T}}$ = 35-100, $40 < p_{T}^{jet} < 50$ GeV)')

# plt.tight_layout()
# plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
# fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))

# XSCAPE pTHat 15-100 photon / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Photons, pp')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_AuAu_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons, nPDF, 0-5%')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_AuAu_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_integral_z = np.trapz(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z)
ax1.errorbar(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, yerr = photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='purple', capsize=5, label = 'JETSCAPE Photons, hydro, bgdsub, 0-5%')

# photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
# photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_z = np.trapz(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z)
# ax1.errorbar(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro, bgdsub, 0-1%')

# pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z)
# ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err, fmt = '-', color='orange', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro (no quench), bgdsub, 0-1%')

# photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err = np.loadtxt('photon_AuAu_only_hydro_photon_jet_frag_func_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_1M_randomcone.txt').T
# photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_z = np.trapz(photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z)
# ax1.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, yerr = photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err, fmt = '--', color='blue', capsize=5, label = 'JETSCAPE Photons, only hydro, random cone, 0-5%')

# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_frag_func_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_10k_randomcone_centr0_1.txt').T
# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_z = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z)
# ax1.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')

# # XSCAPE pTHat 15-100 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
ax2.errorbar(photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE Photons, pp')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_AuAu_pTHat15_100_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
ax2.errorbar(photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE Photons, nPDF, 0-5%')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_nobkgdsub.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
# # ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_AuAu_pTHat15_100_photon_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_integral_deltaR = np.trapz(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR)
ax2.errorbar(photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR, photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR, yerr = photon_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='purple', capsize=5, label = 'JETSCAPE Photons, hydro, bgdsub, 0-5%')

# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro, bgdsub, 0-1%')

# pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='orange', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro (no quench), bgdsub, 0-1%')

# photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err = np.loadtxt('photon_AuAu_only_hydro_photon_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_1M_randomcone.txt').T
# photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR)
# ax2.errorbar(photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR, photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR, yerr = photon_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err, fmt = '--', color='blue', capsize=5, label = 'JETSCAPE Photons, only hydro, random cone, 0-5%')

# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_10k_randomcone_centr0_1.txt').T
# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR,pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR)
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')

# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_jetpt_20_30_1M_randomcone.txt').T
# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR,pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR)
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')


ax1.set_yscale('log')
ax1.set_title('Momentum Fraction of Photons in AuAu Dijets')
ax1.set_xlabel(r'$z = \frac{p^{\gamma}_{T}}{p_{T}^{subtr,jets}}$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N^{subtr.}_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.text(0.55, 0.0025, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=8)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax1.text(0.55, 0.0020, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=8)
ax1.text(0.55, 0.0017, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{subtr,jet}<30$ GeV' , fontsize=8)
# ax1.set_ylim(1e-3,1e1)
ax1.legend(fontsize=8)

ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ of Photons in AuAu Dijets')
ax2.set_xlabel(r'$\Delta R$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N^{subtr.}_{jets}}$ $\frac{dN^{\gamma}}{d\Delta R}$',fontsize=12)
ax2.text(0.05, 0.0015, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=8)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax2.text(0.05, 0.00125, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=8)
ax2.text(0.05, 0.00107, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{subtr,jet}<30$ GeV' , fontsize=8)
# ax2.set_ylim(1e-1,1e1)
ax2.legend(fontsize=8)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 9
#       6 fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))
#       8 # XSCAPE pTHat 15-100 photon / jet momentum fraction, jet pT 40-50 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# ----> 9 photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_100_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
# ...

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
# fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11.0,5.0))



# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = 'o', color='black', capsize=5, label = 'XSCAPE Pions pp')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# ax1.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = 'o', color='red', capsize=5, label = 'XSCAPE Pions AuAu nPDF')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_hydro_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# # ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z)
ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err, fmt = 'o', color='purple', capsize=5, label = 'JETSCAPE Pions AuAu nPDF+Hydro $p_{T}$ bgdsub')

pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z)
# ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro, bgdsub, 0-1%')

pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_nohydro_quench_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
# pion_Au_jet_xscape_15_100_noprompt_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z)
# ax1.errorbar(pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, yerr = pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err, fmt = 'o', color='orange', capsize=5, label = 'JETSCAPE Pions AuAu nPDF (quench) $p_{T}$ bgdsub')

pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z)
# ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err, fmt = 'o', color='blue', capsize=5, label = 'JETSCAPE Pions AuAu nPDF+Hydro (no quench) $p_{T}$ bgdsub')

pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_z = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z)
# ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_z, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNdz_err, fmt = '-', color='orange', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro (no quench), bgdsub, 0-1%')

pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_frag_func_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_randomcone.txt').T
pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_z = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z)
# ax1.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-5%')

# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_frag_func_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_10k_randomcone_centr0_1.txt').T
# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_z = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_z)
# ax1.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')


# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_nobkgdsub.txt').T
# pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
# # ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR, fmt = '-', color='blue', capsize=5, label = 'XSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro')


# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
ax2.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = 'o', color='black', capsize=5, label = 'XSCAPE Pions pp')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = 'o', color='red', capsize=5, label = 'XSCAPE Pions AuAu nPDF')

# XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err, fmt = 'o', color='purple', capsize=5, label = 'JETSCAPE Pions AuAu nPDF+Hydro $p_{T}$ bgdsub')

pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro, bgdsub, 0-1%')

pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err, fmt = 'o', color='blue', capsize=5, label = 'JETSCAPE Pions AuAu nPDF+Hydro (no quench) $p_{T}$ bgdsub')

pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_noquench_hydro10_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_1.txt').T
pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='orange', capsize=5, label = 'JETSCAPE Pions $\hat{p_{T}}$ 15-100 dijets, $20<p_{T}^{jets}<30$, hydro (no quench), bgdsub, 0-1%')

pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_nohydro_quench_deltaRcut_constituentcut_jetpt20_30_1M_bkgdsub_centr0_5.txt').T
# pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_integral_deltaR = np.trapz(pion_Au_hydro_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR,pion_Au_hydro_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR)
# ax2.errorbar(pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR, yerr = pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err, fmt = 'o', color='orange', capsize=5, label = 'JETSCAPE Pions AuAu nPDF (quench) $p_{T}$ bgdsub')

pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_jetpt20_30_1M_randomcone.txt').T
pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR,pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR)
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-5%')

pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_10k_randomcone_centr0_1.txt').T
pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR,pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR)
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')

# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_only_hydro_pion_jet_deltaR_alldecayoff_noprompt_hydro100_iSS1_deltaRcut_constituentcut_jetpt_20_30_1M_randomcone.txt').T
# pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_integral_deltaR = np.trapz(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR,pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR)
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')


ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_title('Momentum Fraction of Pions in Dijets')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\pi}}{p_{T}^{jets}}$',fontsize=14)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=14)
ax1.text(0.015, 0.0095, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax1.text(0.015, 0.0045, '$\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
ax1.text(0.015, 0.0022, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax1.set_ylim(1e-4,1e3)
ax1.set_xlim(1e-2,1)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
# ax2.set_xscale('log')
ax2.set_title(r'$\Delta R$ of Pions in Dijets')
ax2.set_xlabel(r'$\Delta R$',fontsize=14)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{d\Delta R}$',fontsize=14)
ax2.text(0.01, 0.45, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax2.text(0.01, 0.25, '$\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
ax2.text(0.01, 0.15, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax2.set_ylim(1e-1,1e3)
ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Momentum Fraction in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax3.set_xlabel(r'$z = \frac{p_{T}}{p_{T}^{jets}}$',fontsize=12)
# ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# ax3.set_ylim(1e-3,1e1)
# ax3.legend(fontsize=8)

# ax4.set_yscale('log')
# ax4.set_title(r'$\Delta R$ in Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# ax4.set_xlabel(r'$\Delta R$',fontsize=12)
# ax4.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{d\Delta R}$',fontsize=12)
# ax4.set_ylim(1e-2,1e1)
# ax4.legend(fontsize=8)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 16
#      13 ax1.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = 'o', color='black', capsize=5, label = 'XSCAPE Pions pp')
#      15 # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# ...

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
# fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16.0,6.0))


# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
# pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='black', capsize=5, label = 'XSCAPE pp Jets 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNdz, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_nohydro_nonquenched_z_centrality0_10_1M_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNdz, yerr = pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNdz_err, fmt = '.', color='red', capsize=5, label = 'JETSCAPE AuAu Jets+nPDF (Nonquenched) 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNdz, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_nohydro_quenched_z_centrality0_10_10k_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNdz, yerr = pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNdz_err, fmt = '.', color='orange', capsize=5, label = 'JETSCAPE AuAu Jets+nPDF (Quenched) 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNdz, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_hydro_raw_jet_z_centrality0_10_1M_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_z, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNdz, yerr = pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'JETSCAPE AuAu Hard Hydro Jets 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_z, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNdz, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_soft_hydro100_z_centrality0_10_10k_events_trackpTcut.txt').T
# # pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# ax1.errorbar(pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_z, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNdz, yerr = pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNdz_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE AuAu Soft+Hard Hydro Jets 20<$p_{T}$<30 GeV')

pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_z, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNdz, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNdz_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_soft_hydro10_z_centrality0_10_10k_events_SMASH_only_decay_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax1.errorbar(pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_z, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNdz, yerr = pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNdz_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE AuAu Soft+Hard Hydro Jets 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_pp_pTHat15_100_pion_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_100M_smearedphotonjet.txt').T
# pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_deltaR = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR,pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR)
ax2.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='black', capsize=5, label = 'XSCAPE pp Jets 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNddeltaR, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_nohydro_nonquenched_deltaR_centrality0_10_1M_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax2.errorbar(pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNddeltaR, yerr = pion_jetscape_15_100_hard_sector_nohydro_nonquenched_jetpt_20_30_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'JETSCAPE AuAu Jets+nPDF (Nonquenched) 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNddeltaR, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_nohydro_quenched_deltaR_centrality0_10_10k_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax2.errorbar(pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNddeltaR, yerr = pion_jetscape_15_100_hard_sector_nohydro_quenched_jetpt_20_30_dNddeltaR_err, fmt = '.', color='orange', capsize=5, label = 'JETSCAPE AuAu Jets+nPDF (Quenched) 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNddeltaR, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_sector_hydro_raw_jet_deltaR_centrality0_10_1M_events_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax2.errorbar(pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNddeltaR, yerr = pion_jetscape_15_100_hard_sector_hydro_jetpt_20_30_dNddeltaR_err, fmt = '.', color='blue', capsize=5, label = 'JETSCAPE AuAu Hard Hydro Jets 20<$p_{T}$<30 GeV')

# # XSCAPE pTHat 15-100 pion / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
# pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNddeltaR, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_soft_hydro100_deltaR_centrality0_10_10k_events_trackpTcut.txt').T
# # pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
# ax2.errorbar(pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_deltaR, pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNddeltaR, yerr = pion_jetscape_15_100_hard_soft_hydro100_jetpt_20_30_dNddeltaR_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE AuAu Soft+Hard Hydro Jets 20<$p_{T}$<30 GeV')

pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_deltaR, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNddeltaR, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNddeltaR_err = np.loadtxt('pion_AuAu_pTHat15_100_hard_soft_hydro10_deltaR_centrality0_10_10k_events_SMASH_only_decay_trackpTcut.txt').T
# pion_jetscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_integral_z = np.trapz(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z)
ax2.errorbar(pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_deltaR, pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNddeltaR, yerr = pion_jetscape_15_100_hard_soft_hydro10_jetpt_20_30_SMASH_only_decay_dNddeltaR_err, fmt = '.', color='green', capsize=5, label = 'JETSCAPE AuAu Soft+Hard Hydro Jets 20<$p_{T}$<30 GeV')

ax1.set_yscale('log')
# ax1.set_xscale('log')
ax1.set_title('Momentum Fraction of Pions in Dijets ($p_{T}^{trk}$>0.5 GeV)')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\pi}}{p_{T}^{jets}}$',fontsize=14)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=14)
# ax1.text(0.015, 0.0095, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# # ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
# ax1.text(0.015, 0.0045, '$\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
# ax1.text(0.015, 0.0022, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax1.set_ylim(1e-4,1e3)
# ax1.set_xlim(1e-2,1)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
# ax1.set_xscale('log')
ax2.set_title(r' $\Delta R$ of Pions in Dijets ($p_{T}^{trk}$>0.5 GeV)')
ax2.set_xlabel(r'$\Delta R$',fontsize=14)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{d\Delta R}$',fontsize=14)
# ax1.text(0.015, 0.0095, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# # ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
# ax1.text(0.015, 0.0045, '$\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
# ax1.text(0.015, 0.0022, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax2.set_ylim(1e-1,1e3)
# ax1.set_xlim(1e-2,1)
ax2.legend(fontsize=9)

plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
# fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))

jets_hydro_quench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err)**2)
jets_hydro_noquench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err)**2)

jets_hydro_quench_only_hydro_subtraction_deltaR_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err)**2)
jets_hydro_noquench_only_hydro_subtraction_deltaR_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err)**2)

jets_hydro_quench_only_hydro_subtraction_z = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz)
jets_hydro_noquench_only_hydro_subtraction_z = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz)

jets_hydro_quench_only_hydro_subtraction_deltaR = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR)
jets_hydro_noquench_only_hydro_subtraction_deltaR = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR)

ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, jets_hydro_quench_only_hydro_subtraction_z, yerr = jets_hydro_quench_only_hydro_subtraction_z_err, fmt = '.', color='purple', capsize=5, label = 'JETSCAPE Jets+nPDF+Hydro w/ quenching, random cone bgdsub')
ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, jets_hydro_noquench_only_hydro_subtraction_z, yerr = jets_hydro_noquench_only_hydro_subtraction_z_err, fmt = '.', color='blue', capsize=5, label = 'JETSCAPE Jets+nPDF+Hydro w/o quenching, random cone bgdsub')
# ax1.errorbar(pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, jets_hydro_quench_only_hydro_subtraction_z, yerr = jets_hydro_noquench_only_hydro_subtraction_z_err, fmt = '.', color='blue', capsize=5, label = 'JETSCAPE Jets+nPDF+Hydro w/o quenching, random cone bgdsub')
ax1.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE Jets+nPDF')
ax1.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='black', capsize=5, label = 'XSCAPE Jets pp')

ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, jets_hydro_quench_only_hydro_subtraction_deltaR, yerr = jets_hydro_quench_only_hydro_subtraction_deltaR_err, fmt = '.', color='purple', capsize=5, label = 'JETSCAPE Jets+nPDF+Hydro w/ quenching, random cone bgdsub')
ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_1_jetpt_20_30_deltaR, jets_hydro_noquench_only_hydro_subtraction_deltaR, yerr = jets_hydro_noquench_only_hydro_subtraction_deltaR_err, fmt = '.', color='blue', capsize=5, label = 'JETSCAPE Jets+nPDF+Hydro w/o quenching, random cone bgdsub')
ax2.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE Jets+nPDF')
ax2.errorbar(pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='black', capsize=5, label = 'XSCAPE Jets pp')

ax1.set_yscale('log')
ax1.set_title('Momentum Fraction of Charged Pions in AuAu Dijets')
ax1.set_xlabel(r'$z = \frac{p_{T}}{p_{T}^{subtr.jets}}$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{subtr.jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=12)
# ax1.set_ylim(1e-3,1e1)
ax1.text(0.5, 6.0, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=8)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax1.text(0.5, 3.5, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=8)
ax1.text(0.5, 2.2, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{subtr,jet}<30$ GeV' , fontsize=8)
ax1.legend(fontsize=7)

ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ of Charged Pions in AuAu Dijets')
ax2.set_xlabel(r'$\Delta R$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{subtr.jets}}$ $\frac{dN^{\pi}}{d\Delta R}$',fontsize=12)
# ax2.set_ylim(1e-1,1e1)
ax2.text(0.09, 0.75, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=8)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax2.text(0.09, 0.60, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=8)
ax2.text(0.09, 0.50, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{subtr,jet}<30$ GeV' , fontsize=8)
ax2.legend(fontsize=7)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       4 # fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
#       5 # fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
#       6 fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))
# ----> 8 jets_hydro_quench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err)**2)
#       9 jets_hydro_noquench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err)**2)
# ...

# %%
import numpy  as np
import matplotlib.pyplot as plt

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))
# fig, (ax3, ax4) = plt.subplots(2,1,figsize=(6.0,9.0))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))

# pp_AuAu_pion0_20_RAA_ratio_err = ((pion_xscape_AuAu_0_20_cross_sec)/pion_xscape_pp_0_20_cross_sec) * np.sqrt(((pion_xscape_AuAu_0_20_cross_sec_err)/(pion_xscape_AuAu_0_20_cross_sec))**2 + (pion_xscape_pp_0_20_cross_sec_err/pion_xscape_pp_0_20_cross_sec)**2)

jets_hydro_quench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err)**2)
jets_hydro_noquench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err)**2)

jets_hydro_quench_only_hydro_subtraction_deltaR_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err)**2)
jets_hydro_noquench_only_hydro_subtraction_deltaR_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err)**2)

jets_hydro_quench_only_hydro_subtraction_z = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz)
jets_hydro_noquench_only_hydro_subtraction_z = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz)

jets_hydro_quench_only_hydro_subtraction_deltaR = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR)
jets_hydro_noquench_only_hydro_subtraction_deltaR = pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR - (pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNddeltaR)

jets_hydro_quench_jets_nohydro_quench_ratio_z = jets_hydro_quench_only_hydro_subtraction_z/pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz
jets_hydro_noquench_jets_nohydro_noquench_ratio_z = jets_hydro_noquench_only_hydro_subtraction_z/pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz
jets_hydro_quench_jets_hydro_noquench_ratio_z = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz/pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz

jets_hydro_quench_jets_nohydro_quench_ratio_deltaR = jets_hydro_quench_only_hydro_subtraction_deltaR/pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR
jets_hydro_noquench_jets_nohydro_noquench_ratio_deltaR = jets_hydro_noquench_only_hydro_subtraction_deltaR/pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR
jets_hydro_quench_jets_hydro_noquench_ratio_deltaR = pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR/pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR

jets_hydro_quench_jets_nohydro_quench_ratio_z_err = (jets_hydro_quench_jets_nohydro_quench_ratio_z) * np.sqrt(((jets_hydro_quench_only_hydro_subtraction_z_err)/(jets_hydro_quench_only_hydro_subtraction_z))**2 + (pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err/pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz)**2)
jets_hydro_noquench_jets_nohydro_noquench_ratio_z_err = (jets_hydro_noquench_jets_nohydro_noquench_ratio_z) * np.sqrt(((jets_hydro_noquench_only_hydro_subtraction_z_err)/(jets_hydro_noquench_only_hydro_subtraction_z))**2 + (pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err/pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz)**2)
jets_hydro_quench_jets_hydro_noquench_ratio_z_err = (jets_hydro_quench_jets_hydro_noquench_ratio_z) * np.sqrt(((pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err)/(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz))**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz_err/pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNdz)**2)

jets_hydro_quench_jets_nohydro_quench_ratio_deltaR_err = (jets_hydro_quench_jets_nohydro_quench_ratio_deltaR) * np.sqrt(((jets_hydro_quench_only_hydro_subtraction_deltaR_err)/(jets_hydro_quench_only_hydro_subtraction_deltaR))**2 + (pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err/pion_Au_jet_xscape_15_100_noprompt_nohydro_quench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR)**2)
jets_hydro_noquench_jets_nohydro_noquench_ratio_deltaR_err = (jets_hydro_noquench_jets_nohydro_noquench_ratio_deltaR) * np.sqrt(((jets_hydro_noquench_only_hydro_subtraction_deltaR_err)/(jets_hydro_noquench_only_hydro_subtraction_deltaR))**2 + (pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err/pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR)**2)
jets_hydro_quench_jets_hydro_noquench_ratio_deltaR_err = (jets_hydro_quench_jets_hydro_noquench_ratio_deltaR) * np.sqrt(((pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR_err)/(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNddeltaR))**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR_err/pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_dNddeltaR)**2)

ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_z, jets_hydro_quench_jets_hydro_noquench_ratio_z, yerr = jets_hydro_quench_jets_hydro_noquench_ratio_z_err, fmt = 'o', color='green', capsize=5, label = r'$\frac{Jets+nPDF+Hydro(quenched)}{Jets+nPDF+Hydro(non-quenched)}$')
# ax1.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_z, abs(jets_hydro_noquench_jets_nohydro_noquench_ratio_z), yerr = abs(jets_hydro_noquench_jets_nohydro_noquench_ratio_z_err), fmt = '-', color='orange', capsize=5, label = r'$\frac{Jets+nPDF+Hydro(nonquenched)}{Jets+nPDF(nonquenched)}$')
# ax1.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE Jets+nPDF, 0-5%')
# ax1.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_z, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz/10, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNdz_err/10, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')

ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_deltaR, jets_hydro_quench_jets_hydro_noquench_ratio_deltaR, yerr = jets_hydro_quench_jets_hydro_noquench_ratio_deltaR_err, fmt = 'o', color='green', capsize=5, label = r'$\frac{Jets+nPDF+Hydro (quenched)}{Jets+nPDF+Hydro(non-quenched)}$')
# ax2.errorbar(pion_Au_hydro_jet_xscape_15_100_noprompt_noquench_deltaRcut_constituentcut_bgdsub_centr0_5_jetpt_20_30_deltaR, abs(jets_hydro_noquench_jets_nohydro_noquench_ratio_deltaR), yerr = abs(jets_hydro_noquench_jets_nohydro_noquench_ratio_deltaR_err), fmt = '-', color='orange', capsize=5, label = r'$\frac{Jets+nPDF+Hydro (nonquenched)}{Jets+nPDF(nonquenched)}$')
# ax2.errorbar(pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = pion_Au_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE Jets+nPDF, 0-5%')
# ax2.errorbar(pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_deltaR, pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR/10, yerr = pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_centr0_1_dNddeltaR_err/10, fmt = '-', color='purple', capsize=5, label = 'JETSCAPE Pions, only hydro, random cone, 0-1%')

# ax1.set_yscale('log')
ax1.set_title('Momentum Fraction Ratio of Charged Pions in AuAu Dijets')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\pi}}{p_{T}^{jets}}$',fontsize=14)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=14)
ax1.text(0.2, 0.15, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax1.text(0.2, 0.0, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
ax1.text(0.2, -0.15, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax1.set_ylim(-0.5,2)
ax1.legend(fontsize=11)

# ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ Ratio of Charged Pions in AuAu Dijets')
ax2.set_xlabel(r'$\Delta R$',fontsize=14)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{d\Delta R}$',fontsize=14)
ax2.text(0.2, 0.15, 'Preliminary (Sleeth, Paquet, RKE)', fontsize=11)
# ax1.text(0.25, 5, 'Sleeth, Paquet, RKE' , fontsize=12)
ax2.text(0.2, 0.00, 'AuAu $\sqrt{s_{NN}} = 200$ GeV', fontsize=11)
ax2.text(0.2, -0.15, 'anti-$k_{T}$, R=0.4, $20<p_{T}^{jet}<30$ GeV' , fontsize=11)
ax2.set_ylim(-0.5,2)
ax2.legend(fontsize=11)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       6 fig, (ax1, ax2) = plt.subplots(1,2,figsize=(14.0,5.5))
#       8 # pp_AuAu_pion0_20_RAA_ratio_err = ((pion_xscape_AuAu_0_20_cross_sec)/pion_xscape_pp_0_20_cross_sec) * np.sqrt(((pion_xscape_AuAu_0_20_cross_sec_err)/(pion_xscape_AuAu_0_20_cross_sec))**2 + (pion_xscape_pp_0_20_cross_sec_err/pion_xscape_pp_0_20_cross_sec)**2)
# ---> 10 jets_hydro_quench_only_hydro_subtraction_z_err = np.sqrt((pion_Au_only_hydro_jet_xscape_noprompt_deltaRcut_constituentcut_randomcone_dNdz_err)**2 + (pion_Au_hydro_jet_xscape_15_100_noprompt_deltaRcut_constituentcut_bgdsub_smeared_jetpt_20_30_dNdz_err)**2)
# ...

# %%
import numpy  as np
import matplotlib.pyplot as plt

#With Track pT cut:

#Number of raw jets in pp for 10M: 2300389
# 230138
#Number of raw jets in AuAu+nPDF for 100M (99,000,000 actually but close enough): 6506
#Number of raw jets in AuAu+nPDF for 10M: 632
#Number of sub jets in AuAu+hydro for 10k: 1522
#Number of sub jets in AuAu+hydro for 100k: 14736
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 14736
#Number of reflected cones in AuAu+hydro for 100k: 8606

#Number of raw pions in pp for 10M: 301347
#Number of raw pions in AuAu+nPDF for 100M: 
#Number of sub pions in AuAu+hydro for 100k: 267999


#Without Track pT cut:

#Number of raw jets in pp for 10M: 254484
#Number of raw jets in AuAu+nPDF for 100M: 
#Number of raw jets in AuAu+nPDF for 10M: 650
#Number of sub jets in AuAu+hydro for 10k: 
#Number of sub jets in AuAu+hydro for 100k: 18335
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 18335  

#Number of raw pions in pp for 10M: 348825
#Number of raw pions in AuAu+nPDF for 10M: 855
#Number of sub pions in AuAu+hydro for 100k: 742368
#Number of random cone pions in AuAu hydro for 1k and AuAu+hydro for 100k:

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

# 10-20
jet_pp_jetscape_15_100_raw_jet10_20_pion_pT, jet_pp_jetscape_15_100_raw_jet10_20_pion_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet10_20_pion_pt_counts.txt').T
pp_pions_per_jet10_20 = jet_pp_jetscape_15_100_raw_jet10_20_pion_dNdpT/157614
ax1.plot(jet_pp_jetscape_15_100_raw_jet10_20_pion_pT, pp_pions_per_jet10_20, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet10_20_pion_pt_counts.txt').T
AuAu_nPDF_pions_per_jet10_20 = jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_dNdpT/5606
ax1.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion_pT, AuAu_nPDF_pions_per_jet10_20, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet10_20_pion_pt_counts.txt').T
AuAu_nPDF_quenched_pions_per_jet10_20 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_dNdpT/20806
ax1.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion_pT, AuAu_nPDF_quenched_pions_per_jet10_20, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet10_20_pion_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions_per_jet10_20 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_dNdpT/160513
ax1.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion_pT, AuAu_nPDF_quenched_brick_pions_per_jet10_20, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet10_20_pion_pt_counts.txt').T
AuAu_hydro_pions_per_jet10_20 = jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_dNdpT/106254
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, AuAu_hydro_pions_per_jet10_20, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone10_20_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions_per_cone10_20 = cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion_dNdpT/106254
ax1.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion_pT, cone_hydro_pions_per_cone10_20, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone10_20_pion_pt_counts.txt').T
perp_cone_hydro_pions_per_cone10_20 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT/212508
ax1.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, perp_cone_hydro_pions_per_cone10_20, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_cone10_20_pion_pt_counts.txt').T
grid_cone_hydro_pions_per_cone10_20 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT/6367696
ax1.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, grid_cone_hydro_pions_per_cone10_20, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone10_20_pion_pt_counts.txt').T
reflected_cone_hydro_pions_per_cone10_20 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_dNdpT/106254
ax1.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion_pT, reflected_cone_hydro_pions_per_cone10_20, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')


# 20-30
jet_pp_jetscape_15_100_raw_jet_pion_pT, jet_pp_jetscape_15_100_raw_jet_pion_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet_pion_pt_counts.txt').T
pp_pions_per_event = jet_pp_jetscape_15_100_raw_jet_pion_dNdpT/10000000
pp_pions_per_jet = jet_pp_jetscape_15_100_raw_jet_pion_dNdpT/2300389
ax2.plot(jet_pp_jetscape_15_100_raw_jet_pion_pT, pp_pions_per_jet, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet_pion_pt_counts.txt').T
AuAu_nPDF_pions_per_event = jet_AuAu_nPDF_jetscape_15_100_raw_jet_dNdpT/100000000
AuAu_nPDF_pions_per_jet = jet_AuAu_nPDF_jetscape_15_100_raw_jet_dNdpT/6506
ax2.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion_pT, AuAu_nPDF_pions_per_jet, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet_pion_pt_counts.txt').T
AuAu_nPDF_quenched_pions_per_event = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_dNdpT/1000000
AuAu_nPDF_quenched_pions_per_jet = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_dNdpT/(19416*10)
ax2.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion_pT, AuAu_nPDF_quenched_pions_per_jet, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet_pion_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions_per_event = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_dNdpT/1000000
AuAu_nPDF_quenched_brick_pions_per_jet = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_dNdpT/(223100*10)
ax2.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion_pT, AuAu_nPDF_quenched_brick_pions_per_jet, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet_pion_pt_counts.txt').T
AuAu_hydro_pions_per_event = jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_dNdpT/100000
AuAu_hydro_pions_per_jet = jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_dNdpT/14736
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, AuAu_hydro_pions_per_jet, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions_per_event = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion_dNdpT/100000
cone_hydro_pions_per_cone = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion_dNdpT/14736
ax2.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion_pT, cone_hydro_pions_per_cone, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone_pion_pt_counts.txt').T
perp_cone_hydro_pions_per_event = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/100000
perp_cone_hydro_pions_per_cone = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/29472
ax2.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, perp_cone_hydro_pions_per_cone, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_cone_pion_pt_counts.txt').T
grid_cone_hydro_pions_per_event = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/100000
grid_cone_hydro_pions_per_cone = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/6367696
ax2.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, grid_cone_hydro_pions_per_cone, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone_pion_pt_counts.txt').T
reflected_cone_hydro_pions_per_event = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/100000
reflected_cone_hydro_pions_per_cone = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/8606
ax2.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, reflected_cone_hydro_pions_per_cone, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')

corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_corrected_perpendicular_cone_pion_pt_counts.txt').T
corrected_perp_cone_hydro_pions_per_event = corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/100000
corrected_perp_cone_hydro_pions_per_cone = corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT/29472
# plt.plot(corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, corrected_perp_cone_hydro_pions_per_cone, linestyle='-', marker='.', color='purple', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu flow corrected perpendicular cones')


# 30-40
jet_pp_jetscape_15_100_raw_jet30_40_pion_pT, jet_pp_jetscape_15_100_raw_jet30_40_pion_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet30_40_pion_pt_counts.txt').T
pp_pions_per_jet30_40 = jet_pp_jetscape_15_100_raw_jet30_40_pion_dNdpT/29263
ax3.plot(jet_pp_jetscape_15_100_raw_jet30_40_pion_pT, pp_pions_per_jet30_40, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet30_40_pion_pt_counts.txt').T
AuAu_nPDF_pions_per_jet30_40 = jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_dNdpT/118
ax3.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion_pT, AuAu_nPDF_pions_per_jet30_40, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet30_40_pion_pt_counts.txt').T
AuAu_nPDF_quenched_pions_per_jet30_40 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_dNdpT/2239
ax3.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion_pT, AuAu_nPDF_quenched_pions_per_jet30_40, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet30_40_pion_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions_per_jet30_40 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_dNdpT/25278
ax3.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion_pT, AuAu_nPDF_quenched_brick_pions_per_jet30_40, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet30_40_pion_pt_counts.txt').T
AuAu_hydro_pions_per_jet30_40 = jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_dNdpT/1630
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, AuAu_hydro_pions_per_jet30_40, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone30_40_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions_per_cone30_40 = cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion_dNdpT/1630
ax3.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion_pT, cone_hydro_pions_per_cone30_40, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone30_40_pion_pt_counts.txt').T
perp_cone_hydro_pions_per_cone30_40 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT/3260
ax3.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, perp_cone_hydro_pions_per_cone30_40, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_cone30_40_pion_pt_counts.txt').T
grid_cone_hydro_pions_per_cone30_40 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT/6367696
ax3.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, grid_cone_hydro_pions_per_cone30_40, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone30_40_pion_pt_counts.txt').T
reflected_cone_hydro_pions_per_cone30_40 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_dNdpT/1630
ax3.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion_pT, reflected_cone_hydro_pions_per_cone30_40, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')


# 40-50
jet_pp_jetscape_15_100_raw_jet40_50_pion_pT, jet_pp_jetscape_15_100_raw_jet40_50_pion_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet40_50_pion_pt_counts.txt').T
pp_pions_per_jet40_50 = jet_pp_jetscape_15_100_raw_jet40_50_pion_dNdpT/1864
ax4.plot(jet_pp_jetscape_15_100_raw_jet40_50_pion_pT, pp_pions_per_jet40_50, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet40_50_pion_pt_counts.txt').T
AuAu_nPDF_pions_per_jet40_50 = jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_dNdpT/9
ax4.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion_pT, AuAu_nPDF_pions_per_jet40_50, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet40_50_pion_pt_counts.txt').T
AuAu_nPDF_quenched_pions_per_jet40_50 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_dNdpT/(138)
ax4.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion_pT, AuAu_nPDF_quenched_pions_per_jet40_50, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet40_50_pion_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions_per_jet40_50 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_dNdpT/(1581)
ax4.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion_pT, AuAu_nPDF_quenched_brick_pions_per_jet40_50, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet40_50_pion_pt_counts.txt').T
AuAu_hydro_pions_per_jet40_50 = jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_dNdpT/129
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, AuAu_hydro_pions_per_jet40_50, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone40_50_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions_per_cone40_50 = cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion_dNdpT/129
ax4.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion_pT, cone_hydro_pions_per_cone40_50, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone40_50_pion_pt_counts.txt').T
perp_cone_hydro_pions_per_cone40_50 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT/258
ax4.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, perp_cone_hydro_pions_per_cone40_50, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_cone40_50_pion_pt_counts.txt').T
grid_cone_hydro_pions_per_cone40_50 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT/6367696
ax4.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, grid_cone_hydro_pions_per_cone40_50, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone40_50_pion_pt_counts.txt').T
reflected_cone_hydro_pions_per_cone40_50 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_dNdpT/129
ax4.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion_pT, reflected_cone_hydro_pions_per_cone40_50, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')

# cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_notrackpTcut_cone_pt_counts_v3.txt').T
# plt.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu random cones')

# plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, (AuAu_hydro_pions_per_jet) - (perp_cone_hydro_pions_per_cone), linestyle='-', marker='.', color='black', label = 'JETSCAPE 20 < $p_{T}$ < 30 AuAu+hydro - perp cones')

# plt.yscale('log')
# plt.ylim(1e-5,1e3)
# plt.xlim(0,15.1)
# plt.title(r'Dijet Charged Pion $p_{T}$ Spectra, $p_{T}^{trk}$>0.5GeV')
# plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets/cones}} N_{\pi}$',fontsize=12)
# plt.legend(fontsize=7)

ax1.set_yscale('log')
ax1.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 10<$p_{T}$<20')
ax1.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax1.set_ylim(1e-4,1e3)
ax1.legend(fontsize=7)

ax2.set_yscale('log')
ax2.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 20<$p_{T}$<30')
ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax2.set_ylim(1e-4,1e3)
ax2.legend(fontsize=7)

ax3.set_yscale('log')
ax3.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 30<$p_{T}$<40')
ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax3.set_ylim(1e-4,1e3)
ax3.legend(fontsize=7)

ax4.set_yscale('log')
ax4.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 40<$p_{T}$<50')
ax4.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax4.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax4.set_ylim(1e-4,1e3)
ax4.legend(fontsize=7)

plt.tight_layout()
plt.show()

# %%
## Ratio Plots (need to be the same bins)
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

#10-20
# Ratio of pp / pp
Ratiopp_pp10_20 = (pp_pions_per_jet10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, Ratiopp_pp10_20, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp10_20 = (AuAu_hydro_pions_per_jet10_20*2) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAAHydro_pp10_20, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone10_20_pp = ((AuAu_hydro_pions_per_jet10_20*2) - perp_cone_hydro_pions_per_cone10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAAHydroPerpCone10_20_pp, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
RatioAAHydroRandCone10_20_pp = ((AuAu_hydro_pions_per_jet10_20*2) - cone_hydro_pions_per_cone10_20) / (pp_pions_per_jet10_20) 
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAAHydroRandCone10_20_pp, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone10_20_pp = ((AuAu_hydro_pions_per_jet10_20*2) - reflected_cone_hydro_pions_per_cone10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAAHydroReflCone10_20_pp, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone10_20_pp = ((AuAu_hydro_pions_per_jet10_20*2) - grid_cone_hydro_pions_per_cone10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAAHydroGridCone10_20_pp, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched10_20_pp = (AuAu_nPDF_quenched_pions_per_jet10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAANoHydroQuenched10_20_pp, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick10_20_pp = (AuAu_nPDF_quenched_brick_pions_per_jet10_20) / (pp_pions_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion_pT, RatioAANoHydroQuenchedBrick10_20_pp, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick / pp')

#20-30
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp = (pp_pions_per_jet) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, Ratiopp_pp, linestyle='--', color='red', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp = (AuAu_hydro_pions_per_jet) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAAHydro_pp, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone_pp = ((AuAu_hydro_pions_per_jet/2) - perp_cone_hydro_pions_per_cone) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAAHydroPerpCone_pp, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
RatioAAHydroRandCone_pp = ((AuAu_hydro_pions_per_jet/2) - cone_hydro_pions_per_cone) / (pp_pions_per_jet) 
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAAHydroRandCone_pp, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone_pp = ((AuAu_hydro_pions_per_jet/2) - reflected_cone_hydro_pions_per_cone) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAAHydroReflCone_pp, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone_pp = ((AuAu_hydro_pions_per_jet/2) - grid_cone_hydro_pions_per_cone) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAAHydroGridCone_pp, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched_pp = (AuAu_nPDF_quenched_pions_per_jet) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAANoHydroQuenched_pp, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick_pp = (AuAu_nPDF_quenched_brick_pions_per_jet) / (pp_pions_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, RatioAANoHydroQuenchedBrick_pp, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick / pp')

#30-40
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp30_40 = (pp_pions_per_jet30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, Ratiopp_pp30_40, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp30_40 = (AuAu_hydro_pions_per_jet30_40*2) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAAHydro_pp30_40, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone30_40_pp = ((AuAu_hydro_pions_per_jet30_40*2) - perp_cone_hydro_pions_per_cone30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAAHydroPerpCone30_40_pp, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
RatioAAHydroRandCone30_40_pp = ((AuAu_hydro_pions_per_jet30_40*2) - cone_hydro_pions_per_cone30_40) / (pp_pions_per_jet30_40) 
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAAHydroRandCone30_40_pp, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone30_40_pp = ((AuAu_hydro_pions_per_jet30_40*2) - reflected_cone_hydro_pions_per_cone30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAAHydroReflCone30_40_pp, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone30_40_pp = ((AuAu_hydro_pions_per_jet30_40*2) - grid_cone_hydro_pions_per_cone30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAAHydroGridCone30_40_pp, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched30_40_pp = (AuAu_nPDF_quenched_pions_per_jet30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAANoHydroQuenched30_40_pp, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick30_40_pp = (AuAu_nPDF_quenched_brick_pions_per_jet30_40) / (pp_pions_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion_pT, RatioAANoHydroQuenchedBrick30_40_pp, linestyle='-', marker='.', color='black', label = 'JETSCAPE  AuAu+nPDF Quenched Brick / pp')

#40-50
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp40_50 = (pp_pions_per_jet40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, Ratiopp_pp40_50, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp40_50 = (AuAu_hydro_pions_per_jet40_50*2) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAAHydro_pp40_50, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone40_50_pp = ((AuAu_hydro_pions_per_jet40_50*2) - perp_cone_hydro_pions_per_cone40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAAHydroPerpCone40_50_pp, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
RatioAAHydroRandCone40_50_pp = ((AuAu_hydro_pions_per_jet40_50*2) - cone_hydro_pions_per_cone40_50) / (pp_pions_per_jet40_50) 
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAAHydroRandCone40_50_pp, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone40_50_pp = ((AuAu_hydro_pions_per_jet40_50*2) - reflected_cone_hydro_pions_per_cone40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAAHydroReflCone40_50_pp, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone40_50_pp = ((AuAu_hydro_pions_per_jet40_50) - grid_cone_hydro_pions_per_cone40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAAHydroGridCone40_50_pp, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched40_50_pp = (AuAu_nPDF_quenched_pions_per_jet40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAANoHydroQuenched40_50_pp, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick40_50_pp = (AuAu_nPDF_quenched_brick_pions_per_jet40_50) / (pp_pions_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion_pT, RatioAANoHydroQuenchedBrick40_50_pp, linestyle='-', marker='.', color='black', label = 'JETSCAPE  AuAu+nPDF Quenched Brick / pp')

# plt.yscale('log')
# plt.ylim(-0.5,5.5)
# plt.xlim(0,15.1)
# plt.title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, $p_{T}^{trk}$>0.5GeV')
# plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets/cones}}N_{\pi}$',fontsize=12)
# plt.legend(fontsize=7)

# ax1.set_yscale('log')
ax1.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 10<$p_{T}$<20')
ax1.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax1.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax1.set_ylim(0.0,2.5)
ax1.legend(fontsize=7)

ax2.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 20<$p_{T}$<30')
ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax2.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax2.set_ylim(0.0,2.5)
ax2.legend(fontsize=7)

ax3.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 30<$p_{T}$<40')
ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax3.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax3.set_ylim(0.0,2.5)
ax3.legend(fontsize=7)

ax4.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 40<$p_{T}$<50')
ax4.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax4.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax4.set_ylim(0.0,2.5)
ax4.legend(fontsize=7)

plt.tight_layout()
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

#With Track pT cut:

#Number of raw jets in pp for 10M: 2300389
# 230138
#Number of raw jets in AuAu+nPDF for 100M (99,000,000 actually but close enough): 6506
#Number of raw jets in AuAu+nPDF for 10M: 632
#Number of sub jets in AuAu+hydro for 10k: 1522
#Number of sub jets in AuAu+hydro for 100k: 14736
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 14736
#Number of reflected cones in AuAu+hydro for 100k: 8606

#Number of raw pions in pp for 10M: 301347
#Number of raw pions in AuAu+nPDF for 100M: 
#Number of sub pions in AuAu+hydro for 100k: 267999


#Without Track pT cut:

#Number of raw jets in pp for 10M: 254484
#Number of raw jets in AuAu+nPDF for 100M: 
#Number of raw jets in AuAu+nPDF for 10M: 650
#Number of sub jets in AuAu+hydro for 10k: 
#Number of sub jets in AuAu+hydro for 100k: 18335
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 18335  

#Number of raw pions in pp for 10M: 348825
#Number of raw pions in AuAu+nPDF for 10M: 855
#Number of sub pions in AuAu+hydro for 100k: 742368
#Number of random cone pions in AuAu hydro for 1k and AuAu+hydro for 100k:

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

# 10-20
jet_pp_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, jet_pp_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet10_20_pion4GeVcut_pt_counts.txt').T
pp_pions4GeVcut_per_jet10_20 = jet_pp_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT/157614
ax1.plot(jet_pp_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, pp_pions4GeVcut_per_jet10_20, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet10_20_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_pions4GeVcut_per_jet10_20 = jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT/5606
ax1.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, AuAu_nPDF_pions4GeVcut_per_jet10_20, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet10_20_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_pions4GeVcut_per_jet10_20 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT/20806
ax1.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, AuAu_nPDF_quenched_pions4GeVcut_per_jet10_20, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet10_20_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet10_20 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion4GeVcut_dNdpT/160513
ax1.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet10_20_pion4GeVcut_pT, AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet10_20, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet10_20_pion4GeVcut_pt_counts.txt').T
AuAu_hydro_pions4GeVcut_per_jet10_20 = jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_dNdpT/106254
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, AuAu_hydro_pions4GeVcut_per_jet10_20, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion4GeVcut_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone10_20_pion4GeVcut_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions4GeVcut_per_cone10_20 = cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion4GeVcut_dNdpT/106254
ax1.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pTcut_pion4GeVcut_pT, cone_hydro_pions4GeVcut_per_cone10_20, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone10_20_pion4GeVcut_pt_counts.txt').T
perp_cone_hydro_pions4GeVcut_per_cone10_20 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT/212508
ax1.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, perp_cone_hydro_pions4GeVcut_per_cone10_20, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut6GeV_cone10_20_pion4GeVcut_pt_counts.txt').T
grid_cone_hydro_pions4GeVcut_per_cone10_20 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT/6367696
ax1.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, grid_cone_hydro_pions4GeVcut_per_cone10_20, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone10_20_pion4GeVcut_pt_counts.txt').T
reflected_cone_hydro_pions4GeVcut_per_cone10_20 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_dNdpT/106254
ax1.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone10_20_pion4GeVcut_pT, reflected_cone_hydro_pions4GeVcut_per_cone10_20, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')


# 20-30
jet_pp_jetscape_15_100_raw_jet_pion4GeVcut_pT, jet_pp_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet_pion4GeVcut_pt_counts.txt').T
pp_pions4GeVcut_per_event = jet_pp_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/10000000
pp_pions4GeVcut_per_jet = jet_pp_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/230138
ax2.plot(jet_pp_jetscape_15_100_raw_jet_pion4GeVcut_pT, pp_pions4GeVcut_per_jet, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion4GeVcut_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_pions4GeVcut_per_event = jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/100000000
AuAu_nPDF_pions4GeVcut_per_jet = jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/632
ax2.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet_pion4GeVcut_pT, AuAu_nPDF_pions4GeVcut_per_jet, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_pions4GeVcut_per_event = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/1000000
AuAu_nPDF_quenched_pions4GeVcut_per_jet = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/(19416)
ax2.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet_pion4GeVcut_pT, AuAu_nPDF_quenched_pions4GeVcut_per_jet, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions4GeVcut_per_event = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/1000000
AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion4GeVcut_dNdpT/(223100)
ax2.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet_pion4GeVcut_pT, AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet_pion4GeVcut_pt_counts.txt').T
AuAu_hydro_pions4GeVcut_per_event = jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_dNdpT/100000
AuAu_hydro_pions4GeVcut_per_jet = jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_dNdpT/14736
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, AuAu_hydro_pions4GeVcut_per_jet, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion4GeVcut_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone_pion4GeVcut_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions4GeVcut_per_event = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion4GeVcut_dNdpT/100000
cone_hydro_pions4GeVcut_per_cone = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion4GeVcut_dNdpT/14736
ax2.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_pion4GeVcut_pT, cone_hydro_pions4GeVcut_per_cone, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone_pion4GeVcut_pt_counts.txt').T
perp_cone_hydro_pions4GeVcut_per_event = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/100000
perp_cone_hydro_pions4GeVcut_per_cone = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/29472
ax2.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, perp_cone_hydro_pions4GeVcut_per_cone, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut6GeV_cone_pion4GeVcut_pt_counts.txt').T
grid_cone_hydro_pions4GeVcut_per_event = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/100000
grid_cone_hydro_pions4GeVcut_per_cone = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/6367696
ax2.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, grid_cone_hydro_pions4GeVcut_per_cone, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone_pion4GeVcut_pt_counts.txt').T
reflected_cone_hydro_pions4GeVcut_per_event = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/100000
reflected_cone_hydro_pions4GeVcut_per_cone = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/14736
ax2.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, reflected_cone_hydro_pions4GeVcut_per_cone, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')

# corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_pT, corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_corrected_perpendicular_cone_pion4GeVcut_pt_counts.txt').T
# corrected_perp_cone_hydro_pions4GeVcut_per_event = corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/100000
# corrected_perp_cone_hydro_pions4GeVcut_per_cone = corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion4GeVcut_dNdpT/29472
# # plt.plot(corrected_perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_pT, corrected_perp_cone_hydro_pions_per_cone, linestyle='-', marker='.', color='purple', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu flow corrected perpendicular cones')


# 30-40
jet_pp_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, jet_pp_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet30_40_pion4GeVcut_pt_counts.txt').T
pp_pions4GeVcut_per_jet30_40 = jet_pp_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT/29263
ax3.plot(jet_pp_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, pp_pions4GeVcut_per_jet30_40, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet30_40_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_pions4GeVcut_per_jet30_40 = jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT/118
ax3.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, AuAu_nPDF_pions4GeVcut_per_jet30_40, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet30_40_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_pions4GeVcut_per_jet30_40 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT/2239
ax3.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, AuAu_nPDF_quenched_pions4GeVcut_per_jet30_40, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet30_40_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet30_40 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion4GeVcut_dNdpT/25278
ax3.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet30_40_pion4GeVcut_pT, AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet30_40, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet30_40_pion4GeVcut_pt_counts.txt').T
AuAu_hydro_pions4GeVcut_per_jet30_40 = jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_dNdpT/1630
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, AuAu_hydro_pions4GeVcut_per_jet30_40, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion4GeVcut_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone30_40_pion4GeVcut_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions4GeVcut_per_cone30_40 = cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion4GeVcut_dNdpT/1630
ax3.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pTcut_pion4GeVcut_pT, cone_hydro_pions4GeVcut_per_cone30_40, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone30_40_pion4GeVcut_pt_counts.txt').T
perp_cone_hydro_pions4GeVcut_per_cone30_40 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT/3260
ax3.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, perp_cone_hydro_pions4GeVcut_per_cone30_40, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut6GeV_cone30_40_pion4GeVcut_pt_counts.txt').T
grid_cone_hydro_pions4GeVcut_per_cone30_40 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT/6367696
ax3.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, grid_cone_hydro_pions4GeVcut_per_cone30_40, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone30_40_pion4GeVcut_pt_counts.txt').T
reflected_cone_hydro_pions4GeVcut_per_cone30_40 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_dNdpT/1630
ax3.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone30_40_pion4GeVcut_pT, reflected_cone_hydro_pions4GeVcut_per_cone30_40, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')


# 40-50
jet_pp_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, jet_pp_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet40_50_pion4GeVcut_pt_counts.txt').T
pp_pions4GeVcut_per_jet40_50 = jet_pp_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT/1864
ax4.plot(jet_pp_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, pp_pions4GeVcut_per_jet40_50, linestyle = '-', marker='.', color='red', label = 'JETSCAPE pp raw dijets')

jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut05_raw_jet40_50_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_pions4GeVcut_per_jet40_50 = jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT/9
ax4.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, AuAu_nPDF_pions4GeVcut_per_jet40_50, linestyle='-', marker='.', color='blue', label = 'JETSCAPE AuAu+nPDF raw dijets')

jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_10M_trackpTcut05_raw_jet40_50_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_pions4GeVcut_per_jet40_50 = jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT/(138)
ax4.plot(jet_AuAu_nPDF_quenched_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, AuAu_nPDF_quenched_pions4GeVcut_per_jet40_50, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched raw dijets')

jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_quenched_brick_10M_trackpTcut05_raw_jet40_50_pion4GeVcut_pt_counts.txt').T
AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet40_50 = jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion4GeVcut_dNdpT/(1581)
ax4.plot(jet_AuAu_nPDF_quenched_brick_jetscape_15_100_raw_jet40_50_pion4GeVcut_pT, AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet40_50, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_sub_jet40_50_pion4GeVcut_pt_counts.txt').T
AuAu_hydro_pions4GeVcut_per_jet40_50 = jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_dNdpT/129
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, AuAu_hydro_pions4GeVcut_per_jet40_50, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro $p_{T}$ subtracted dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion4GeVcut_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone40_50_pion4GeVcut_pt_counts_v3_fixed_bins.txt').T
cone_hydro_pions4GeVcut_per_cone40_50 = cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion4GeVcut_dNdpT/129
ax4.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pTcut_pion4GeVcut_pT, cone_hydro_pions4GeVcut_per_cone40_50, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_perp_cone40_50_pion4GeVcut_pt_counts.txt').T
perp_cone_hydro_pions4GeVcut_per_cone40_50 = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT/258
ax4.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, perp_cone_hydro_pions4GeVcut_per_cone40_50, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu perpendicular cones')

grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_ATLASGrid_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut6GeV_cone40_50_pion4GeVcut_pt_counts.txt').T
grid_cone_hydro_pions4GeVcut_per_cone40_50 = grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT/6367696
ax4.plot(grid_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, grid_cone_hydro_pions4GeVcut_per_cone40_50, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu grid cones')

reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_Jussi_method_reflected_cone40_50_pion4GeVcut_pt_counts.txt').T
reflected_cone_hydro_pions4GeVcut_per_cone40_50 = reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_dNdpT/129
ax4.plot(reflected_cone_AuAu_hydro_jetscape_15_100_raw_cone40_50_pion4GeVcut_pT, reflected_cone_hydro_pions4GeVcut_per_cone40_50, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu reflected cones')

# cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_notrackpTcut_cone_pt_counts_v3.txt').T
# plt.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu random cones')

# plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, (AuAu_hydro_pions_per_jet) - (perp_cone_hydro_pions_per_cone), linestyle='-', marker='.', color='black', label = 'JETSCAPE 20 < $p_{T}$ < 30 AuAu+hydro - perp cones')

# plt.yscale('log')
# plt.ylim(1e-5,1e3)
# plt.xlim(0,15.1)
# plt.title(r'Dijet Charged Pion $p_{T}$ Spectra, $p_{T}^{trk}$>0.5GeV')
# plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets/cones}} N_{\pi}$',fontsize=12)
# plt.legend(fontsize=7)

ax1.set_yscale('log')
ax1.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 10<$p_{T}$<20, $p_{T}^{\pi}$>4 GeV')
ax1.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax1.set_ylim(1e-5,1e1)
ax1.legend(fontsize=7)

ax2.set_yscale('log')
ax2.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 20<$p_{T}$<30, $p_{T}^{\pi}$>4 GeV')
ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax2.set_ylim(1e-5,1e1)
ax2.legend(fontsize=7)

ax3.set_yscale('log')
ax3.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 30<$p_{T}$<40, $p_{T}^{\pi}$>4 GeV')
ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax3.set_ylim(1e-5,1e1)
ax3.legend(fontsize=7)

ax4.set_yscale('log')
ax4.set_title(r'Dijet Charged Pion $p_{T}$ Spectra, 40<$p_{T}$<50, $p_{T}^{\pi}$>4 GeV')
ax4.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax4.set_ylabel(r'$\frac{1}{N_{jets/cones}}$ $N^{\pi}$',fontsize=12)
ax4.set_ylim(1e-5,1e1)
ax4.legend(fontsize=7)

plt.tight_layout()
plt.show()

# %%
## Ratio Plots (need to be the same bins)
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize=(6.0,18.5))

#10-20
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp10_20_pion4GeVcut = (pp_pions4GeVcut_per_jet10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, Ratiopp_pp10_20_pion4GeVcut, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp10_20_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet10_20*2) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAAHydro_pp10_20_pion4GeVcut, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone10_20_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet10_20*2) - perp_cone_hydro_pions4GeVcut_per_cone10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAAHydroPerpCone10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
# RatioAAHydroRandCone10_20_pp_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet10_20 - cone_hydro_pions4GeVcut_per_cone10_20) / (pp_pions4GeVcut_per_jet10_20) 
# ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAAHydroRandCone10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone10_20_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet10_20*2) - reflected_cone_hydro_pions4GeVcut_per_cone10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAAHydroReflCone10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone10_20_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet10_20*2) - grid_cone_hydro_pions4GeVcut_per_cone10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAAHydroGridCone10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched10_20_pp_pion4GeVcut = (AuAu_nPDF_quenched_pions4GeVcut_per_jet10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAANoHydroQuenched10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick10_20_pp_pion4GeVcut = (AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet10_20) / (pp_pions4GeVcut_per_jet10_20)
ax1.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet10_20_pion4GeVcut_pT, RatioAANoHydroQuenchedBrick10_20_pp_pion4GeVcut, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick / pp')

#20-30
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp_pion4GeVcut = (pp_pions4GeVcut_per_jet) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, Ratiopp_pp_pion4GeVcut, linestyle='--', color='red', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet*2) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAAHydro_pp_pion4GeVcut, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet*2) - perp_cone_hydro_pions4GeVcut_per_cone) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAAHydroPerpCone_pp_pion4GeVcut, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
# RatioAAHydroRandCone_pp_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet - cone_hydro_pions4GeVcut_per_cone) / (pp_pions4GeVcut_per_jet) 
# ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAAHydroRandCone_pp_pion4GeVcut, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet*2) - reflected_cone_hydro_pions4GeVcut_per_cone) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAAHydroReflCone_pp_pion4GeVcut, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet*2) - grid_cone_hydro_pions4GeVcut_per_cone) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAAHydroGridCone_pp_pion4GeVcut, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched_pp_pion4GeVcut = (AuAu_nPDF_quenched_pions4GeVcut_per_jet) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAANoHydroQuenched_pp_pion4GeVcut, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick_pp_pion4GeVcut = (AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet) / (pp_pions4GeVcut_per_jet)
ax2.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion4GeVcut_pT, RatioAANoHydroQuenchedBrick_pp_pion4GeVcut, linestyle='-', marker='.', color='black', label = 'JETSCAPE AuAu+nPDF Quenched Brick / pp')

#30-40
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp30_40_pion4GeVcut = (pp_pions4GeVcut_per_jet30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, Ratiopp_pp30_40_pion4GeVcut, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp30_40_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet30_40*2) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAAHydro_pp30_40_pion4GeVcut, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone30_40_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet30_40*2) - perp_cone_hydro_pions4GeVcut_per_cone30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAAHydroPerpCone30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
# RatioAAHydroRandCone30_40_pp_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet30_40 - cone_hydro_pions4GeVcut_per_cone30_40) / (pp_pions4GeVcut_per_jet30_40) 
# ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAAHydroRandCone30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone30_40_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet30_40*2) - reflected_cone_hydro_pions4GeVcut_per_cone30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAAHydroReflCone30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone30_40_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet30_40*2) - grid_cone_hydro_pions4GeVcut_per_cone30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAAHydroGridCone30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched30_40_pp_pion4GeVcut = (AuAu_nPDF_quenched_pions4GeVcut_per_jet30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAANoHydroQuenched30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick30_40_pp_pion4GeVcut = (AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet30_40) / (pp_pions4GeVcut_per_jet30_40)
ax3.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet30_40_pion4GeVcut_pT, RatioAANoHydroQuenchedBrick30_40_pp_pion4GeVcut, linestyle='-', marker='.', color='black', label = 'JETSCAPE  AuAu+nPDF Quenched Brick / pp')

#40-50
# Ratio of AuAu+hydro - perpendicular cones / pp
Ratiopp_pp40_50_pion4GeVcut = (pp_pions4GeVcut_per_jet40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, Ratiopp_pp40_50_pion4GeVcut, linestyle='--', color='red', label = 'JETSCAPE pp / pp')

# Ratio of AuAu+hydro / pp
RatioAAHydro_pp40_50_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet40_50*2) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAAHydro_pp40_50_pion4GeVcut, linestyle='-', marker='.', color='green', label = 'JETSCAPE AuAu+hydro / pp')

# Ratio of AuAu+hydro - perpendicular cones / pp
RatioAAHydroPerpCone40_50_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet40_50*2) - perp_cone_hydro_pions4GeVcut_per_cone40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAAHydroPerpCone40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='orange', label = 'JETSCAPE AuAu+hydro-Perpendicular Cones / pp')

# Ratio of AuAu+hydro - random cones / pp
# RatioAAHydroRandCone40_50_pp_pion4GeVcut = (AuAu_hydro_pions4GeVcut_per_jet40_50 - cone_hydro_pions4GeVcut_per_cone40_50) / (pp_pions4GeVcut_per_jet40_50) 
# ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAAHydroRandCone40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu+hydro-Random Cones / pp')

# Ratio of AuAu+hydro - reflected cones / pp
RatioAAHydroReflCone40_50_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet40_50*2) - reflected_cone_hydro_pions4GeVcut_per_cone40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAAHydroReflCone40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='purple', label = 'JETSCAPE AuAu+hydro-Reflected Cones / pp')

# Ratio of AuAu+hydro - grid cones / pp
RatioAAHydroGridCone40_50_pp_pion4GeVcut = ((AuAu_hydro_pions4GeVcut_per_jet40_50*2) - grid_cone_hydro_pions4GeVcut_per_cone40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAAHydroGridCone40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='brown', label = 'JETSCAPE AuAu+hydro-Grid Cones / pp')

RatioAANoHydroQuenched40_50_pp_pion4GeVcut = (AuAu_nPDF_quenched_pions4GeVcut_per_jet40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAANoHydroQuenched40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='cyan', label = 'JETSCAPE AuAu+nPDF Quenched / pp')

RatioAANoHydroQuenchedBrick40_50_pp_pion4GeVcut = (AuAu_nPDF_quenched_brick_pions4GeVcut_per_jet40_50) / (pp_pions4GeVcut_per_jet40_50)
ax4.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet40_50_pion4GeVcut_pT, RatioAANoHydroQuenchedBrick40_50_pp_pion4GeVcut, linestyle='-', marker='.', color='black', label = 'JETSCAPE  AuAu+nPDF Quenched Brick / pp')

# plt.yscale('log')
# plt.ylim(-0.5,5.5)
# plt.xlim(0,15.1)
# plt.title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, $p_{T}^{trk}$>0.5GeV')
# plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets/cones}}N_{\pi}$',fontsize=12)
# plt.legend(fontsize=7)

# ax1.set_yscale('log')
ax1.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 10<$p_{T}$<20, $p_{T}^{\pi}$>4 GeV')
ax1.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax1.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax1.set_ylim(0.0,2.5)
ax1.legend(fontsize=7)

ax2.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 20<$p_{T}$<30, $p_{T}^{\pi}$>4 GeV')
ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax2.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax2.set_ylim(0.0,2.5)
ax2.legend(fontsize=7)

ax3.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 30<$p_{T}$<40, $p_{T}^{\pi}$>4 GeV')
ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax3.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax3.set_ylim(0.0,2.5)
ax3.legend(fontsize=7)

ax4.set_title(r'Dijet Charged Pion $p_{T}$ Spectra Ratios, 40<$p_{T}$<50, $p_{T}^{\pi}$>4 GeV')
ax4.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax4.set_ylabel(r'$\frac{AuAu+hydro - cones}{pp}$',fontsize=12)
ax4.set_ylim(0.0,2.5)
ax4.legend(fontsize=7)

plt.tight_layout()
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

charged_particle_AuAu_only_hydro_jetscape_centr0_10_eta, charged_particle_AuAu_only_hydro_jetscape_centr0_10_dNdeta = np.loadtxt('charged_particle_AuAu_only_hydro_full_SMASH_dNdeta_centr0_10.txt').T
AuAu_centr0_10_charged_particles_per_event = charged_particle_AuAu_only_hydro_jetscape_centr0_10_dNdeta/10
plt.plot(charged_particle_AuAu_only_hydro_jetscape_centr0_10_eta, AuAu_centr0_10_charged_particles_per_event, linestyle = '-', marker='.', color='red', label = 'JETSCAPE AuAu only hydro 0-10%')

charged_particle_AuAu_only_hydro_jetscape_centr10_20_eta, charged_particle_AuAu_only_hydro_jetscape_centr10_20_dNdeta = np.loadtxt('charged_particle_AuAu_only_hydro_full_SMASH_dNdeta_centr10_20.txt').T
AuAu_centr10_20_charged_particles_per_event = charged_particle_AuAu_only_hydro_jetscape_centr10_20_dNdeta/10
plt.plot(charged_particle_AuAu_only_hydro_jetscape_centr10_20_eta, AuAu_centr10_20_charged_particles_per_event, linestyle = '-', marker='.', color='blue', label = 'JETSCAPE AuAu only hydro 10-20%')

charged_particle_AuAu_only_hydro_jetscape_centr20_30_eta, charged_particle_AuAu_only_hydro_jetscape_centr20_30_dNdeta = np.loadtxt('charged_particle_AuAu_only_hydro_full_SMASH_dNdeta_centr20_30.txt').T
AuAu_centr20_30_charged_particles_per_event = charged_particle_AuAu_only_hydro_jetscape_centr20_30_dNdeta/10
plt.plot(charged_particle_AuAu_only_hydro_jetscape_centr20_30_eta, AuAu_centr20_30_charged_particles_per_event, linestyle = '-', marker='.', color='green', label = 'JETSCAPE AuAu only hydro 20-30%')

charged_particle_AuAu_only_hydro_jetscape_centr30_40_eta, charged_particle_AuAu_only_hydro_jetscape_centr30_40_dNdeta = np.loadtxt('charged_particle_AuAu_only_hydro_full_SMASH_dNdeta_centr30_40.txt').T
AuAu_centr30_40_charged_particles_per_event = charged_particle_AuAu_only_hydro_jetscape_centr30_40_dNdeta/10
plt.plot(charged_particle_AuAu_only_hydro_jetscape_centr30_40_eta, AuAu_centr30_40_charged_particles_per_event, linestyle = '-', marker='.', color='purple', label = 'JETSCAPE AuAu only hydro 30-40%')

charged_particle_AuAu_only_hydro_jetscape_centr40_50_eta, charged_particle_AuAu_only_hydro_jetscape_centr40_50_dNdeta = np.loadtxt('charged_particle_AuAu_only_hydro_full_SMASH_dNdeta_centr40_50.txt').T
AuAu_centr40_50_charged_particles_per_event = charged_particle_AuAu_only_hydro_jetscape_centr40_50_dNdeta/10
plt.plot(charged_particle_AuAu_only_hydro_jetscape_centr40_50_eta, AuAu_centr40_50_charged_particles_per_event, linestyle = '-', marker='.', color='orange', label = 'JETSCAPE AuAu only hydro 40-50%')

plt.yscale('log')
# plt.ylim(80,(1*10**(3.3)))
plt.xlim(-1.1,1.1)
plt.title(r'Charged Particle dN/deta, $p_{T}^{trk}$>0.05GeV')
plt.xlabel(r'$\eta$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{events}}$ $\frac{dN_{ch}}{d \eta}$',fontsize=12)
plt.legend(fontsize=7)

plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

#With Track pT cut:

#Number of raw jets in pp for 10M: 230138
#Number of raw jets in AuAu+nPDF for 100M (99,000,000 actually but close enough): 
#Number of raw jets in AuAu+nPDF for 10M: 632
#Number of sub jets in AuAu+hydro for 100k: 14736
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 

#Number of raw photons in pp for 10M: 457
#Number of raw photons in AuAu+nPDF for 10M: 6
#Number of sub photons in AuAu+hydro for 100k: 1916


#Without Track pT cut:

#Number of raw jets in pp for 10M: 254484
#Number of raw jets in AuAu+nPDF for 100M: 
#Number of raw jets in AuAu+nPDF for 10M: 650
#Number of sub jets in AuAu+hydro for 10k: 
#Number of sub jets in AuAu+hydro for 100k: 18335
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 18335  

#Number of raw photons in pp for 10M: 348825
#Number of raw photons in AuAu+nPDF for 10M: 855
#Number of sub photons in AuAu+hydro for 100k: 742368
#Number of random cone photons in AuAu hydro for 1k and AuAu+hydro for 100k:


jet_pp_jetscape_15_100_raw_jet_photon_pT, jet_pp_jetscape_15_100_raw_jet_photon_dNdpT = np.loadtxt('photon_JETSCAPE_pp_pTHat15_100_nohydro_10M_notrackpTcut_raw_jet_photon_pt_counts.txt').T
pp_photons_per_event = jet_pp_jetscape_15_100_raw_jet_photon_dNdpT/10000000
pp_photons_per_jet = jet_pp_jetscape_15_100_raw_jet_photon_dNdpT/230138
plt.plot(jet_pp_jetscape_15_100_raw_jet_photon_pT, pp_photons_per_jet, linestyle = '-', marker='.', color='red', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV pp raw dijets')

# jet_AuAu_nPDF_jetscape_15_100_raw_jet_photon_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_photon_dNdpT = np.loadtxt('photon_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut_raw_jet_pion_pt_counts.txt').T
# AuAu_nPDF_photons_per_event = jet_AuAu_nPDF_jetscape_15_100_raw_jet_photon_dNdpT/100000000
# AuAu_nPDF_photons_per_jet = jet_AuAu_nPDF_jetscape_15_100_raw_jet_photon_dNdpT/6506
# plt.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet_photon_pT, AuAu_nPDF_photons_per_jet, linestyle='-', marker='.', color='blue', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu+nPDF raw dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet_photon_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_photon_dNdpT = np.loadtxt('photon_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut03_sub_jet_photon_pt_counts.txt').T
AuAu_hydro_photons_per_event = jet_AuAu_hydro_jetscape_15_100_sub_jet_photon_dNdpT/100000
AuAu_hydro_photons_per_jet = jet_AuAu_hydro_jetscape_15_100_sub_jet_photon_dNdpT/14736
plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_photon_pT, AuAu_hydro_photons_per_jet, linestyle='-', marker='.', color='green', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu+hydro $p_{T}$ subtracted dijets')

# cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_photon_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_photon_dNdpT = np.loadtxt('photon_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_trackpTcut_cone_pt_counts_v4.txt').T
# cone_hydro_photons_per_event = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_photon_dNdpT/100000
# cone_hydro_photons_per_cone = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_photon_dNdpT/14736
# plt.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_photon_pT, cone_hydro_photons_per_cone, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_photon_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_photon_dNdpT = np.loadtxt('photon_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_trackpTcut_perp_cone_photon_pt_counts.txt').T
perp_cone_hydro_photons_per_event = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_photon_dNdpT/100000
perp_cone_hydro_photons_per_cone = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_photon_dNdpT/29472
plt.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_photon_pT, perp_cone_hydro_photons_per_cone, linestyle='-', marker='.', color='orange', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu perpendicular cones')


# plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, (AuAu_hydro_pions_per_event) - (cone_hydro_pions_per_event), linestyle='-', marker='.', color='black', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu+hydro - random cones')

plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,50)
plt.title(r'Dijet Charged Pion $p_{T}$ Spectra, $p_{T}^{trk}$>0.5GeV')
plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets/cones}}\frac{dN_{\pi}}{dp_{T}}$',fontsize=12)
plt.legend(fontsize=7)

plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

#With Track pT cut:

#Number of raw jets in pp for 10M: 201699
#Number of raw jets in AuAu+nPDF for 10M: 550
#Number of sub jets in AuAu+hydro for 100k: 14736
#Number of random cones in AuAu hydro for 1k with AuAu+hydro 100k jet info: 14736


jet_pp_jetscape_15_100_raw_jet_charged_hadron_pT, jet_pp_jetscape_15_100_raw_jet_charged_hadron_dNdpT = np.loadtxt('charged_hadron_JETSCAPE_pp_pTHat15_100_nohydro_10M_trackpTcut_raw_jet_charged_hadron_pt_counts.txt').T
pp_charged_hadron_per_event = jet_pp_jetscape_15_100_raw_jet_charged_hadron_dNdpT/10000000
pp_charged_hadron_per_jet = jet_pp_jetscape_15_100_raw_jet_charged_hadron_dNdpT/201699
plt.plot(jet_pp_jetscape_15_100_raw_jet_charged_hadron_pT, pp_charged_hadron_per_jet, linestyle = '-', marker='.', color='red', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV pp raw dijets')

# jet_pp_jetscape_15_100_raw_jet_nopTcut_pion_pT, jet_pp_jetscape_15_100_raw_jet_nopTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_pp_pTHat15_100_nohydro_10M_notrackpTcut_raw_jet_pion_pt_counts.txt').T
# plt.plot(jet_pp_jetscape_15_100_raw_jet_nopTcut_pion_pT, jet_pp_jetscape_15_100_raw_jet_nopTcut_pion_dNdpT/50, linestyle = '--', marker='.', color='red', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 pp dijets no pT cut')

jet_AuAu_nPDF_jetscape_15_100_raw_jet_charged_hadron_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_charged_hadron_dNdpT = np.loadtxt('charged_hadron_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_trackpTcut_raw_jet_charged_hadron_pt_counts.txt').T
AuAu_nPDF_charged_hadron_per_event = jet_AuAu_nPDF_jetscape_15_100_raw_jet_charged_hadron_dNdpT/10000000
AuAu_nPDF_charged_hadron_per_jet = jet_AuAu_nPDF_jetscape_15_100_raw_jet_charged_hadron_dNdpT/550
plt.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet_charged_hadron_pT, AuAu_nPDF_charged_hadron_per_jet, linestyle='-', marker='.', color='blue', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu+nPDF raw dijets')

# jet_AuAu_nPDF_jetscape_15_100_raw_jet_nopTcut_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_nopTcut_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_nohydro_10M_notrackpTcut_raw_jet_pion_pt_counts.txt').T
# plt.plot(jet_AuAu_nPDF_jetscape_15_100_raw_jet_nopTcut_pion_pT, jet_AuAu_nPDF_jetscape_15_100_raw_jet_nopTcut_dNdpT*10, linestyle='--', marker='.', color='blue', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu+nPDF dijets')

jet_AuAu_hydro_jetscape_15_100_sub_jet_charged_hadron_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_charged_hadron_dNdpT = np.loadtxt('charged_hadron_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_noconstsub_sub_jet_charged_hadron_pt_counts.txt').T
AuAu_hydro_charged_hadron_per_event = jet_AuAu_hydro_jetscape_15_100_sub_jet_charged_hadron_dNdpT/100000
AuAu_hydro_charged_hadron_per_jet = jet_AuAu_hydro_jetscape_15_100_sub_jet_charged_hadron_dNdpT/14736
plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_charged_hadron_pT, AuAu_hydro_charged_hadron_per_jet, linestyle='-', marker='.', color='green', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu+hydro $p_{T}$ subtr. dijets')

jet_AuAu_hydro_jetscape_15_100_constit_sub_jet_charged_hadron_pT, jet_AuAu_hydro_jetscape_15_100_constit_sub_jet_charged_hadron_dNdpT = np.loadtxt('charged_hadron_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut_sub_jet_charged_hadron_pt_counts.txt').T
AuAu_hydro_constit_charged_hadron_per_event = jet_AuAu_hydro_jetscape_15_100_constit_sub_jet_charged_hadron_dNdpT/100000
AuAu_hydro_constit_charged_hadron_per_jet = jet_AuAu_hydro_jetscape_15_100_constit_sub_jet_charged_hadron_dNdpT/14434
plt.plot(jet_AuAu_hydro_jetscape_15_100_constit_sub_jet_charged_hadron_pT, AuAu_hydro_constit_charged_hadron_per_jet, linestyle='-', marker='.', color='black', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu+hydro $p_{T}$ & constituent subtr. dijets')
# jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_notrackpTcut_sub_jet_pion_pt_counts.txt').T
# plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_dNdpT, linestyle='--', marker='.', color='green', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu+hydro dijets')

cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_charged_hadron_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_charged_hadron_dNdpT = np.loadtxt('charged_hadron_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_100k_trackpTcut05_cone_pt_counts_v3.txt').T
cone_hydro_charged_hadron_per_event = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_charged_hadron_dNdpT/100000
cone_hydro_charged_hadron_per_cone = cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_charged_hadron_dNdpT/14736
plt.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_pTcut_charged_hadron_pT, cone_hydro_charged_hadron_per_cone, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE AuAu random cones')

perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_charged_hadron_pT, perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_charged_hadron_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_trackpTcut_perp_cone_charged_hadron_pt_counts.txt').T
perp_cone_hydro_charged_hadron_per_event = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_charged_hadron_dNdpT/100000
perp_cone_hydro_charged_hadron_per_cone = perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_charged_hadron_dNdpT/29472
plt.plot(perp_cone_AuAu_hydro_jetscape_15_100_raw_cone_charged_hadron_pT, perp_cone_hydro_charged_hadron_per_cone, linestyle='-', marker='.', color='orange', label = 'JETSCAPE 20 < $p_{T}$ < 30 GeV AuAu perpendicular cones')


# cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro10_SMASH_only_decay_10k_notrackpTcut_cone_pt_counts_v3.txt').T
# plt.plot(cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_pT, cone_AuAu_hydro_jetscape_15_100_raw_cone_nopTcut_pion_dNdpT, linestyle='-', marker='.', color='magenta', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu random cones')

# plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_pion_pT, (AuAu_hydro_pions_per_event) - (cone_hydro_pions_per_event), linestyle='-', marker='.', color='black', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu+hydro - random cones')

plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,50)
plt.title(r'Dijet Charged Hadron $p_{T}$ Spectra, $p_{T}^{trk}$>0.5GeV')
plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets/cones}}\frac{dN}{dp_{T}}$',fontsize=12)
plt.legend(fontsize=7)

plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

#With Track pT cut:

#Number of raw jets in pp for 10M: 2300389
#Number of raw jets in AuAu+nPDF for 100M: 222927
#Number of sub jets in AuAu+hydro for 10k: 1522
#Number of sub jets in AuAu+hydro for 100k: 14736
#Number of random cones in AuAu hydro for 1k: 1522

#Number of raw pions in pp for 10M: 301347
#Number of raw pions in AuAu+nPDF for 100M: 
#Number of sub pions in AuAu+hydro for 100k: 267999


#Without Track pT cut:

#Number of raw jets in pp for 10M: 254484
#Number of raw jets in AuAu+nPDF for 100M: 
#Number of raw jets in AuAu+nPDF for 10M: 650
#Number of sub jets in AuAu+hydro for 10k: 
#Number of sub jets in AuAu+hydro for 100k: 18335
#Number of random cones in AuAu hydro for 1k:  

#Number of raw pions in pp for 10M: 348825
#Number of raw pions in AuAu+nPDF for 10M: 855
#Number of sub pions in AuAu+hydro for 100k: 742368



plt.plot(jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_pT, jet_AuAu_hydro_jetscape_15_100_sub_jet_nopTcut_pion_dNdpT - cone_AuAu_hydro_jetscape_15_100_raw_cone_pion_dNdpT, linestyle='-', marker='.', color='green', label = 'JETSCAPE $\hat{p_{T}}$ 15-100 AuAu+hydro dijets')



plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,50)
plt.title(r'Dijet $p_{T}$ Spectra, $p_{T}^{trk}$>0.5GeV')
plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
plt.ylabel(r'$\frac{dN_{\pi}}{dp_{T}}$',fontsize=12)
plt.legend(fontsize=7)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11.0,4.5))

pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_jet_pt_differences.txt').T
ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts, marker='.', linestyle='-', color='blue', label='AuAu Jets+Hydro')

# pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_nohydro_jet_pt_differences.txt').T
# ax2.plot(pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts, marker='.', linestyle='-', color='red', label='AuAu no hydro')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_AuAu_out_only_hydro10_iSS1_JETSCAPE_MUSIC_1_10k_jet_pt_differences.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE only hydro 10 (manual edits)')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_1, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts_1 = np.loadtxt('pion_AuAu_out_only_hydro10_iSS1_JETSCAPE_MUSIC_10k_jet_pt_differences.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_1, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts_1, marker='.', linestyle='-', color='red', label='AuAu XSCAPE only hydro 10')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_XSCAPE_AuAu_out_only_hydro100_iSS1_10k_jet_pt_differences.txt').T
# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_integral = np.trapz(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts,pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences)
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts/pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_integral, marker='.', linestyle='-', color='green', label='AuAu XSCAPE only hydro 100')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro10_iSS1_10k_jet_pt_differences.txt').T
# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_integral = np.trapz(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts,pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences)
# ax2.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_counts/pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_jet_pt_differences_integral, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE only hydro 100')

# pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts = np.loadtxt('pion_pp_pTHat15_100_out_alldecayoff_noprompt_jet_pt_differences.txt').T
# ax3.plot(pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_jet_pt_differences_counts, marker='.', linestyle='-', color='purple', label='pp')

ax1.set_yscale('log')
ax1.set_title('Jet $p_{T}$ Differences')
ax1.set_xlabel(r'$p_{T}^{raw} - p_{T}^{sub}$',fontsize=12)
ax1.set_ylabel(r'Counts',fontsize=12)
# ax1.set_ylim(0,1.5)
ax1.legend(fontsize=9)

# ax2.set_yscale('log')
ax2.set_title('Jet $p_{T}$ Differences')
ax2.set_xlabel(r'$p_{T}^{raw} - p_{T}^{sub}$',fontsize=12)
ax2.set_ylabel(r'$\frac{dN}{d(p_{T}^{raw} - p_{T}^{sub})}$',fontsize=12)
# ax2.set_ylim(0,1.5)
ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Jet $p_{T}$ Differences')
# ax3.set_xlabel(r'$p_{T}^{raw} - p_{T}^{sub}$',fontsize=12)
# ax3.set_ylabel(r'Counts',fontsize=12)
# # ax3.set_ylim(0,1.5)
# ax3.legend(fontsize=9)

plt.tight_layout()

# plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,1)
# plt.title(r'Particles in Jets vs Particles in Event')
# plt.xlabel(r'Particles in Jets',fontsize=12)
# plt.ylabel(r'Particles in Event',fontsize=12)
# plt.legend(fontsize=9)

plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
import math

# fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11.0,4.5))

existing_pionplus_Au_phenix_centr0_5_particle_pt, existing_pionplus_Au_phenix_centr0_5_particle_pt_counts, existing_pionplus_Au_phenix_centr0_5_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr0_5 PHENIX.txt').T
# ax1.errorbar(existing_pionplus_Au_phenix_centr0_5_particle_pt, existing_pionplus_Au_phenix_centr0_5_particle_pt_counts*20, yerr=existing_pionplus_Au_phenix_centr0_5_particle_pt_counts_err, fmt='o', mfc='white', linestyle='-', color='red',  capsize=5, label='PHENIX 0-5% * 20')

existing_pionplus_Au_phenix_centr5_10_particle_pt, existing_pionplus_Au_phenix_centr5_10_particle_pt_counts, existing_pionplus_Au_phenix_centr5_10_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr5_10 PHENIX.txt').T
# ax1.errorbar(existing_pionplus_Au_phenix_centr5_10_particle_pt, existing_pionplus_Au_phenix_centr5_10_particle_pt_counts*10, yerr=existing_pionplus_Au_phenix_centr5_10_particle_pt_counts_err, fmt='o', linestyle='--', color='red',  capsize=5, label='PHENIX 5-10% * 10')

existing_pionplus_Au_phenix_centr0_10_particle_pt_counts = (existing_pionplus_Au_phenix_centr0_5_particle_pt_counts + existing_pionplus_Au_phenix_centr5_10_particle_pt_counts)/2
plt.errorbar(existing_pionplus_Au_phenix_centr5_10_particle_pt, existing_pionplus_Au_phenix_centr0_10_particle_pt_counts*15, yerr=existing_pionplus_Au_phenix_centr5_10_particle_pt_counts_err, fmt='o', linestyle='--', color='red',  capsize=5, label='PHENIX 0-10% * 15')

existing_pionplus_Au_phenix_centr10_15_particle_pt, existing_pionplus_Au_phenix_centr10_15_particle_pt_counts, existing_pionplus_Au_phenix_centr10_15_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr10_15 PHENIX.txt').T
# ax1.errorbar(existing_pionplus_Au_phenix_centr10_15_particle_pt, existing_pionplus_Au_phenix_centr10_15_particle_pt_counts*5, yerr=existing_pionplus_Au_phenix_centr10_15_particle_pt_counts_err, fmt='o', mfc='white', linestyle='-', color='green',  capsize=5, label='PHENIX 10-15% * 5')

existing_pionplus_Au_phenix_centr15_20_particle_pt, existing_pionplus_Au_phenix_centr15_20_particle_pt_counts, existing_pionplus_Au_phenix_centr15_20_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr15_20 PHENIX.txt').T
# ax1.errorbar(existing_pionplus_Au_phenix_centr15_20_particle_pt, existing_pionplus_Au_phenix_centr15_20_particle_pt_counts*2.5, yerr=existing_pionplus_Au_phenix_centr15_20_particle_pt_counts_err, fmt='o', linestyle='--', color='green',  capsize=5, label='PHENIX 15-20% * 2.5')

existing_pionplus_Au_phenix_centr10_20_particle_pt_counts = (existing_pionplus_Au_phenix_centr10_15_particle_pt_counts + existing_pionplus_Au_phenix_centr15_20_particle_pt_counts)/2
plt.errorbar(existing_pionplus_Au_phenix_centr5_10_particle_pt, existing_pionplus_Au_phenix_centr10_20_particle_pt_counts*7.5, yerr=existing_pionplus_Au_phenix_centr15_20_particle_pt_counts_err, fmt='o', linestyle='--', color='green',  capsize=5, label='PHENIX 10-20% * 7.5')

existing_pionplus_Au_phenix_centr20_30_particle_pt, existing_pionplus_Au_phenix_centr20_30_particle_pt_counts, existing_pionplus_Au_phenix_centr20_30_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr20_30 PHENIX.txt').T
plt.errorbar(existing_pionplus_Au_phenix_centr20_30_particle_pt, existing_pionplus_Au_phenix_centr20_30_particle_pt_counts*1.5, yerr=existing_pionplus_Au_phenix_centr20_30_particle_pt_counts_err, fmt='o', mfc='white', linestyle='-', color='blue',  capsize=5, label='PHENIX 20-30% * 1.5')

existing_pionplus_Au_phenix_centr30_40_particle_pt, existing_pionplus_Au_phenix_centr30_40_particle_pt_counts, existing_pionplus_Au_phenix_centr30_40_particle_pt_counts_err = np.loadtxt('Existing AuAu PionPlus Data for Invariant Yield Centr30_40 PHENIX.txt').T
plt.errorbar(existing_pionplus_Au_phenix_centr30_40_particle_pt, existing_pionplus_Au_phenix_centr30_40_particle_pt_counts, yerr=existing_pionplus_Au_phenix_centr30_40_particle_pt_counts_err, fmt='o', mfc='white', linestyle='-', color='cyan',  capsize=5, label='PHENIX 30-40%')

pion_Au_soft_hydro_jetscape_centr0_10_particle_pt, pion_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts, pion_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts_err = np.loadtxt('pion_JETSCAPE_AuAu_soft_sector_only_hydro_centr0_10_10_events_SMASH_only_decay_pt_counts.txt').T
plt.errorbar(pion_Au_soft_hydro_jetscape_centr0_10_particle_pt, (1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr0_10_particle_pt))*(pion_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts*15)/1000, yerr=(1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr0_10_particle_pt))*pion_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts_err, linestyle='--', color='red', label='0-10% * 15')

pion_Au_soft_hydro_jetscape_centr10_20_particle_pt, pion_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts, pion_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts_err = np.loadtxt('pion_JETSCAPE_AuAu_soft_sector_only_hydro_centr10_20_10_events_SMASH_only_decay_pt_counts.txt').T
plt.errorbar(pion_Au_soft_hydro_jetscape_centr10_20_particle_pt, (1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr10_20_particle_pt))*(pion_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts*7.5)/1000, yerr=(1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr10_20_particle_pt))*pion_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts_err, linestyle='--', color='green', label='10-20% * 7.5')

pion_Au_soft_hydro_jetscape_centr20_30_particle_pt, pion_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts, pion_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts_err = np.loadtxt('pion_JETSCAPE_AuAu_soft_sector_only_hydro_centr20_30_10_events_SMASH_only_decay_pt_counts.txt').T
plt.errorbar(pion_Au_soft_hydro_jetscape_centr20_30_particle_pt, (1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr20_30_particle_pt))*(pion_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts*1.5)/1000, yerr=(1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr20_30_particle_pt))*pion_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts_err, linestyle='--', color='blue', label='20-30% * 1.5')

pion_Au_soft_hydro_jetscape_centr30_40_particle_pt, pion_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts, pion_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts_err = np.loadtxt('pion_JETSCAPE_AuAu_soft_sector_only_hydro_centr30_40_10_events_SMASH_only_decay_pt_counts.txt').T
plt.errorbar(pion_Au_soft_hydro_jetscape_centr30_40_particle_pt, (1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr30_40_particle_pt))*pion_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts/1000, yerr=(1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr30_40_particle_pt))*pion_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts_err, linestyle='--', color='cyan', label='30-40%')


# particle_Au_soft_hydro_jetscape_centr0_10_particle_pt, particle_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts, particle_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts_err = np.loadtxt('particle_JETSCAPE_AuAu_soft_sector_only_hydro_centr0_10_10_events_pt_counts.txt').T
# ax2.errorbar(particle_Au_soft_hydro_jetscape_centr0_10_particle_pt, particle_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts/10, yerr=particle_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts_err, fmt='.', linestyle='-', color='red', capsize=5, label='0-10%')

# particle_Au_soft_hydro_jetscape_centr10_20_particle_pt, particle_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts, particle_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts_err = np.loadtxt('particle_JETSCAPE_AuAu_soft_sector_only_hydro_centr10_20_10_events_pt_counts.txt').T
# ax2.errorbar(particle_Au_soft_hydro_jetscape_centr10_20_particle_pt, particle_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts/10, yerr=particle_Au_soft_hydro_jetscape_centr10_20_particle_pt_counts_err, fmt='.', linestyle='-', color='green', capsize=5, label='10-20%')

# particle_Au_soft_hydro_jetscape_centr20_30_particle_pt, particle_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts, particle_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts_err = np.loadtxt('particle_JETSCAPE_AuAu_soft_sector_only_hydro_centr20_30_10_events_pt_counts.txt').T
# ax2.errorbar(particle_Au_soft_hydro_jetscape_centr20_30_particle_pt, particle_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts/10, yerr=particle_Au_soft_hydro_jetscape_centr20_30_particle_pt_counts_err, fmt='.', linestyle='-', color='blue', capsize=5, label='20-30%')

# particle_Au_soft_hydro_jetscape_centr30_40_particle_pt, particle_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts, particle_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts_err = np.loadtxt('particle_JETSCAPE_AuAu_soft_sector_only_hydro_centr30_40_10_events_pt_counts.txt').T
# ax2.errorbar(particle_Au_soft_hydro_jetscape_centr30_40_particle_pt, particle_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts/10, yerr=particle_Au_soft_hydro_jetscape_centr30_40_particle_pt_counts_err, fmt='.', linestyle='-', color='cyan', capsize=5, label='30-40%')

# print(*((1/(8*math.pi*pion_Au_soft_hydro_jetscape_centr0_10_particle_pt))*pion_Au_soft_hydro_jetscape_centr0_10_particle_pt_counts/1000))

plt.yscale('log')
plt.title('Transverse Momentum Distribution of Pions (SMASH only decay)')
plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
plt.ylabel(r'$\frac{1}{2 \pi p_{T} N_{evt}}\frac{d^{2}N}{dydp_{T}}$ $(1/GeV^{2})$',fontsize=12)
plt.ylim(1e-4,1e5)
plt.xlim(0,3)
plt.legend(fontsize=7)

# ax2.set_yscale('log')
# ax2.set_title('Particle $p_{T}$')
# ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# ax2.set_ylabel(r'Counts',fontsize=12)
# ax2.set_ylim(1e-2,1e6)
# ax2.set_xlim(0,7)
# ax2.legend(fontsize=7)

plt.tight_layout()
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
import math

# fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10.0,4.5))

charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_200MeV_EEC_deltaR, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_200MeV_EEC, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_200MeV_EEC_paircounts  = np.loadtxt('charged_particle_pp_pTHat15_100_deltaR_EEC_R08_trackpTcut200MeV_analysis.txt').T
# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
plt.errorbar(charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_200MeV_EEC_deltaR, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_200MeV_EEC, yerr=0.0001, marker='.', linestyle='-', color='blue', label=r'pp jets $p_{T}^{trk}$ > 0.2 GeV')

charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_1GeV_EEC_deltaR, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_1GeV_EEC, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_1GeV_EEC_paircounts= np.loadtxt('charged_particle_pp_pTHat15_100_deltaR_EEC_R08_trackpTcut1GeV_analysis.txt').T
# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
plt.errorbar(charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_1GeV_EEC_deltaR, charged_particle_pp_jetscape_15_100_noprompt_R08_raw_trackpTcut_1GeV_EEC, yerr = 0.0001, marker='.', linestyle='-', color='red', label=r'pp jets $p_{T}^{trk}$ > 1 GeV')

# charged_particle_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_raw_jet_pt_counts.txt').T
# # pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
# ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts, marker='.', linestyle='-', color='blue', label='AuAu JETSCAPE hydro raw jets')

# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_sub_jet_pt_counts.txt').T
# # pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('sub_jet_pt_counts.txt').T
# ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts, marker='.', linestyle='-', color='red', label='AuAu JETSCAPE hydro subtracted jets')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt_counts, marker='.', linestyle='-', color='green', label='AuAu only hydro raw jets')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('sub_jet_pt_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt_counts, marker='.', linestyle='-', color='purple', label='AuAu only hydro subtracted jets')

# plt.yscale('log')
plt.title(r'EEC for Jets at $\sqrt{s_{NN}} = 200$ GeV')
plt.xlabel(r'$\Delta R$',fontsize=12)
plt.ylabel(r'$EEC = \frac{p_{T,1} \cdot p_{T,2}}{p_{T,jet}}$',fontsize=12)
# ax1.set_ylim(0,11)
# ax1.set_xlim(0,11)
plt.legend(fontsize=9)

# ax2.set_yscale('log')
# ax2.set_title('AuAu Only Hydro $p_{T}$ Spectra')
# ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# ax2.set_ylabel(r'Counts',fontsize=12)
# # ax2.set_ylim(0,1.5)
# ax2.set_xlim(0,105)
# ax2.legend(fontsize=9)

plt.tight_layout()

# plt.yscale('log')
# # plt.ylim(1e-4,1e1)
# # plt.xlim(0,1)
# plt.title('Jet $p_{T}$ Spectra ($p_{T} > 10$)')
# plt.xlabel(r'$p_{T}$',fontsize=12)
# plt.ylabel(r'Counts',fontsize=12)
# plt.legend(fontsize=9)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10.0,4.5))

pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_raw_jet_pt_counts.txt').T
# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_raw_jet_pt_counts, marker='.', linestyle='-', color='blue', label='AuAu JETSCAPE hydro raw jets')

pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_sub_jet_pt_counts.txt').T
# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('sub_jet_pt_counts.txt').T
ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_sub_jet_pt_counts, marker='.', linestyle='-', color='red', label='AuAu JETSCAPE hydro subtracted jets')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt_counts = np.loadtxt('raw_jet_pt_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_raw_jet_pt_counts, marker='.', linestyle='-', color='green', label='AuAu only hydro raw jets')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt_counts = np.loadtxt('sub_jet_pt_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_sub_jet_pt_counts, marker='.', linestyle='-', color='purple', label='AuAu only hydro subtracted jets')

ax1.set_yscale('log')
ax1.set_title('AuAu Hydro + Jets $p_{T}$ Spectra')
ax1.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax1.set_ylabel(r'Counts',fontsize=12)
# ax1.set_ylim(0,11)
# ax1.set_xlim(0,11)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title('AuAu Only Hydro $p_{T}$ Spectra')
ax2.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
ax2.set_ylabel(r'Counts',fontsize=12)
# ax2.set_ylim(0,1.5)
ax2.set_xlim(0,105)
ax2.legend(fontsize=9)

plt.tight_layout()

# plt.yscale('log')
# # plt.ylim(1e-4,1e1)
# # plt.xlim(0,1)
# plt.title('Jet $p_{T}$ Spectra ($p_{T} > 10$)')
# plt.xlabel(r'$p_{T}$',fontsize=12)
# plt.ylabel(r'Counts',fontsize=12)
# plt.legend(fontsize=9)

plt.show()

# %%
# fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(10.0,4.5))

# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_hydro_iSS_particles_in_event_and_jets.txt').T
# ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event, marker='.', linestyle='-', color='blue', label='AuAu hydro')

# pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_nohydro_particles_in_event_and_jets.txt').T
# ax2.plot(pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event, marker='.', linestyle='-', color='red', label='AuAu no hydro')

# pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event = np.loadtxt('pion_pp_pTHat15_100_out_alldecayoff_noprompt_particles_in_event_and_jets.txt').T
# ax2.plot(pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_jet, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_particles_in_event, marker='.', linestyle='-', color='red', label='pp')

# # ax1.set_yscale('log')
# ax1.set_title('Particles in Jets vs Particles in Event')
# ax1.set_xlabel(r'Particles in Jets',fontsize=12)
# ax1.set_ylabel(r'Particles in Event',fontsize=12)
# # ax1.set_ylim(1e-3,1e1)
# ax1.legend(fontsize=9)

# # ax2.set_yscale('log')
# ax2.set_title('Particles in Jets vs Particles in Event')
# ax2.set_xlabel(r'Particles in Jets',fontsize=12)
# ax2.set_ylabel(r'Particles in Event',fontsize=12)
# # ax1.set_ylim(1e-3,1e1)
# ax2.legend(fontsize=9)

# # ax2.set_yscale('log')
# ax3.set_title('Particles in Jets vs Particles in Event')
# ax3.set_xlabel(r'Particles in Jets',fontsize=12)
# ax3.set_ylabel(r'Particles in Event',fontsize=12)
# # ax1.set_ylim(1e-3,1e1)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# # plt.yscale('log')
# # plt.ylim(1e-4,1e1)
# # plt.xlim(0,1)
# # plt.title(r'Particles in Jets vs Particles in Event')
# # plt.xlabel(r'Particles in Jets',fontsize=12)
# # plt.ylabel(r'Particles in Event',fontsize=12)
# # plt.legend(fontsize=9)

# plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11.0,4.5))

pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_JETSCAPE_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_background_density_area_counts.txt').T
ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='blue', label='AuAu Jets+Hydro')

# pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_nohydro_background_density_counts.txt').T
# ax2.plot(pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='red', label='AuAu no hydro')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_AuAu_out_only_hydro100_iSS1_10k_background_density_area_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE only hydro')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_XSCAPE_AuAu_out_only_hydro100_iSS1_10k_XSCAPE_MUSIC_background_density_counts.txt').T
# # pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_integral = np.trapz(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts,pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density)
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE only hydro 100')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_1, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts_1 = np.loadtxt('pion_AuAu_out_only_hydro10_iSS1_JETSCAPE_MUSIC_1_10k_background_density_area_counts.txt').T
# ax2.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_1, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts_1, marker='.', linestyle='-', color='red', label='AuAu XSCAPE only hydro JETSCAPE MUSIC 10 (manual edits)')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro100_iSS1_10k_background_density_counts.txt').T
# # pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_integral = np.trapz(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts,pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density)
# ax2.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE only hydro 100')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro10_iSS1_10k_background_density_area_counts.txt').T
# ax3.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE only hydro')

# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_AuAu_out_only_hydro10_iSS_10k_background_density_area_counts.txt').T
# ax3.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE only hydro')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro10_iSS1_10k_background_density_area_counts.txt').T
# ax3.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE only hydro')

# pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_pp_pTHat15_100_out_alldecayoff_noprompt_background_density_counts.txt').T
# ax3.plot(pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='purple', label='pp')

# ax1.set_yscale('log')
ax1.set_title('Background Density Counts')
ax1.set_xlabel(r'$\rho$',fontsize=12)
ax1.set_ylabel(r'Counts',fontsize=12)
# ax1.set_ylim(0,1.5)
ax1.legend(fontsize=9)

# ax2.set_yscale('log')
ax2.set_title('Background Density Counts')
ax2.set_xlabel(r'$\rho$',fontsize=12)
ax2.set_ylabel(r'$N$',fontsize=12)
# ax2.set_ylim(0,1.5)
ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Background Density Counts')
# ax3.set_xlabel(r'$\rho \times A$',fontsize=12)
# ax3.set_ylabel(r'Counts',fontsize=12)
# # ax3.set_ylim(0,1.5)
# ax3.legend(fontsize=9)

plt.tight_layout()

# plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,1)
# plt.title(r'Particles in Jets vs Particles in Event')
# plt.xlabel(r'Particles in Jets',fontsize=12)
# plt.ylabel(r'Particles in Event',fontsize=12)
# plt.legend(fontsize=9)

plt.show()

# %%
# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts = np.loadtxt('pion_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt').T
# plt.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE 100 hydro events')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt').T
# plt.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE 100 hydro events')

# Load data
# data = np.loadtxt('pion_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt', delimiter=',', skiprows=1)
# rhoA = data[:, 0]  # rho * A
# num_particles = data[:, 1]  # Number of particles
# event_index = data[:, 2]  # Event index

# # Create a 2D scatter plot
# plt.figure(figsize=(9, 5.5))
# scatter = plt.scatter(event_index, rhoA, c=num_particles, cmap='viridis', s=20)

# # Add colorbar
# cbar = plt.colorbar(scatter)
# cbar.set_label('Event Index')

# # Set labels and title
# plt.ylabel(r'$\rho \times A$')
# plt.xlabel('Number of Particles')
# plt.title(r'2D Correlation Plot of $\rho \times A$ vs Number of Particles')

# # Show the plot
# plt.show()
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# Load data
data = np.loadtxt('particle_AuAu_pTHat15_100_hard_soft_hydro100_centr0_10_1k_rho_particle_counts.txt', delimiter=',', skiprows=1)
rhoA = data[:, 0]  # rho * A
num_particles = data[:, 1]  # Number of particles
event_index = data[:, 2]  # Event index (not used for counting)

# Create a 2D histogram to count events
heatmap, xedges, yedges = np.histogram2d(rhoA, num_particles, bins=50)
heatmap += 1  # Add 1 to avoid log(0)

# Create a heatmap using logarithmic scale for the color
plt.figure(figsize=(8, 5))
c = plt.pcolormesh(xedges, yedges, heatmap.T, shading='auto', norm=LogNorm(), cmap='viridis')

# Add a colorbar
cbar = plt.colorbar(c)
cbar.set_label('Number of Events (Log Scale)')

# Set labels and title
# plt.yscale('log')
plt.xlabel(r'$\rho$')
plt.ylabel('Number of Particles')
plt.title(r'2D Correlation of XSCAPE $\rho$ vs Number of Particles per Event')

# Show the plot
plt.show()

# ax1.set_yscale('log')
# ax1.set_title('Background Density Counts')
# ax1.set_xlabel(r'$\rho \times A$',fontsize=12)
# ax1.set_ylabel(r'Counts',fontsize=12)
# # ax1.set_ylim(0,1.5)
# ax1.legend(fontsize=9)

# # ax2.set_yscale('log')
# ax2.set_title('Background Density Counts')
# ax2.set_xlabel(r'$\rho$',fontsize=12)
# ax2.set_ylabel(r'Counts',fontsize=12)
# # ax2.set_ylim(0,1.5)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Pion $p_{T}$ Spectra')
# ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# ax3.set_ylabel(r'$N_{\pi}$',fontsize=12)
# # ax3.set_ylim(0,1.5)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,1)
# plt.title(r'Particles per Event vs $\rho \times A$')
# plt.xlabel(r'$\rho \times A$',fontsize=12)
# plt.ylabel(r'Particles per Event',fontsize=12)
# plt.legend(fontsize=9)

# plt.show()

# %%
# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts = np.loadtxt('pion_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt').T
# plt.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts, marker='.', linestyle='-', color='green', label='AuAu XSCAPE 100 hydro events')

# pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt').T
# plt.plot(pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_rhoA, pion_Au_jetscape_onlyhydro_xscape_deltaRcut_constituentcut_particle_counts, marker='.', linestyle='-', color='purple', label='AuAu JETSCAPE 100 hydro events')

# Load data
# data = np.loadtxt('pion_AuAu_out_only_hydro100_iSS1_10k_rhoA_particle_counts.txt', delimiter=',', skiprows=1)
# rhoA = data[:, 0]  # rho * A
# num_particles = data[:, 1]  # Number of particles
# event_index = data[:, 2]  # Event index

# # Create a 2D scatter plot
# plt.figure(figsize=(9, 5.5))
# scatter = plt.scatter(event_index, rhoA, c=num_particles, cmap='viridis', s=20)

# # Add colorbar
# cbar = plt.colorbar(scatter)
# cbar.set_label('Event Index')

# # Set labels and title
# plt.ylabel(r'$\rho \times A$')
# plt.xlabel('Number of Particles')
# plt.title(r'2D Correlation Plot of $\rho \times A$ vs Number of Particles')

# # Show the plot
# plt.show()
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# Load data
data = np.loadtxt('pion_JETSCAPE_AuAu_out_only_hydro100_iSS1_10k_rho_particle_counts.txt', delimiter=',', skiprows=1)
rhoA = data[:, 0]  # rho * A
num_particles = data[:, 1]  # Number of particles
event_index = data[:, 2]  # Event index (not used for counting)

# Create a 2D histogram to count events
heatmap, xedges, yedges = np.histogram2d(rhoA, num_particles, bins=50)
heatmap += 1  # Add 1 to avoid log(0)

# Create a heatmap using logarithmic scale for the color
plt.figure(figsize=(8, 5))
c = plt.pcolormesh(xedges, yedges, heatmap.T, shading='auto', norm=LogNorm(), cmap='viridis')

# Add a colorbar
cbar = plt.colorbar(c)
cbar.set_label('Number of Events (Log Scale)')

# Set labels and title
# plt.yscale('log')
plt.xlabel(r'$\rho$')
plt.ylabel('Number of Particles')
plt.title(r'2D Correlation of JETSCAPE $\rho$ vs Number of Particles per Event')

# Show the plot
plt.show()

# ax1.set_yscale('log')
# ax1.set_title('Background Density Counts')
# ax1.set_xlabel(r'$\rho \times A$',fontsize=12)
# ax1.set_ylabel(r'Counts',fontsize=12)
# # ax1.set_ylim(0,1.5)
# ax1.legend(fontsize=9)

# # ax2.set_yscale('log')
# ax2.set_title('Background Density Counts')
# ax2.set_xlabel(r'$\rho$',fontsize=12)
# ax2.set_ylabel(r'Counts',fontsize=12)
# # ax2.set_ylim(0,1.5)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Pion $p_{T}$ Spectra')
# ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# ax3.set_ylabel(r'$N_{\pi}$',fontsize=12)
# # ax3.set_ylim(0,1.5)
# ax3.legend(fontsize=9)

# plt.tight_layout()

# plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,1)
# plt.title(r'Particles per Event vs $\rho \times A$')
# plt.xlabel(r'$\rho \times A$',fontsize=12)
# plt.ylabel(r'Particles per Event',fontsize=12)
# plt.legend(fontsize=9)

# plt.show()

# %%
# fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(10.0,4.5))

# pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_hydro10_iSS_100k_background_density_area_counts.txt').T
# ax1.plot(pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_hydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='blue', label='AuAu hydro')

# pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_nohydro_background_density_counts.txt').T
# ax2.plot(pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density/10, pion_Au_nohydro_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='red', label='AuAu no hydro')

# particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts = np.loadtxt('particle_AuAu_pTHat15_100_out_alldecayoff_noprompt_hydro10_iSS10_10k_pt_counts.txt').T
# particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts = np.loadtxt('particle_pt_counts.txt').T
# plt.plot(particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, particle_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts, marker='.', linestyle='-', color='blue', label='AuAu hydro + jets all particles')

pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts = np.loadtxt('pion_AuAu_pTHat15_100_out_alldecayoff_noprompt_hydro10_iSS10_10k_pt_counts.txt').T
# pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts = np.loadtxt('pion_pt_counts.txt').T
plt.plot(pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT, pion_Au_onlyhydro_xscape_deltaRcut_constituentcut_pion_pT_counts, marker='.', linestyle='-', color='green', label='AuAu hydro + jets pions')

# pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts = np.loadtxt('pion_pp_pTHat15_100_out_alldecayoff_noprompt_background_density_counts.txt').T
# ax3.plot(pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density, pion_pp_xscape_15_100_noprompt_deltaRcut_constituentcut_background_density_counts, marker='.', linestyle='-', color='purple', label='pp')

# ax1.set_yscale('log')
# ax1.set_title('Background Density Counts')
# ax1.set_xlabel(r'$\rho \times A$',fontsize=12)
# ax1.set_ylabel(r'Counts',fontsize=12)
# # ax1.set_ylim(0,1.5)
# ax1.legend(fontsize=9)

# # ax2.set_yscale('log')
# ax2.set_title('Background Density Counts')
# ax2.set_xlabel(r'$\rho$',fontsize=12)
# ax2.set_ylabel(r'Counts',fontsize=12)
# # ax2.set_ylim(0,1.5)
# ax2.legend(fontsize=9)

# ax3.set_yscale('log')
# ax3.set_title('Pion $p_{T}$ Spectra')
# ax3.set_xlabel(r'$p_{T}$ (GeV)',fontsize=12)
# ax3.set_ylabel(r'$N_{\pi}$',fontsize=12)
# # ax3.set_ylim(0,1.5)
# ax3.legend(fontsize=9)

# plt.tight_layout()

plt.yscale('log')
# plt.ylim(1e-4,1e1)
# plt.xlim(0,1)
plt.title(r'Particle $p_{T}$ Spectra')
plt.xlabel(r'$p_{T}$ (GeV)',fontsize=12)
plt.ylabel(r'N (Counts)',fontsize=12)
plt.legend(fontsize=9)

plt.show()

# %% [markdown]
# ### PTHat 15-40 GeV Pions Momentum Fraction and Delta R

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 pion / jet momentum fraction, jet pT 10-20 GeV
pion_jet_xscape_15_40_smeared_jetpt_10_20_z, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_frag_func_alldecayoff_noprompt_jetpt10_20_1M_smearedpionjet.txt').T
# plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_10_20_z, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, yerr = pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 pion / jet momentum fraction, jet pT 20-30 GeV
pion_jet_xscape_15_40_smeared_jetpt_20_30_z, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_frag_func_alldecayoff_noprompt_jetpt20_30_1M_smearedpionjet.txt').T
# plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_20_30_z, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title('Momentum Fraction of Pions in Jets (anti-$k_{T}$, R=0.4, Gaussian smearing)')
# plt.xlabel(r'$z = \frac{p_{T}^{\pi}}{p_{T}^{jets}}$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 pion / jet momentum fraction, jet pT 10-20 GeV
pion_jet_xscape_15_40_smeared_jetpt_10_20_deltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_deltaR_alldecayoff_noprompt_jetpt10_20_1M_smearedpionjet.txt').T
# plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_10_20_deltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR, yerr = pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 pion / jet momentum fraction, jet pT 20-30 GeV
pion_jet_xscape_15_40_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_deltaR_alldecayoff_noprompt_jetpt20_30_1M_smearedpionjet.txt').T
# plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR, yerr = pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Pions in Jets (anti-$k_{T}$, R=0.4, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
# plt.show()
