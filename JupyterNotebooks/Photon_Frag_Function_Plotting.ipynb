# %% [markdown]
# ## Plotting of Momentum Fraction of Photons in Jets (Fragmentation Photons)

# %% [markdown]
# Momentum fraction of photons from jets (no cut on jets, pTHat 5-15 and 15-30, prompt photons enabled, and all hadron decay disabled)

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 photon / jet momentum fraction
photon_jet_xscape_5_15_z, photon_jet_xscape_5_15_dNdz, photon_jet_xscape_5_15_dNdz_err = np.loadtxt('photon_pp_pTHat5_15_photon_jet_frag_funct_1M.txt').T
plt.errorbar(photon_jet_xscape_5_15_z, photon_jet_xscape_5_15_dNdz, yerr = photon_jet_xscape_5_15_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-15 $\gamma$')

# XSCAPE pTHat 15-30 photon / jet momentum fraction
photon_jet_xscape_15_30_z, photon_jet_xscape_15_30_dNdz, photon_jet_xscape_15_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_30_photon_jet_frag_funct_1M.txt').T
plt.errorbar(photon_jet_xscape_15_30_z, photon_jet_xscape_15_30_dNdz, yerr = photon_jet_xscape_15_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-30 $\gamma$')


# plt.ylim(1e-11,1e-3)
# plt.xlim(4,21)
plt.yscale('log')

plt.title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, R=0.4)')
plt.xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 photon / jet momentum fraction
photon_jet_xscape_5_15_z, photon_jet_xscape_5_15_dNdz, photon_jet_xscape_5_15_dNdz_err = np.loadtxt('photon_pp_pTHat5_15_photon_jet_frag_funct_1M.txt').T
plt.errorbar(np.log(1/photon_jet_xscape_5_15_z), photon_jet_xscape_5_15_dNdz, yerr = photon_jet_xscape_5_15_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-15 $\gamma$')

# XSCAPE pTHat 15-30 photon / jet momentum fraction
photon_jet_xscape_15_30_z, photon_jet_xscape_15_30_dNdz, photon_jet_xscape_15_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_30_photon_jet_frag_funct_1M.txt').T
plt.errorbar(np.log(1/photon_jet_xscape_15_30_z), photon_jet_xscape_15_30_dNdz, yerr = photon_jet_xscape_15_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-30 $\gamma$')


# plt.ylim(1e-11,1e-3)
# plt.xlim(4,21)
# plt.yscale('log')

plt.title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, R=0.4)')
plt.xlabel(r'$\xi = Ln(\frac{1}{z})$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# Momentum fraction of photons from jets (jet pT cut between 10-20 GeV, pTHat 15-40, prompt photons and all hadron decay disabled)

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 photon / jet momentum fraction, jet pT 10-20 GeV
photon_jet_xscape_15_40_jetpt_10_20_z, photon_jet_xscape_15_40_jetpt_10_20_dNdz, photon_jet_xscape_15_40_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_jetpt10_20_1M.txt').T
plt.errorbar(photon_jet_xscape_15_40_jetpt_10_20_z, photon_jet_xscape_15_40_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_jetpt_10_20_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV
photon_jet_xscape_15_40_jetpt_20_30_z, photon_jet_xscape_15_40_jetpt_20_30_dNdz, photon_jet_xscape_15_40_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_jetpt20_30_1M.txt').T
plt.errorbar(photon_jet_xscape_15_40_jetpt_20_30_z, photon_jet_xscape_15_40_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
plt.yscale('log')

plt.title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, R=0.4)')
plt.xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 photon / jet momentum fraction, jet pT 10-20 GeV
photon_jet_xscape_15_40_jetpt_10_20_deltaR, photon_jet_xscape_15_40_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_jetpt10_20_1M.txt').T
plt.errorbar(photon_jet_xscape_15_40_jetpt_10_20_deltaR, photon_jet_xscape_15_40_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_jetpt_10_20_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV
photon_jet_xscape_15_40_jetpt_20_30_deltaR, photon_jet_xscape_15_40_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_jetpt20_30_1M.txt').T
plt.errorbar(photon_jet_xscape_15_40_jetpt_20_30_deltaR, photon_jet_xscape_15_40_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_jetpt_20_30_dNddeltaR_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
plt.yscale('log')

plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, R=0.4)')
plt.xlabel(r'$\Delta R$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %% [markdown]
# Momentum fraction of photons from jets (jet pT cut between 10-20 GeV, pTHat 15-40, prompt photons and all hadron decay disabled), smeared jet pT by Gaussian of resolution 15%

# %%
import numpy  as np
import matplotlib.pyplot as plt


# XSCAPE pTHat 5-15 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_jetpt10_20_1M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_15_40_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ no prompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_jetpt20_30_1M_smearedphotonjet.txt').T
plt.errorbar(photon_jet_xscape_15_40_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$ no prompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
# plt.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ prompt')

# # XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
# photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
# plt.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$ prompt')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
plt.yscale('log')

plt.title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, R=0.4, Gaussian smearing)')
plt.xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.5,14.5))

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# XSCAPE pTHat 15-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')

# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

ax3.set_yscale('log')
ax3.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax3.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax3.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6.5,14.5))

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# XSCAPE pTHat 15-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_15_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')


# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax1.set_xlabel(r'$\Delta R$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax2.set_xlabel(r'$\Delta R$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

ax3.set_yscale('log')
ax3.set_title(r'$\Delta R$ of Photons in 30-40 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax3.set_xlabel(r'$\Delta R$',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax3.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %% [markdown]
# ### PTHat 30-40 GeV Photon Momentum Fraction and Delta R

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6,14))

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# XSCAPE pTHat 30-40 photon / jet momentum fraction, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_z, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')

# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

ax3.set_yscale('log')
ax3.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax3.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax3.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(6,14))

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt const>1')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, noprompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_10M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_10M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# XSCAPE pTHat 30-40 photon-jet deltaR, jet pT 30-40 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err = np.loadtxt('photon_pp_pTHat30_40_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt30_40_10M_smearedphotonjet.txt').T
ax3.errorbar(photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_deltaR, photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR, yerr = photon_jet_xscape_30_40_yesprompt_deltaRcut_constituentcut_smeared_jetpt_30_40_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 30-40 dijets, $30<p_{T}^{jets}<40$, prompt const>1')


# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax1.set_xlabel(r'$\Delta R$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax2.set_xlabel(r'$\Delta R$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

ax3.set_yscale('log')
ax3.set_title(r'$\Delta R$ of Photons in 30-40 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax3.set_xlabel(r'$\Delta R$',fontsize=12)
ax3.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax3.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %% [markdown]
# ### PTHat 40-60 GeV Photon Momentum Fraction and Delta R

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,6))

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_30_40_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_noprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ prompt const>1')

# XSCAPE pTHat 40-60 photon / jet momentum fraction, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_frag_func_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_z, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNdz_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt const>1')

# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$,, Gaussian smearing)')
ax1.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title('Momentum Fraction of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$,, Gaussian smearing)')
ax2.set_xlabel(r'$z = \frac{p_{T}^{\gamma}}{p_{T}^{jets}}$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,6))

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$ noprompt const>1')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt const>1')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, noprompt')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = off, deltaR < 0.4)
photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_noprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_noprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, noprompt')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4)
photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='green', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 10-20 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt10_20_1M_smearedphotonjet.txt').T
ax1.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_10_20_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $10<p_{T}^{jets}<20$, prompt const>1')

# XSCAPE pTHat 40-60 photon-jet deltaR, jet pT 20-30 GeV (PromptPhoton:all = on, deltaR < 0.4, constituents > 1)
photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat40_60_photon_jet_deltaR_alldecayoff_yesprompt_deltaRcut_constituentcut_jetpt20_30_1M_smearedphotonjet.txt').T
ax2.errorbar(photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_deltaR, photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR, yerr = photon_jet_xscape_40_60_yesprompt_deltaRcut_constituentcut_smeared_jetpt_20_30_dNddeltaR_err, fmt = '-', color='purple', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 40-60 dijets, $20<p_{T}^{jets}<30$, prompt const>1')


# ax1.set_ylim(1e-13,1e-3)
# ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title(r'$\Delta R$ of Photons in 10-20 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax1.set_xlabel(r'$\Delta R$',fontsize=12)
ax1.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax1.legend(fontsize=9)

ax2.set_yscale('log')
ax2.set_title(r'$\Delta R$ of Photons in 20-30 GeV Dijets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
ax2.set_xlabel(r'$\Delta R$',fontsize=12)
ax2.set_ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
ax2.legend(fontsize=9)

plt.tight_layout()

# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
# plt.yscale('log')

# plt.title(r'$\Delta R$ of Photons in Jets (anti-$k_{T}$, $\Delta R<0.4$, Gaussian smearing)')
# plt.xlabel(r'$\Delta R$',fontsize=12)
# plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\gamma}}{dz}$',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %% [markdown]
# ### PTHat 15-40 GeV Pions Momentum Fraction and Delta R

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 pion / jet momentum fraction, jet pT 10-20 GeV
pion_jet_xscape_15_40_smeared_jetpt_10_20_z, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_frag_func_alldecayoff_noprompt_jetpt10_20_1M_smearedpionjet.txt').T
plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_10_20_z, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz, yerr = pion_jet_xscape_15_40_smeared_jetpt_10_20_dNdz_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 pion / jet momentum fraction, jet pT 20-30 GeV
pion_jet_xscape_15_40_smeared_jetpt_20_30_z, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_frag_func_alldecayoff_noprompt_jetpt20_30_1M_smearedpionjet.txt').T
plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_20_30_z, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz, yerr = pion_jet_xscape_15_40_smeared_jetpt_20_30_dNdz_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
plt.yscale('log')

plt.title('Momentum Fraction of Pions in Jets (anti-$k_{T}$, R=0.4, Gaussian smearing)')
plt.xlabel(r'$z = \frac{p_{T}^{\pi}}{p_{T}^{jets}}$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt


# # PYTHIA pTHat 5-15 charged pion cross sections
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# # PYTHIA pTHat 15-30 charged pion cross sections
# pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 pion / jet momentum fraction, jet pT 10-20 GeV
pion_jet_xscape_15_40_smeared_jetpt_10_20_deltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_deltaR_alldecayoff_noprompt_jetpt10_20_1M_smearedpionjet.txt').T
plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_10_20_deltaR, pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR, yerr = pion_jet_xscape_15_40_smeared_jetpt_10_20_dNddeltaR_err, fmt = '.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $10<p_{T}^{jets}<20$')

# XSCAPE pTHat 15-40 pion / jet momentum fraction, jet pT 20-30 GeV
pion_jet_xscape_15_40_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR_err = np.loadtxt('photon_pp_pTHat15_40_pion_jet_deltaR_alldecayoff_noprompt_jetpt20_30_1M_smearedpionjet.txt').T
plt.errorbar(pion_jet_xscape_15_40_smeared_jetpt_20_30_deltaR, pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR, yerr = pion_jet_xscape_15_40_smeared_jetpt_20_30_dNddeltaR_err, fmt = '.', color='blue', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-40 dijets, $20<p_{T}^{jets}<30$')


# plt.ylim(1e-4,1e1)
# plt.xlim(4,21)
plt.yscale('log')

plt.title(r'$\Delta R$ of Pions in Jets (anti-$k_{T}$, R=0.4, Gaussian smearing)')
plt.xlabel(r'$\Delta R$',fontsize=12)
plt.ylabel(r'$\frac{1}{N_{jets}}$ $\frac{dN^{\pi}}{dz}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$10 < p_{T}^{jet} < 20$ GeV' , fontsize=12)
plt.show()
