# %% [markdown]
# ## XSCAPE Pion Cross Sections Compared to Data and PYTHIA Results

# %% [markdown]
# ### Charged Pions (Positive and Negative Averaged)

# %% [markdown]
# PTHAT 5-10, 10-15, 15-20, and 20-25 PYTHIA and XSCAPE cross sections, with varying XSCAPE hadronization and virtuality factor

# %%
import numpy  as np
import matplotlib.pyplot as plt
import os
import subprocess
from IPython.display import display

# Pion Plus Data
existing_pionplus_pT, existing_pionplus_cross_sec, existing_pionplus_stat_err, existing_pionplus_syst_err=np.loadtxt('Existing PionPlus Data for Cross Sections.txt').T
# plt.errorbar(existing_pionplus_pT, existing_pionplus_cross_sec, yerr=np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2), fmt='.', color='blue', label='PHENIX $\pi^{+}$ $|\eta|<0.35$')
existing_pionplus_cross_sec_err = np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2)

# Pion Minus Data
existing_pionminus_pT, existing_pionminus_cross_sec, existing_pionminus_stat_err, existing_pionminus_syst_err=np.loadtxt('Existing PionMinus Data for Cross Sections.txt').T
# plt.errorbar(existing_pionminus_pT, existing_pionminus_cross_sec, yerr=np.sqrt(existing_pionminus_stat_err**2+existing_pionminus_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{-}$ $|\eta|<0.35$')
existing_pionminus_cross_sec_err = np.sqrt(existing_pionminus_stat_err**2+existing_pionminus_syst_err**2)

# Combined Pion Plus and Pion Minus Data
existing_piontotal_cross_sec = (existing_pionplus_cross_sec+existing_pionminus_cross_sec)/2
existing_piontotal_cross_sec_err = np.sqrt(existing_pionminus_cross_sec_err**2 + existing_pionplus_cross_sec_err**2)
# plt.plot(existing_pionminus_pT, existing_piontotal_cross_sec,'-', color='black', label='maybe PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')
# plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
existing_pionall_pT, existing_pionall_cross_sec, existing_pionall_stat_err, existing_pionall_syst_err = np.loadtxt('Existing Pion Data for Cross Sections (all pT).txt').T
# plt.plot(existing_pionall_pT, existing_pionall_cross_sec,'-', color='blue', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')
existing_pionall_cross_sec_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
# plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')


# PYTHIA colorless charged pion cross sections
pionplusminus_pythia_5_10_pT, pionplusminus_pythia_5_10_cross_sec, pionplusminus_pythia_5_10_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_10_cross_sec_v4.txt').T
pionplusminus_pythia_10_15_pT, pionplusminus_pythia_10_15_cross_sec, pionplusminus_pythia_10_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat10_15_cross_sec_v4.txt').T
pionplusminus_pythia_15_20_pT, pionplusminus_pythia_15_20_cross_sec, pionplusminus_pythia_15_20_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_20_cross_sec_v4.txt').T
pionplusminus_pythia_20_25_pT, pionplusminus_pythia_20_25_cross_sec, pionplusminus_pythia_20_25_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat20_25_cross_sec_v4.txt').T

# XSCAPE colorless charged pion cross sections
pionplusminus_xscape_5_10_pT, pionplusminus_xscape_5_10_cross_sec, pionplusminus_xscape_5_10_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_10_cross_sec_v4.txt').T
pionplusminus_xscape_10_15_pT, pionplusminus_xscape_10_15_cross_sec, pionplusminus_xscape_10_15_cross_sec_err = np.loadtxt('pionall_pp_pTHat10_15_cross_sec_v4.txt').T
pionplusminus_xscape_15_20_pT, pionplusminus_xscape_15_20_cross_sec, pionplusminus_xscape_15_20_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_20_cross_sec_v4.txt').T
pionplusminus_xscape_20_25_pT, pionplusminus_xscape_20_25_cross_sec, pionplusminus_xscape_20_25_cross_sec_err = np.loadtxt('pionall_pp_pTHat20_25_cross_sec_v4.txt').T

# XSCAPE colored charged pion cross sections
pionplusminus_xscape_5_10_colored_pT, pionplusminus_xscape_5_10_colored_cross_sec, pionplusminus_xscape_5_10_colored_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_10_cross_sec_v4_colored.txt').T
pionplusminus_xscape_10_15_colored_pT, pionplusminus_xscape_10_15_colored_cross_sec, pionplusminus_xscape_10_15_colored_cross_sec_err = np.loadtxt('pionall_pp_pTHat10_15_cross_sec_v4_colored.txt').T
pionplusminus_xscape_15_20_colored_pT, pionplusminus_xscape_15_20_colored_cross_sec, pionplusminus_xscape_15_20_colored_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_20_cross_sec_v4_colored.txt').T
pionplusminus_xscape_20_25_colored_pT, pionplusminus_xscape_20_25_colored_cross_sec, pionplusminus_xscape_20_25_colored_cross_sec_err = np.loadtxt('pionall_pp_pTHat20_25_cross_sec_v4_colored.txt').T

# XSCAPE colorless vir0.5 charged pion cross sections
pionplusminus_xscape_5_10_vir05_pT, pionplusminus_xscape_5_10_vir05_cross_sec, pionplusminus_xscape_5_10_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_10_cross_sec_v4_vir05.txt').T
pionplusminus_xscape_10_15_vir05_pT, pionplusminus_xscape_10_15_vir05_cross_sec, pionplusminus_xscape_10_15_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat10_15_cross_sec_v4_vir05.txt').T
pionplusminus_xscape_15_20_vir05_pT, pionplusminus_xscape_15_20_vir05_cross_sec, pionplusminus_xscape_15_20_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_20_cross_sec_v4_vir05.txt').T
pionplusminus_xscape_20_25_vir05_pT, pionplusminus_xscape_20_25_vir05_cross_sec, pionplusminus_xscape_20_25_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat20_25_cross_sec_v4_vir05.txt').T

# XSCAPE colored vir0.5 charged pion cross sections
pionplusminus_xscape_5_10_colored_vir05_pT, pionplusminus_xscape_5_10_colored_vir05_cross_sec, pionplusminus_xscape_5_10_colored_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_10_cross_sec_v4_colored_vir05.txt').T
pionplusminus_xscape_10_15_colored_vir05_pT, pionplusminus_xscape_10_15_colored_vir05_cross_sec, pionplusminus_xscape_10_15_colored_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat10_15_cross_sec_v4_colored_vir05.txt').T
pionplusminus_xscape_15_20_colored_vir05_pT, pionplusminus_xscape_15_20_colored_vir05_cross_sec, pionplusminus_xscape_15_20_colored_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_20_cross_sec_v4_colored_vir05.txt').T
pionplusminus_xscape_20_25_colored_vir05_pT, pionplusminus_xscape_20_25_colored_vir05_cross_sec, pionplusminus_xscape_20_25_colored_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat20_25_cross_sec_v4_colored_vir05.txt').T

# Plotting
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4,figsize=(35,10))

# Plotting Existing Charged Pion Cross Sections
ax1.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')
ax2.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')
ax3.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')
ax4.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Plotting PYTHIA Charged Pion Cross Sections
ax1.errorbar(pionplusminus_pythia_5_10_pT, pionplusminus_pythia_5_10_cross_sec/(2*pionplusminus_pythia_5_10_pT), yerr = pionplusminus_pythia_5_10_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-10 $(\pi^{+}+\pi^{-})/2$')
ax2.errorbar(pionplusminus_pythia_10_15_pT, pionplusminus_pythia_10_15_cross_sec/(2*pionplusminus_pythia_10_15_pT), yerr = pionplusminus_pythia_10_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$')
ax3.errorbar(pionplusminus_pythia_15_20_pT, pionplusminus_pythia_15_20_cross_sec/(2*pionplusminus_pythia_15_20_pT), yerr = pionplusminus_pythia_15_20_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-20 $(\pi^{+}+\pi^{-})/2$')
ax4.errorbar(pionplusminus_pythia_20_25_pT, pionplusminus_pythia_20_25_cross_sec/(2*pionplusminus_pythia_20_25_pT), yerr = pionplusminus_pythia_20_25_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 20-25 $(\pi^{+}+\pi^{-})/2$')

# Plotting XSCAPE Colorless Charged Pion Cross Sections
ax1.errorbar(pionplusminus_xscape_5_10_pT, pionplusminus_xscape_5_10_cross_sec/(2*pionplusminus_xscape_5_10_pT), yerr = pionplusminus_xscape_5_10_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-10 $(\pi^{+}+\pi^{-})/2$')
ax2.errorbar(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_10_15_cross_sec/(2*pionplusminus_xscape_10_15_pT), yerr = pionplusminus_xscape_10_15_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$')
ax3.errorbar(pionplusminus_xscape_15_20_pT, pionplusminus_xscape_15_20_cross_sec/(2*pionplusminus_xscape_15_20_pT), yerr = pionplusminus_xscape_15_20_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 15-20 $(\pi^{+}+\pi^{-})/2$')
ax4.errorbar(pionplusminus_xscape_20_25_pT, pionplusminus_xscape_20_25_cross_sec/(2*pionplusminus_xscape_20_25_pT), yerr = pionplusminus_xscape_20_25_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 20-25 $(\pi^{+}+\pi^{-})/2$')

# Plotting XSCAPE Colored Charged Pion Cross Sections
ax1.errorbar(pionplusminus_xscape_5_10_colored_pT, pionplusminus_xscape_5_10_colored_cross_sec/(2*pionplusminus_xscape_5_10_colored_pT), yerr = pionplusminus_xscape_5_10_colored_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-10 $(\pi^{+}+\pi^{-})/2$ colored')
ax2.errorbar(pionplusminus_xscape_10_15_colored_pT, pionplusminus_xscape_10_15_colored_cross_sec/(2*pionplusminus_xscape_10_15_colored_pT), yerr = pionplusminus_xscape_10_15_colored_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ colored')
ax3.errorbar(pionplusminus_xscape_15_20_colored_pT, pionplusminus_xscape_15_20_colored_cross_sec/(2*pionplusminus_xscape_15_20_colored_pT), yerr = pionplusminus_xscape_15_20_colored_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 15-20 $(\pi^{+}+\pi^{-})/2$ colored')
ax4.errorbar(pionplusminus_xscape_20_25_colored_pT, pionplusminus_xscape_20_25_colored_cross_sec/(2*pionplusminus_xscape_20_25_colored_pT), yerr = pionplusminus_xscape_20_25_colored_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 20-25 $(\pi^{+}+\pi^{-})/2$ colored')

# Plotting XSCAPE Colored vir0.5 Charged Pion Cross Sections
ax1.errorbar(pionplusminus_xscape_5_10_colored_vir05_pT, pionplusminus_xscape_5_10_colored_vir05_cross_sec/(2*pionplusminus_xscape_5_10_colored_vir05_pT), yerr = pionplusminus_xscape_5_10_colored_vir05_cross_sec_err, fmt = '-', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-10 $(\pi^{+}+\pi^{-})/2$ colored vir0.5')
ax2.errorbar(pionplusminus_xscape_10_15_colored_vir05_pT, pionplusminus_xscape_10_15_colored_vir05_cross_sec/(2*pionplusminus_xscape_10_15_colored_vir05_pT), yerr = pionplusminus_xscape_10_15_colored_vir05_cross_sec_err, fmt = '-', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ colored vir0.5')
ax3.errorbar(pionplusminus_xscape_15_20_colored_vir05_pT, pionplusminus_xscape_15_20_colored_vir05_cross_sec/(2*pionplusminus_xscape_15_20_colored_vir05_pT), yerr = pionplusminus_xscape_15_20_colored_vir05_cross_sec_err, fmt = '-', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 15-20 $(\pi^{+}+\pi^{-})/2$ colored vir0.5')
ax4.errorbar(pionplusminus_xscape_20_25_colored_vir05_pT, pionplusminus_xscape_20_25_colored_vir05_cross_sec/(2*pionplusminus_xscape_20_25_colored_vir05_pT), yerr = pionplusminus_xscape_20_25_colored_vir05_cross_sec_err, fmt = '-', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 20-25 $(\pi^{+}+\pi^{-})/2$ colored vir0.5')

# Plotting XSCAPE Colorless vir0.5 Charged Pion Cross Sections
ax1.errorbar(pionplusminus_xscape_5_10_vir05_pT, pionplusminus_xscape_5_10_vir05_cross_sec/(2*pionplusminus_xscape_5_10_vir05_pT), yerr = pionplusminus_xscape_5_10_vir05_cross_sec_err, fmt = '-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-10 $(\pi^{+}+\pi^{-})/2$ vir0.5')
ax2.errorbar(pionplusminus_xscape_10_15_vir05_pT, pionplusminus_xscape_10_15_vir05_cross_sec/(2*pionplusminus_xscape_10_15_vir05_pT), yerr = pionplusminus_xscape_10_15_vir05_cross_sec_err, fmt = '-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ vir0.5')
ax3.errorbar(pionplusminus_xscape_15_20_vir05_pT, pionplusminus_xscape_15_20_vir05_cross_sec/(2*pionplusminus_xscape_15_20_vir05_pT), yerr = pionplusminus_xscape_15_20_vir05_cross_sec_err, fmt = '-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 15-20 $(\pi^{+}+\pi^{-})/2$ vir0.5')
ax4.errorbar(pionplusminus_xscape_20_25_vir05_pT, pionplusminus_xscape_20_25_vir05_cross_sec/(2*pionplusminus_xscape_20_25_vir05_pT), yerr = pionplusminus_xscape_20_25_vir05_cross_sec_err, fmt = '-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 20-25 $(\pi^{+}+\pi^{-})/2$ vir0.5')

# More Plotting Parameters
# PTHat 5-10
ax1.set_ylim(1e-13,1e-3)
ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title(r'Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
ax1.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax1.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax1.legend(fontsize=9)

# PTHat 10-15
ax2.set_ylim(1e-13,1e-3)
ax2.set_xlim(2.5,17)
ax2.set_yscale('log')
ax2.set_title(r'Differential Invariant Cross Section of (\pi^{+}+\pi^{-})/2')
ax2.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax2.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax2.legend(fontsize=9)

# PTHat 15-20
ax3.set_ylim(1e-13,1e-3)
ax3.set_xlim(2.5,17)
ax3.set_yscale('log')
ax3.set_title(r'Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
ax3.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax3.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax3.legend(fontsize=9)

# PTHat 20-25
ax4.set_ylim(1e-13,1e-3)
ax4.set_xlim(2.5,17)
ax4.set_yscale('log')
ax4.set_title(r'Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
ax4.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax4.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax4.legend(fontsize=9)

plt.tight_layout()

fig.savefig('XSCAPE_PYTHIA_cross_sec_color_virtuality_comparison_plots.png', dpi=300, bbox_inches='tight')
if os.name == 'nt': #For Windows
    os.startfile('XSCAPE_PYTHIA_cross_sec_color_virtuality_comparison_plots.png')
else: # For macOS and Linux
    subprocess.call(('open', 'XSCAPE_PYTHIA_cross_sec_color_virtuality_comparison_plots.png'))

# plt.text(11, 0.00008, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(11, 0.000025, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
# plt.legend(fontsize=9)
plt.show()
# display(plt.gcf)

# %% [markdown]
# Ratio of PTHAT 5-10, 10-15, 15-20, and 20-25 XSCAPE and Data cross sections to PYTHIA

# %%
plt.plot(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_10_15_cross_sec_scale/pionplusminus_pythia_10_15_cross_sec_scale, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ vir=0.25')
plt.plot(pionplusminus_xscape_10_15_pT, pionplusminus_pythia_10_15_cross_sec_scale/pionplusminus_pythia_10_15_cross_sec_scale, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_10_15_pT, existing_piontotal_cross_sec/pionplusminus_pythia_10_15_cross_sec_scale, '-', color='blue', label='PHENIX Data $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_10_15_vir05_cross_sec_scale/pionplusminus_pythia_10_15_cross_sec_scale,'-', color = 'red', label = 'XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ vir=0.5')
plt.plot(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_5_10_colored_vir05_cross_sec/pionplusminus_pythia_10_15_cross_sec,'-', color = 'orange', label = 'XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ colored vir=0.5')
plt.plot(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_5_10_colored_cross_sec/pionplusminus_pythia_10_15_cross_sec,'-', color = 'magenta', label = 'XSCAPE $\hat{p_{T}}$ 10-15 $(\pi^{+}+\pi^{-})/2$ colored vir=0.25')

# plt.ylim(-1,2)
plt.xlim(3,15)
plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel('$E d^3\sigma/dp^3$ (mb/GeV$^2$)',fontsize=12)
plt.text(10, 4, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
plt.text(10, 3.4, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
plt.show()

# %% [markdown]
# PTHAT 5-25 PYTHIA and XSCAPE cross sections, with varying XSCAPE hadronization and virtuality factor

# %%
import numpy  as np
import matplotlib.pyplot as plt

# Combined Pion Plus and Pion Minus Data
plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
# plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')


# PYTHIA pTHat 5-25 charged pion cross sections
pionplusminus_pythia_5_25_pT, pionplusminus_pythia_5_25_cross_sec, pionplusminus_pythia_5_25_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_25_cross_sec_v4.txt').T
plt.errorbar(pionplusminus_pythia_5_25_pT, pionplusminus_pythia_5_25_cross_sec/(2*pionplusminus_pythia_5_25_pT), yerr = pionplusminus_pythia_5_25_cross_sec_err, fmt = '-', color='green', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-25 colorless charged pion cross sections
pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_cross_sec, pionplusminus_xscape_5_25_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_25_cross_sec_v3.txt').T
plt.errorbar(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_cross_sec/(2*pionplusminus_xscape_5_25_pT), yerr = pionplusminus_xscape_5_25_cross_sec_err, fmt = '-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ vir=0.25')

# XSCAPE pTHat 5-25 colored charged pion cross sections
pionplusminus_xscape_5_25_colored_pT, pionplusminus_xscape_5_25_colored_cross_sec, pionplusminus_xscape_5_25_colored_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_25_cross_sec_v4_colored.txt').T
plt.errorbar(pionplusminus_xscape_5_25_colored_pT, pionplusminus_xscape_5_25_colored_cross_sec/(2*pionplusminus_xscape_5_25_colored_pT), yerr = pionplusminus_xscape_5_25_colored_cross_sec_err, fmt = '-', color='magenta', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colored vir=0.25')

# XSCAPE pTHat 5-25 colorless vir0.5 charged pion cross sections
pionplusminus_xscape_5_25_vir05_pT, pionplusminus_xscape_5_25_vir05_cross_sec, pionplusminus_xscape_5_25_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_25_cross_sec_v4_vir05.txt').T
plt.errorbar(pionplusminus_xscape_5_25_vir05_pT, pionplusminus_xscape_5_25_vir05_cross_sec/(2*pionplusminus_xscape_5_25_vir05_pT), yerr = pionplusminus_xscape_5_25_vir05_cross_sec_err, fmt = '-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ vir=0.5')

# XSCAPE pTHat 5-25 colored vir0.5 charged pion cross sections
pionplusminus_xscape_5_25_colored_vir05_pT, pionplusminus_xscape_5_25_colored_vir05_cross_sec, pionplusminus_xscape_5_25_colored_vir05_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_25_cross_sec_v4_colored_vir05.txt').T
plt.errorbar(pionplusminus_xscape_5_25_colored_vir05_pT, pionplusminus_xscape_5_25_colored_vir05_cross_sec/(2*pionplusminus_xscape_5_25_colored_vir05_pT), yerr = pionplusminus_xscape_5_25_colored_vir05_cross_sec_err, fmt = '-', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colored vir=0.5')


plt.ylim(1e-10,1e-3)
plt.xlim(4,13)
plt.yscale('log')

plt.title('Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# Ratio of PTHAT 5-25 XSCAPE and Data cross sections to PYTHIA

# %%
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colorless vir=0.25')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_pythia_5_25_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_5_25_pT, existing_piontotal_cross_sec/pionplusminus_pythia_5_25_cross_sec, '-', color='blue', label='PHENIX Data $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_vir05_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec,'-', color = 'red', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colorless vir=0.5')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_colored_vir05_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec,'-', color = 'orange', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colored vir=0.5')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_colored_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec,'-', color = 'magenta', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colored vir=0.25')

plt.ylim(-1,2)
plt.xlim(3,15)
plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel('$E d^3\sigma/dp^3$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# PTHAT 5-25 combined XSCAPE and PYTHIA cross sections

# %%
# Combined Pion Plus and Pion Minus Data
plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# Combining all PYTHIA pTHat bins into one
if (np.all(pionplusminus_pythia_5_10_pT==pionplusminus_pythia_10_15_pT)):
    pionplusminus_pythia_5_15_comb_cross_sec = pionplusminus_pythia_5_10_cross_sec+pionplusminus_pythia_10_15_cross_sec
    pionplusminus_pythia_5_15_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_10_cross_sec_err**2+pionplusminus_pythia_10_15_cross_sec_err**2)
    if (np.all(pionplusminus_pythia_10_15_pT==pionplusminus_pythia_15_20_pT)):
        pionplusminus_pythia_5_20_comb_cross_sec = pionplusminus_pythia_5_15_comb_cross_sec+pionplusminus_pythia_15_20_cross_sec
        pionplusminus_pythia_5_20_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_comb_cross_sec_err**2+pionplusminus_pythia_15_20_cross_sec_err**2)
        if (np.all(pionplusminus_pythia_15_20_pT==pionplusminus_pythia_20_25_pT)):
            pionplusminus_pythia_5_25_comb_cross_sec = pionplusminus_pythia_5_20_comb_cross_sec+pionplusminus_pythia_20_25_cross_sec
            pionplusminus_pythia_5_25_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_20_comb_cross_sec_err**2+pionplusminus_pythia_20_25_cross_sec_err**2)
            plt.errorbar(pionplusminus_pythia_10_15_pT, pionplusminus_pythia_5_25_comb_cross_sec, yerr=pionplusminus_pythia_5_25_comb_cross_sec_err, fmt='-', color='green', label= 'PYTHIA $\hat{p_{T}}$ 5-25 comb $(\pi^{+}+\pi^{-})/2$')

# Combinging all XSCAPE pTHat bins into one
if (np.all(pionplusminus_xscape_5_15_pT==pionplusminus_xscape_15_30_pT)):
    pionplusminus_xscape_5_15_comb_cross_sec = pionplusminus_xscape_5_10_cross_sec+pionplusminus_xscape_10_15_cross_sec
    pionplusminus_xscape_5_15_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_10_cross_sec_err**2+pionplusminus_xscape_10_15_cross_sec_err**2)
    if (np.all(pionplusminus_xscape_10_15_pT==pionplusminus_xscape_15_20_pT)):
        pionplusminus_xscape_5_20_comb_cross_sec = pionplusminus_xscape_5_15_comb_cross_sec+pionplusminus_xscape_15_20_cross_sec
        pionplusminus_xscape_5_20_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_comb_cross_sec_err**2+pionplusminus_xscape_15_20_cross_sec_err**2)
        if (np.all(pionplusminus_xscape_15_20_pT==pionplusminus_xscape_20_25_pT)):
            pionplusminus_xscape_5_25_comb_cross_sec = pionplusminus_xscape_5_20_comb_cross_sec+pionplusminus_xscape_20_25_cross_sec
            pionplusminus_xscape_5_25_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_20_comb_cross_sec_err**2+pionplusminus_xscape_20_25_cross_sec_err**2)
            plt.errorbar(pionplusminus_xscape_10_15_pT, pionplusminus_xscape_5_25_comb_cross_sec, yerr=pionplusminus_xscape_5_25_comb_cross_sec_err, fmt='-', color='purple', label= 'XSCAPE $\hat{p_{T}}$ 5-25 comb $(\pi^{+}+\pi^{-})/2$')

plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

plt.title('Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# Ratio of PTHAT 5-25 combined XSCAPE and Data cross sections to PYTHIA

# %%
# plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec_scale, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$ vir=0.25')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_pythia_5_25_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec_scale, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_5_25_pT, existing_piontotal_cross_sec/pionplusminus_pythia_5_25_cross_sec_scale, '-', color='blue', label='PHENIX Data $(\pi^{+}+\pi^{-})/2$')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_vir05_cross_sec_scale/pionplusminus_pythia_5_25_cross_sec_scale,'-', color = 'red', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colorless vir=0.5')
plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_colored_vir05_cross_sec/pionplusminus_pythia_5_25_cross_sec,'-', color = 'orange', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ colored vir=0.5')
# plt.plot(pionplusminus_xscape_5_25_pT, pionplusminus_xscape_5_25_colored_cross_sec/pionplusminus_pythia_5_25_cross_sec,'-', color = 'magenta', label = 'XSCAPE $\hat{p_{T}}$ 5-25 $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$ colored vir=0.25')

plt.ylim(-1,2)
plt.xlim(3,15)
plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel('$E d^3\sigma/dp^3$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# PTHAT 5-15 and 15-30 XSCAPE and PYTHIA cross sections

# %%
import numpy  as np
import matplotlib.pyplot as plt

# Combined Pion Plus and Pion Minus Data
plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# PYTHIA pTHat 5-15 charged pion cross sections
pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# PYTHIA pTHat 15-30 charged pion cross sections
pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 5-15 charged pion cross sections
pionplusminus_xscape_5_15_pT, pionplusminus_xscape_5_15_cross_sec, pionplusminus_xscape_5_15_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T
plt.errorbar(pionplusminus_xscape_5_15_pT, pionplusminus_xscape_5_15_cross_sec, yerr = pionplusminus_xscape_5_15_cross_sec_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE pTHat 15-30 charged pion cross sections
pionplusminus_xscape_15_30_pT, pionplusminus_xscape_15_30_cross_sec, pionplusminus_xscape_15_30_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T
plt.errorbar(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_15_30_cross_sec, yerr = pionplusminus_xscape_15_30_cross_sec_err, fmt = '-.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')


plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

plt.title('Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# PTHAT 5-15 and 15-30 combined XSCAPE and PYTHIA cross sections

# %%
# Combined Pion Plus and Pion Minus Data
plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

# Combining PYTHIA pTHat 5-15 and 15-30
if (np.all(pionplusminus_pythia_5_15_pT==pionplusminus_pythia_15_30_pT)):
    pionplusminus_pythia_5_30_comb_cross_sec = pionplusminus_pythia_5_15_cross_sec+pionplusminus_pythia_15_30_cross_sec 
    pionplusminus_pythia_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_cross_sec_err**2+pionplusminus_pythia_15_30_cross_sec_err**2)
    plt.errorbar(existing_pionall_pT, pionplusminus_pythia_5_30_comb_cross_sec/2, yerr=pionplusminus_pythia_5_30_comb_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

# Combining XSCAPE pTHat 5-15 and 15-30
if (np.all(pionplusminus_xscape_5_15_pT==pionplusminus_xscape_15_30_pT)):
    pionplusminus_xscape_5_30_comb_cross_sec = pionplusminus_xscape_5_15_cross_sec+pionplusminus_xscape_15_30_cross_sec
    pionplusminus_xscape_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_cross_sec_err**2+pionplusminus_xscape_15_30_cross_sec_err**2)
    plt.errorbar(existing_pionall_pT, pionplusminus_xscape_5_30_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_comb_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

plt.title('Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# PTHAT 5-15 and 15-30 combined XSCAPE and PYTHIA cross sections Ratio to PYTHIA

# %%
# Interpolating the calculations (PYTHIA and XSCAPE) to match the data points
# def align_and_ratio(x1, y1, y1_err, x2, y2, y2_err):
#     # Find common x-range
#     x_min = max(min(x1), min(x2))
#     x_max = min(max(x1), max(x2))
    
#     # Use x1 as reference
#     # x_ref = x1[(x1 >= x_min) & (x1 <= x_max)]
#     # y1_ref = y1[(x1 >= x_min) & (x1 <= x_max)]
#     x_ref = np.linspace(x_min, x_max, num=max(len(x1), len(x2)))
#     y1_interp = np.interp(x_ref, x1, y1)
    
#     # Interpolate y2 to match x_ref
#     y2_interp = np.interp(x_ref, x2, y2)
#     y1_err_interp = np.interp(x_ref, x1, y1_err)
#     y2_err_interp = np.interp(x_ref, x2, y2_err)

#     # Calculate ratio
#     # ratio = y1_ref / y2_interp
#     ratio = y1_interp / y2_interp
#     ratio_err = ratio * np.sqrt((y1_err_interp/y1_interp)**2 + (y2_err_interp/y2_interp)**2)

#     return x_ref, ratio, ratio_err

# # Defining the variables
# x1 = existing_pionall_pT
# y1 = existing_pionall_cross_sec
# y1_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
# x2 = pionplusminus_pythia_15_30_pT
# y2 = pionplusminus_pythia_5_30_comb_cross_sec
# y2_err = pionplusminus_pythia_5_30_comb_cross_sec_err

# x_aligned, ratio, ratio_err = align_and_ratio(x1, y1, y1_err, x2, y2, y2_err)

# # Plotting the Neutral Pion Data / PYTHIA ratio
# plt.errorbar(x_aligned, 2*ratio, yerr=ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# Error Ratios for XSCAPE and PYTHIA
xscape_pythia_ratio_err = (pionplusminus_xscape_5_30_comb_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_comb_cross_sec_err/pionplusminus_xscape_5_30_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)
pythia_pythia_ratio_err = (pionplusminus_pythia_5_30_comb_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)
data_pythia_ratio_err = (existing_pionall_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((existing_pionall_cross_sec_err/existing_pionall_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)

# Plotting the XSCAPE / PYTHIA and PYTHIA / PYTHIA ratios
plt.errorbar(existing_pionall_pT, (pionplusminus_xscape_5_30_comb_cross_sec)/pionplusminus_pythia_5_30_comb_cross_sec, yerr=xscape_pythia_ratio_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(existing_pionall_pT, (pionplusminus_pythia_5_30_comb_cross_sec)/pionplusminus_pythia_5_30_comb_cross_sec, yerr=pythia_pythia_ratio_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(existing_pionall_pT, (2*existing_pionall_cross_sec)/pionplusminus_pythia_5_30_comb_cross_sec, yerr=data_pythia_ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

plt.ylim(-1.5,3.5)
# plt.xlim(5,20)
# plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'Ratio to PYTHIA 8.309 [$E \frac{d^{3}\sigma}{dp^{3}}$]',fontsize=12)
plt.legend(fontsize=9)
# plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# Comparing Charged Pion Cross Section Data to XSCAPE and PYTHIA

# %%
# Combined Pion Plus and Pion Minus Data
plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
# plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

# PYTHIA and XSCAPE pTHat 5-15 
pionplusminus_pythia_5_15_cut_pT, pionplusminus_pythia_5_15_cut_cross_sec, pionplusminus_pythia_5_15_cut_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_5_12_pT.txt').T
pionplusminus_xscape_5_15_cut_pT, pionplusminus_xscape_5_15_cut_cross_sec, pionplusminus_xscape_5_15_cut_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_cross_sec_v4_5_12_pT.txt').T

# PYTHIA and XSCAPE pTHat 15-30
pionplusminus_pythia_15_30_cut_pT, pionplusminus_pythia_15_30_cut_cross_sec, pionplusminus_pythia_15_30_cut_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_5_12_pT.txt').T
pionplusminus_xscape_15_30_cut_pT, pionplusminus_xscape_15_30_cut_cross_sec, pionplusminus_xscape_15_30_cut_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_cross_sec_v4_5_12_pT.txt').T

# Combining PYTHIA pTHat 5-15 and 15-30
if (np.all(pionplusminus_pythia_5_15_cut_pT==pionplusminus_pythia_15_30_cut_pT)):
    pionplusminus_pythia_5_30_comb_cut_cross_sec = pionplusminus_pythia_5_15_cut_cross_sec+pionplusminus_pythia_15_30_cut_cross_sec 
    pionplusminus_pythia_5_30_comb_cut_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_cut_cross_sec_err**2+pionplusminus_pythia_15_30_cut_cross_sec_err**2)
    plt.errorbar(pionplusminus_pythia_15_30_cut_pT, pionplusminus_pythia_5_30_comb_cut_cross_sec/2, yerr=pionplusminus_pythia_5_30_comb_cut_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

# Combining XSCAPE pTHat 5-15 and 15-30
if (np.all(pionplusminus_xscape_5_15_cut_pT==pionplusminus_xscape_15_30_cut_pT)):
    pionplusminus_xscape_5_30_comb_cut_cross_sec = pionplusminus_xscape_5_15_cut_cross_sec+pionplusminus_xscape_15_30_cut_cross_sec
    pionplusminus_xscape_5_30_comb_cut_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_cut_cross_sec_err**2+pionplusminus_xscape_15_30_cut_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_cut_pT, pionplusminus_xscape_5_30_comb_cut_cross_sec/2, yerr=pionplusminus_xscape_5_30_comb_cut_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.xlim(4.9,12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
def align_and_ratio(x1, y1, y1_err, x2, y2, y2_err):
    # Find common x-range
    x_min = max(min(x1), min(x2))
    x_max = min(max(x1), max(x2))
    
    # Use x1 as reference
    # x_ref = x1[(x1 >= x_min) & (x1 <= x_max)]
    # y1_ref = y1[(x1 >= x_min) & (x1 <= x_max)]
    x_ref = np.linspace(x_min, x_max, num=max(len(x1), len(x2)))
    y1_interp = np.interp(x_ref, x1, y1)
    
    # Interpolate y2 to match x_ref
    y2_interp = np.interp(x_ref, x2, y2)
    y1_err_interp = np.interp(x_ref, x1, y1_err)
    y2_err_interp = np.interp(x_ref, x2, y2_err)

    # Calculate ratio
    # ratio = y1_ref / y2_interp
    ratio = y1_interp / y2_interp
    ratio_err = ratio * np.sqrt((y1_err_interp/y1_interp)**2 + (y2_err_interp/y2_interp)**2)

    return x_ref, ratio, ratio_err

# Usage
# x1 = existing_pionall_pT
# y1 = existing_pionall_cross_sec
# y1_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
x1 = existing_pionplus_pT
y1 = existing_piontotal_cross_sec
y1_err = existing_piontotal_cross_sec_err
x2 = pionplusminus_pythia_15_30_cut_pT
y2 = pionplusminus_pythia_5_30_comb_cut_cross_sec
y2_err = pionplusminus_pythia_5_30_comb_cut_cross_sec_err

x_aligned, ratio, ratio_err = align_and_ratio(x1, y1, y1_err, x2, y2, y2_err)
# plt.plot(x_aligned, ratio, color='black', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')
plt.errorbar(x_aligned, 2*ratio, yerr=ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

xscape_pythia_ratio_err = (pionplusminus_xscape_5_30_comb_cut_cross_sec/pionplusminus_pythia_5_30_comb_cut_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_comb_cut_cross_sec_err/pionplusminus_xscape_5_30_comb_cut_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cut_cross_sec_err/pionplusminus_pythia_5_30_comb_cut_cross_sec)**2)
pythia_pythia_ratio_err = (pionplusminus_pythia_5_30_comb_cut_cross_sec/pionplusminus_pythia_5_30_comb_cut_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_comb_cut_cross_sec_err/pionplusminus_pythia_5_30_comb_cut_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cut_cross_sec_err/pionplusminus_pythia_5_30_comb_cut_cross_sec)**2)

plt.errorbar(pionplusminus_xscape_15_30_cut_pT, (pionplusminus_xscape_5_30_comb_cut_cross_sec)/pionplusminus_pythia_5_30_comb_cut_cross_sec, yerr=xscape_pythia_ratio_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_pythia_15_30_cut_pT, (pionplusminus_pythia_5_30_comb_cut_cross_sec)/pionplusminus_pythia_5_30_comb_cut_cross_sec, yerr=pythia_pythia_ratio_err, fmt='-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
# plt.errorbar(existing_pionminus_pT, (existing_piontotal_cross_sec)/pionplusminus_pythia_5_30_comb_cut_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

plt.ylim(-1,2.5)
plt.xlim(4.9,12)
# plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'Ratio to PYTHIA 8.309 [$E \frac{d^{3}\sigma}{dp^{3}}$]',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# PTHAT 5-15 HadronDecay Comparison

# %%
import numpy  as np
import matplotlib.pyplot as plt

# PYTHIA pTHat 5-15 and 15-30 hadron decay on
pionplusminus_pythia_5_15_hadrondecayon_pT, pionplusminus_pythia_5_15_hadrondecayon_cross_sec, pionplusminus_pythia_5_15_hadrondecayon_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_hadrondecayon_cross_sec_v4.txt').T
pionplusminus_pythia_15_30_hadrondecayon_pT, pionplusminus_pythia_15_30_hadrondecayon_cross_sec, pionplusminus_pythia_15_30_hadrondecayon_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_hadrondecayon_cross_sec_v4.txt').T

# XSCAPE pTHat 5-15 and 15-30 hadron decay on
pionplusminus_xscape_5_15_hadrondecayon_pT, pionplusminus_xscape_5_15_hadrondecayon_cross_sec, pionplusminus_xscape_5_15_hadrondecayon_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_hadrondecayon_cross_sec_v4.txt').T
pionplusminus_xscape_15_30_hadrondecayon_pT, pionplusminus_xscape_15_30_hadrondecayon_cross_sec, pionplusminus_xscape_15_30_hadrondecayon_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_hadrondecayon_cross_sec_v4.txt').T

# PYTHIA pTHat 5-15 and 15-30 hadron decay off
pionplusminus_pythia_5_15_hadrondecayoff_pT, pionplusminus_pythia_5_15_hadrondecayoff_cross_sec, pionplusminus_pythia_5_15_hadrondecayoff_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_hadrondecayoff_cross_sec_v4.txt').T
pionplusminus_pythia_15_30_hadrondecayoff_pT, pionplusminus_pythia_15_30_hadrondecayoff_cross_sec, pionplusminus_pythia_15_30_hadrondecayoff_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_hadrondecayoff_cross_sec_v4.txt').T

# XSCAPE pTHat 5-15 and 15-30 hadron decay off
pionplusminus_xscape_5_15_hadrondecayoff_pT, pionplusminus_xscape_5_15_hadrondecayoff_cross_sec, pionplusminus_xscape_5_15_hadrondecayoff_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_hadrondecayoff_cross_sec_v4.txt').T
pionplusminus_xscape_15_30_hadrondecayoff_pT, pionplusminus_xscape_15_30_hadrondecayoff_cross_sec, pionplusminus_xscape_15_30_hadrondecayoff_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_hadrondecayoff_cross_sec_v4.txt').T

# Plotting
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))

# Plotting Existing Charged Pion Cross Sections
ax1.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')
ax2.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='-', color='black', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Plotting pTHat 5-15 Charged Pion Cross Sections
ax1.errorbar(pionplusminus_pythia_5_15_hadrondecayon_pT, pionplusminus_pythia_5_15_hadrondecayon_cross_sec/2, yerr = pionplusminus_pythia_5_15_hadrondecayon_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
ax1.errorbar(pionplusminus_xscape_5_15_hadrondecayon_pT, pionplusminus_xscape_5_15_hadrondecayon_cross_sec/2, yerr = pionplusminus_xscape_5_15_hadrondecayon_cross_sec_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-15 HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
ax1.errorbar(pionplusminus_pythia_5_15_hadrondecayoff_pT, pionplusminus_pythia_5_15_hadrondecayoff_cross_sec/2, yerr = pionplusminus_pythia_5_15_hadrondecayoff_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-15 HadronDecay:off $(\pi^{+}+\pi^{-})/2$')
ax1.errorbar(pionplusminus_xscape_5_15_hadrondecayoff_pT, pionplusminus_xscape_5_15_hadrondecayoff_cross_sec/2, yerr = pionplusminus_xscape_5_15_hadrondecayoff_cross_sec_err, fmt = '-.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 5-15 HadronDecay:off $(\pi^{+}+\pi^{-})/2$')

# Plotting pTHat 15-30 Charged Pion Cross Sections 
ax2.errorbar(pionplusminus_pythia_15_30_hadrondecayon_pT, pionplusminus_pythia_15_30_hadrondecayon_cross_sec, yerr = pionplusminus_pythia_15_30_hadrondecayon_cross_sec_err, fmt = '-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
ax2.errorbar(pionplusminus_xscape_15_30_hadrondecayon_pT, pionplusminus_xscape_15_30_hadrondecayon_cross_sec, yerr = pionplusminus_xscape_15_30_hadrondecayon_cross_sec_err, fmt = '-', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-30 HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
ax2.errorbar(pionplusminus_pythia_15_30_hadrondecayoff_pT, pionplusminus_pythia_15_30_hadrondecayoff_cross_sec, yerr = pionplusminus_pythia_15_30_hadrondecayoff_cross_sec_err, fmt = '-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 15-30 HadronDecay:off $(\pi^{+}+\pi^{-})/2$')
ax2.errorbar(pionplusminus_xscape_15_30_hadrondecayoff_pT, pionplusminus_xscape_15_30_hadrondecayoff_cross_sec, yerr = pionplusminus_xscape_15_30_hadrondecayoff_cross_sec_err, fmt = '-.', color='red', capsize=5, label = 'XSCAPE $\hat{p_{T}}$ 15-30 HadronDecay:off $(\pi^{+}+\pi^{-})/2$')

# More Plotting Parameters
# PTHat 5-15
ax1.set_ylim(1e-13,1e-3)
ax1.set_xlim(2.5,17)
ax1.set_yscale('log')
ax1.set_title(r'Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
ax1.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax1.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax1.legend(fontsize=9)

# PTHat 15-30
ax2.set_ylim(1e-13,1e-3)
ax2.set_xlim(2.5,21)
ax2.set_yscale('log')
ax2.set_title(r'Differential Invariant Cross Section of $(\pi^{+}+\pi^{-})/2$')
ax2.set_xlabel('$p_T$ (GeV/c)',fontsize=12)
ax2.set_ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
ax2.legend(fontsize=9)

plt.tight_layout()
# plt.title('Differential Invariant Cross Section of $\pi^{+}$')
# plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
# plt.ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
# plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
# Combined Pion Plus and Pion Minus Data
# plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

# Combining PYTHIA pTHat 5-15 and 15-30 hadron decay on
if (np.all(pionplusminus_pythia_5_15_hadrondecayon_pT==pionplusminus_pythia_15_30_hadrondecayon_pT)):
    pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec = pionplusminus_pythia_5_15_hadrondecayon_cross_sec+pionplusminus_pythia_15_30_hadrondecayon_cross_sec 
    pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_hadrondecayon_cross_sec_err**2+pionplusminus_pythia_15_30_hadrondecayon_cross_sec_err**2)
    plt.errorbar(pionplusminus_pythia_15_30_hadrondecayon_pT, pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec/2, yerr=pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 HadronDecay:on comb $(\pi^{+}+\pi^{-})/2$')

# Combining XSCAPE pTHat 5-15 and 15-30 hadron decay on
if (np.all(pionplusminus_xscape_5_15_hadrondecayon_pT==pionplusminus_xscape_15_30_hadrondecayon_pT)):
    pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec = pionplusminus_xscape_5_15_hadrondecayon_cross_sec+pionplusminus_xscape_15_30_hadrondecayon_cross_sec
    pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_hadrondecayon_cross_sec_err**2+pionplusminus_xscape_15_30_hadrondecayon_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_hadrondecayon_pT, pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 HadronDecay:on comb $(\pi^{+}+\pi^{-})/2$')

# Combining PYTHIA pTHat 5-15 and 15-30 hadron decay off
if (np.all(pionplusminus_pythia_5_15_hadrondecayoff_pT==pionplusminus_pythia_15_30_hadrondecayoff_pT)):
    pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec = pionplusminus_pythia_5_15_hadrondecayoff_cross_sec+pionplusminus_pythia_15_30_hadrondecayoff_cross_sec 
    pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_hadrondecayoff_cross_sec_err**2+pionplusminus_pythia_15_30_hadrondecayoff_cross_sec_err**2)
    plt.errorbar(pionplusminus_pythia_15_30_hadrondecayoff_pT, pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec/2, yerr=pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec_err, fmt='-.', color='purple', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 HadronDecay:off comb $(\pi^{+}+\pi^{-})/2$')

# Combining XSCAPE pTHat 5-15 and 15-30 hadron decay off
if (np.all(pionplusminus_xscape_5_15_hadrondecayoff_pT==pionplusminus_xscape_15_30_hadrondecayoff_pT)):
    pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec = pionplusminus_xscape_5_15_hadrondecayoff_cross_sec+pionplusminus_xscape_15_30_hadrondecayoff_cross_sec
    pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_hadrondecayoff_cross_sec_err**2+pionplusminus_xscape_15_30_hadrondecayoff_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_hadrondecayoff_pT, pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec_err, fmt='-.', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 HadronDecay:off comb $(\pi^{+}+\pi^{-})/2$')

plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
# Interpolating the calculations (PYTHIA and XSCAPE) to match the data points
def align_and_ratio(x1, y1, y1_err, x2, y2, y2_err):
    # Find common x-range
    x_min = max(min(x1), min(x2))
    x_max = min(max(x1), max(x2))
    
    # Use x1 as reference
    # x_ref = x1[(x1 >= x_min) & (x1 <= x_max)]
    # y1_ref = y1[(x1 >= x_min) & (x1 <= x_max)]
    x_ref = np.linspace(x_min, x_max, num=max(len(x1), len(x2)))
    y1_interp = np.interp(x_ref, x1, y1)
    
    # Interpolate y2 to match x_ref
    y2_interp = np.interp(x_ref, x2, y2)
    y1_err_interp = np.interp(x_ref, x1, y1_err)
    y2_err_interp = np.interp(x_ref, x2, y2_err)

    # Calculate ratio
    # ratio = y1_ref / y2_interp
    ratio = y1_interp / y2_interp
    ratio_err = ratio * np.sqrt((y1_err_interp/y1_interp)**2 + (y2_err_interp/y2_interp)**2)

    return x_ref, ratio, ratio_err

# Defining the variables
x1 = existing_pionall_pT
y1 = existing_pionall_cross_sec
y1_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
x2 = pionplusminus_pythia_15_30_pT
y2 = pionplusminus_pythia_5_30_comb_cross_sec
y2_err = pionplusminus_pythia_5_30_comb_cross_sec_err

x_aligned, ratio, ratio_err = align_and_ratio(x1, y1, y1_err, x2, y2, y2_err)

# Plotting the Neutral Pion Data / PYTHIA ratio
plt.errorbar(x_aligned, ratio, yerr=ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# Error Ratios for XSCAPE and PYTHIA
xscape_pythia_hadrondecayon_ratio_err = (pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec_err/pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec)**2)
pythia_pythia_hadrondecayon_ratio_err = (pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec)**2)
xscape_pythia_hadrondecayoff_ratio_err = (pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec/pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec_err/pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec)**2)
pythia_pythia_hadrondecayoff_ratio_err = (pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec/pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec_err/pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec)**2)

plt.errorbar(pionplusminus_xscape_15_30_hadrondecayon_pT, (pionplusminus_xscape_5_30_hadrondecayon_comb_cross_sec/2)/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec, yerr=xscape_pythia_hadrondecayon_ratio_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_pythia_15_30_hadrondecayon_pT, (pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec/2)/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec, yerr=pythia_pythia_hadrondecayon_ratio_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb HadronDecay:on $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_xscape_15_30_hadrondecayoff_pT, (pionplusminus_xscape_5_30_hadrondecayoff_comb_cross_sec/2)/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec, yerr=xscape_pythia_hadrondecayoff_ratio_err, fmt='-.', color='orange', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb HadronDecay:off $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_pythia_15_30_hadrondecayoff_pT, (pionplusminus_pythia_5_30_hadrondecayoff_comb_cross_sec/2)/pionplusminus_pythia_5_30_hadrondecayon_comb_cross_sec, yerr=pythia_pythia_hadrondecayoff_ratio_err, fmt='-.', color='purple', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb HadronDecay:off $(\pi^{+}+\pi^{-})/2$')

plt.ylim(-1,2.5)
plt.xlim(3,21)
# plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'Ratio to PYTHIA 8.309 [$E \frac{d^{3}\sigma}{dp^{3}}$]',fontsize=12)
plt.legend(fontsize=9)
# plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# Comparing Yasuki's Code with PP19

# %%
import numpy  as np
import matplotlib.pyplot as plt

plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_1M.txt').T
# pionplusminus_pythia_5_15_cross_sec_scale = pionplusminus_pythia_5_15_cross_sec/(pionplusminus_pythia_5_15_pT)
# pionplusminus_pythia_5_15_cross_sec_err_scale = pionplusminus_pythia_5_15_cross_sec_err/(pionplusminus_pythia_5_15_pT)
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '.', color='green', capsize=5)
# plt.plot(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

pionplusminus_xscape_5_15_yasuki_pT, pionplusminus_xscape_5_15_yasuki_cross_sec, pionplusminus_xscape_5_15_yasuki_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_yasuki_cross_sec_v4.txt').T
# pionplusminus_xscape_5_15_cross_sec_scale = pionplusminus_xscape_5_15_cross_sec/(pionplusminus_xscape_5_15_pT)
# pionplusminus_xscape_5_15_cross_sec_err_scale = pionplusminus_xscape_5_15_cross_sec_err/(pionplusminus_xscape_5_15_pT)
# plt.errorbar(pionplusminus_xscape_5_15_yasuki_pT, pionplusminus_xscape_5_15_yasuki_cross_sec, yerr = pionplusminus_xscape_5_15_yasuki_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pionplusminus_xscape_5_15_yasuki_pT, pionplusminus_xscape_5_15_yasuki_cross_sec, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 5-15 Yasuki Sample $(\pi^{+}+\pi^{-})/2$')

pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, pionplusminus_pythia_15_30_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat15_30_cross_sec_v4_1M.txt').T
# pionplusminus_pythia_15_30_cross_sec_scale = pionplusminus_pythia_15_30_cross_sec/(pionplusminus_pythia_15_30_pT)
# pionplusminus_pythia_15_30_cross_sec_err_scale = pionplusminus_pythia_15_30_cross_sec_err/(pionplusminus_pythia_15_30_pT)
# plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, yerr = pionplusminus_pythia_15_30_cross_sec_err, fmt = '.', color='green', capsize=5)
# plt.plot(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_15_30_cross_sec, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

pionplusminus_xscape_15_30_yasuki_pT, pionplusminus_xscape_15_30_yasuki_cross_sec, pionplusminus_xscape_15_30_yasuki_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_yasuki_cross_sec_v4.txt').T
# pionplusminus_xscape_15_30_cross_sec_scale = pionplusminus_xscape_15_30_cross_sec/(pionplusminus_xscape_15_30_pT)
# pionplusminus_xscape_15_30_cross_sec_err_scale = pionplusminus_xscape_15_30_cross_sec_err/(pionplusminus_xscape_15_30_pT)
# plt.errorbar(pionplusminus_xscape_15_30_yasuki_pT, pionplusminus_xscape_15_30_yasukicross_sec, yerr = pionplusminus_xscape_15_30_yasuki_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pionplusminus_xscape_15_30_yasuki_pT, pionplusminus_xscape_15_30_yasuki_cross_sec, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

if (np.all(pionplusminus_pythia_5_15_pT==pionplusminus_pythia_15_30_pT)):
    pionplusminus_pythia_5_30_comb_cross_sec = pionplusminus_pythia_5_15_cross_sec+pionplusminus_pythia_15_30_cross_sec 
    pionplusminus_pythia_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_cross_sec_err**2+pionplusminus_pythia_15_30_cross_sec_err**2)
    plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_5_30_comb_cross_sec/2, yerr=pionplusminus_pythia_5_30_comb_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
    # plt.plot(pionplusminus_pythia_15_30_pT,pionplusminus_pythia_5_30_comb_cross_sec, '-',color='green')

    
if (np.all(pionplusminus_xscape_5_15_yasuki_pT==pionplusminus_xscape_15_30_yasuki_pT)):
    pionplusminus_xscape_5_30_yasuki_comb_cross_sec = pionplusminus_xscape_5_15_yasuki_cross_sec+pionplusminus_xscape_15_30_yasuki_cross_sec
    pionplusminus_xscape_5_30_yasuki_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_yasuki_cross_sec_err**2+pionplusminus_xscape_15_30_yasuki_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_yasuki_pT, pionplusminus_xscape_5_30_yasuki_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_yasuki_comb_cross_sec_err, fmt='-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb Yasuki sample $(\pi^{+}+\pi^{-})/2$')
    # plt.plot(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_5_30_comb_cross_sec, '-',color='purple')


if (np.all(pionplusminus_xscape_5_15_pT==pionplusminus_xscape_15_30_pT)):
    pionplusminus_xscape_5_30_comb_cross_sec = pionplusminus_xscape_5_15_cross_sec+pionplusminus_xscape_15_30_cross_sec
    pionplusminus_xscape_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_cross_sec_err**2+pionplusminus_xscape_15_30_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_5_30_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_comb_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb PP19 $(\pi^{+}+\pi^{-})/2$')
    # plt.plot(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_5_30_comb_cross_sec, '-',color='purple')


plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
def align_and_ratio(x1, y1, y1_err, x2, y2, y2_err):
    # Find common x-range
    x_min = max(min(x1), min(x2))
    x_max = min(max(x1), max(x2))
    
    # Use x1 as reference
    # x_ref = x1[(x1 >= x_min) & (x1 <= x_max)]
    # y1_ref = y1[(x1 >= x_min) & (x1 <= x_max)]
    x_ref = np.linspace(x_min, x_max, num=max(len(x1), len(x2)))
    y1_interp = np.interp(x_ref, x1, y1)
    
    # Interpolate y2 to match x_ref
    y2_interp = np.interp(x_ref, x2, y2)
    y1_err_interp = np.interp(x_ref, x1, y1_err)
    y2_err_interp = np.interp(x_ref, x2, y2_err)

    # Calculate ratio
    # ratio = y1_ref / y2_interp
    ratio = y1_interp / y2_interp
    ratio_err = ratio * np.sqrt((y1_err_interp/y1_interp)**2 + (y2_err_interp/y2_interp)**2)

    return x_ref, ratio, ratio_err

# Usage
x1 = existing_pionall_pT
y1 = existing_pionall_cross_sec
y1_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
x2 = pionplusminus_pythia_15_30_pT
y2 = pionplusminus_pythia_5_30_comb_cross_sec
y2_err = pionplusminus_pythia_5_30_comb_cross_sec_err

x_aligned, ratio, ratio_err = align_and_ratio(x1, y1, y1_err, x2, y2, y2_err)
# plt.plot(x_aligned, ratio, color='black', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')
plt.errorbar(x_aligned, ratio, yerr=ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

xscape_yasuki_pythia_ratio_err = (pionplusminus_xscape_5_30_yasuki_comb_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_yasuki_comb_cross_sec_err/pionplusminus_xscape_5_30_yasuki_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)
xscape_pythia_ratio_err = (pionplusminus_xscape_5_30_comb_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_comb_cross_sec_err/pionplusminus_xscape_5_30_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)
pythia_pythia_ratio_err = (pionplusminus_pythia_5_30_comb_cross_sec/pionplusminus_pythia_5_30_comb_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_cross_sec_err/pionplusminus_pythia_5_30_comb_cross_sec)**2)

plt.errorbar(pionplusminus_xscape_15_30_pT, (pionplusminus_xscape_5_30_comb_cross_sec/2)/(pionplusminus_pythia_5_30_comb_cross_sec), yerr=xscape_yasuki_pythia_ratio_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_xscape_15_30_yasuki_pT, (pionplusminus_xscape_5_30_yasuki_comb_cross_sec/2)/(pionplusminus_pythia_5_30_comb_cross_sec), yerr=xscape_pythia_ratio_err, fmt='-', color='purple', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb Yasuki sample $(\pi^{+}+\pi^{-})/2$')
plt.errorbar(pionplusminus_pythia_15_30_pT, (pionplusminus_pythia_5_30_comb_cross_sec/2)/(pionplusminus_pythia_5_30_comb_cross_sec), yerr=pythia_pythia_ratio_err, fmt='-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

plt.ylim(-1,2.5)
plt.xlim(3,21)
# plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'Ratio to PYTHIA 8.309 [$E \frac{d^{3}\sigma}{dp^{3}}$]',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# PTHAT 5-30 Combined Neutral Pions

# %%
import numpy  as np
import matplotlib.pyplot as plt

# Combined Pion Plus and Pion Minus Data
# plt.errorbar(existing_pionplus_pT, existing_piontotal_cross_sec, yerr=existing_piontotal_cross_sec_err, fmt='.', color='green', capsize=5, label='PHENIX $(\pi^{+}+\pi^{-})/2$ $|\eta|<0.35$')

# Neutral Pion Data
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=existing_pionall_cross_sec_err, fmt='.', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')


plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

# PYTHIA pTHat 5-15 neutral pion cross section
pionplusminus_pythia_5_15_pi0decayoff_pT, pionplusminus_pythia_5_15_pi0decayoff_cross_sec, pionplusminus_pythia_5_15_pi0decayoff_cross_sec_err = np.loadtxt('pi0_Pythia_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T

# XSCAPE pTHat 5-15 neutral pion cross section
pionplusminus_xscape_5_15_pi0decayoff_pT, pionplusminus_xscape_5_15_pi0decayoff_cross_sec, pionplusminus_xscape_5_15_pi0decayoff_cross_sec_err = np.loadtxt('pi0_pp_pTHat5_15_cross_sec_v4_data_binning_1M.txt').T

# PYTHIA pTHat 15-30 neutral pion cross section
pionplusminus_pythia_15_30_pi0decayoff_pT, pionplusminus_pythia_15_30_pi0decayoff_cross_sec, pionplusminus_pythia_15_30_pi0decayoff_cross_sec_err = np.loadtxt('pi0_Pythia_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T

# XSCAPE pTHat 15-30 neutral pion cross section
pionplusminus_xscape_15_30_pi0decayoff_pT, pionplusminus_xscape_15_30_pi0decayoff_cross_sec, pionplusminus_xscape_15_30_pi0decayoff_cross_sec_err = np.loadtxt('pi0_pp_pTHat15_30_cross_sec_v4_data_binning_1M.txt').T

# Combined PYTHIA pTHat 5-15 and 15-30 neutral pion cross sections
if (np.all(pionplusminus_pythia_5_15_pi0decayoff_pT==pionplusminus_pythia_15_30_pi0decayoff_pT)):
    pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec = pionplusminus_pythia_5_15_pi0decayoff_cross_sec+pionplusminus_pythia_15_30_pi0decayoff_cross_sec 
    pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_pi0decayoff_cross_sec_err**2+pionplusminus_pythia_15_30_pi0decayoff_cross_sec_err**2)
    plt.errorbar(pionplusminus_pythia_15_30_pi0decayoff_pT, pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec, yerr=pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')

# Combined XSCAPE pTHat 5-15 and 15-30 neutral pion cross sections
if (np.all(pionplusminus_xscape_5_15_pi0decayoff_pT==pionplusminus_xscape_15_30_pi0decayoff_pT)):
    pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec = pionplusminus_xscape_5_15_pi0decayoff_cross_sec+pionplusminus_xscape_15_30_pi0decayoff_cross_sec
    pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_pi0decayoff_cross_sec_err**2+pionplusminus_xscape_15_30_pi0decayoff_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_pi0decayoff_pT, pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec, yerr=pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')


plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^{3}\sigma}{dp^{3}}$',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %%
# def align_and_ratio(x1, y1, y1_err, x2, y2, y2_err):
#     # Find common x-range
#     x_min = max(min(x1), min(x2))
#     x_max = min(max(x1), max(x2))
    
#     # Use x1 as reference
#     # x_ref = x1[(x1 >= x_min) & (x1 <= x_max)]
#     # y1_ref = y1[(x1 >= x_min) & (x1 <= x_max)]
#     x_ref = np.linspace(x_min, x_max, num=max(len(x1), len(x2)))
#     y1_interp = np.interp(x_ref, x1, y1)
    
#     # Interpolate y2 to match x_ref
#     y2_interp = np.interp(x_ref, x2, y2)
#     y1_err_interp = np.interp(x_ref, x1, y1_err)
#     y2_err_interp = np.interp(x_ref, x2, y2_err)

#     # Calculate ratio
#     # ratio = y1_ref / y2_interp
#     ratio = y1_interp / y2_interp
#     ratio_err = ratio * np.sqrt((y1_err_interp/y1_interp)**2 + (y2_err_interp/y2_interp)**2)

#     return x_ref, ratio, ratio_err

# # Usage
# x1 = existing_pionall_pT
# y1 = existing_pionall_cross_sec
# y1_err = np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2)
# x2 = pionplusminus_pythia_15_30_pi0decayoff_pT
# y2 = pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec
# y2_err = pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err

# x_aligned, ratio, ratio_err = align_and_ratio(x1, y1, y1_err, x2, y2, y2_err)
# # plt.plot(x_aligned, ratio, color='black', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')
# plt.errorbar(x_aligned, ratio, yerr=ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# Error Ratios for XSCAPE and PYTHIA
xscape_pythia_pi0decayoff_ratio_err = (pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec) * np.sqrt((pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec_err/pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec)**2)
pythia_pythia_pi0decayoff_ratio_err = (pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec) * np.sqrt((pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec)**2)
data_pythia_pi0decayoff_ratio_err = (existing_pionall_cross_sec/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec) * np.sqrt((existing_pionall_cross_sec_err/existing_pionall_cross_sec)**2 + (pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec_err/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec)**2)

# Plotting the XSCAPE / PYTHIA and PYTHIA / PYTHIA ratios
plt.errorbar(existing_pionall_pT, (existing_pionall_cross_sec)/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec, yerr=data_pythia_pi0decayoff_ratio_err, fmt='o', color='black', capsize=5, label='PHENIX $\pi^{0}$ $|\eta|<0.35$')
plt.errorbar(pionplusminus_xscape_15_30_pi0decayoff_pT, pionplusminus_xscape_5_30_comb_pi0decayoff_cross_sec/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec, yerr=xscape_pythia_pi0decayoff_ratio_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')
plt.errorbar(pionplusminus_pythia_15_30_pi0decayoff_pT, pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec/pionplusminus_pythia_5_30_comb_pi0decayoff_cross_sec, yerr=pythia_pythia_pi0decayoff_ratio_err, fmt='-.', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')


plt.ylim(-1,2.5)
plt.xlim(3,21)
# plt.title('Ratio to PYTHIA (Cross Section of $\pi^{+}$)')
plt.xlabel('$p_T$ (GeV)',fontsize=12)
plt.ylabel(r'Ratio to PYTHIA 8.309 [$E \frac{d^{3}\sigma}{dp^{3}}$]',fontsize=12)
plt.legend(fontsize=9)
# plt.text(10.5, 1.7, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(10.5, 1.5, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)

plt.show()

# %% [markdown]
# PTHAT 10-25

# %%
import numpy  as np
import matplotlib.pyplot as plt

existing_pionplus_pT, existing_pionplus_cross_sec, existing_pionplus_stat_err, existing_pionplus_syst_err=np.loadtxt('Existing PionPlus Data for Cross Sections.txt').T
# plt.errorbar(existing_pionplus_pT, existing_pionplus_cross_sec, yerr=np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2), fmt='.', color='blue', label='PHENIX $\pi^{+}$ $|\eta|<0.35$')

existing_pionminus_pT, existing_pionminus_cross_sec, existing_pionminus_stat_err, existing_pionminus_syst_err=np.loadtxt('Existing PionMinus Data for Cross Sections.txt').T
# plt.errorbar(existing_pionminus_pT, existing_pionminus_cross_sec, yerr=np.sqrt(existing_pionminus_stat_err**2+existing_pionminus_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{-}$ $|\eta|<0.35$')
existing_piontotal_cross_sec = (existing_pionplus_cross_sec+existing_pionminus_cross_sec)/2
plt.plot(existing_pionminus_pT, existing_piontotal_cross_sec,'-', color='black', label='PHENIX $(\pi^{+}+\pi^{-})/2$')

existing_pionall_pT, existing_pionall_cross_sec, existing_pionall_stat_err, existing_pionall_syst_err = np.loadtxt('Existing Pion Data for Cross Sections (all pT).txt').T
plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')


plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')

pionplusminus_pythia_10_25_pT, pionplusminus_pythia_10_25_cross_sec, pionplusminus_pythia_10_25_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat10_25_cross_sec_v4.txt').T
# pionplusminus_pythia_15_30_cross_sec_scale = pionplusminus_pythia_15_30_cross_sec/(pionplusminus_pythia_15_30_pT)
# pionplusminus_pythia_15_30_cross_sec_err_scale = pionplusminus_pythia_15_30_cross_sec_err/(pionplusminus_pythia_15_30_pT)
plt.errorbar(pionplusminus_pythia_10_25_pT, pionplusminus_pythia_10_25_cross_sec, yerr = pionplusminus_pythia_10_25_cross_sec_err, fmt = '.', color='green', capsize=5)
plt.plot(pionplusminus_pythia_10_25_pT, pionplusminus_pythia_10_25_cross_sec, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 10-25 $(\pi^{+}+\pi^{-})/2$')

pionplusminus_xscape_10_25_pT, pionplusminus_xscape_10_25_cross_sec, pionplusminus_xscape_10_25_cross_sec_err = np.loadtxt('pionall_pp_pTHat10_25_cross_sec_v4.txt').T
# pionplusminus_xscape_15_30_cross_sec_scale = pionplusminus_xscape_15_30_cross_sec/(pionplusminus_xscape_15_30_pT)
# pionplusminus_xscape_15_30_cross_sec_err_scale = pionplusminus_xscape_15_30_cross_sec_err/(pionplusminus_xscape_15_30_pT)
plt.errorbar(pionplusminus_xscape_10_25_pT, pionplusminus_xscape_10_25_cross_sec, yerr = pionplusminus_xscape_10_25_cross_sec_err, fmt = '.', color='purple', capsize=5)
plt.plot(pionplusminus_xscape_10_25_pT, pionplusminus_xscape_10_25_cross_sec, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 10-25 $(\pi^{+}+\pi^{-})/2$')

plt.title('Differential Invariant Cross Section of $\pi^{+}$')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel('$E d^3\sigma/dp^3$ (mb/GeV$^2$)',fontsize=12)
# plt.title('Direct Photon Production at RHIC $\sqrt{s}=200GeV$ compared to data')
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()
