# %% [markdown]
# ## Loading XSCAPE Cross Section Text Files and Plotting the Cross Section

# %% [markdown]
# You can use the existing_pionall (neutral pion) or existing_piontotal (charged pion average) for comparison if you want, but I'll be leaving them commented out for now.
#
# I am also leaving the Pythia section commented out until I know for sure you need to include it
#
# You may have weird extending statistical uncertainty bars (like the ones that go to infinity), but we just ignore it for now

# %% [markdown]
# ### Charged Pion Cross Section

# %%
import numpy  as np
import matplotlib.pyplot as plt

# existing_pionplus_pT, existing_pionplus_cross_sec, existing_pionplus_stat_err, existing_pionplus_syst_err=np.loadtxt('Existing PionPlus Data for Cross Sections.txt').T
# # plt.errorbar(existing_pionplus_pT, existing_pionplus_cross_sec, yerr=np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2), fmt='.', color='blue', label='PHENIX $\pi^{+}$ $|\eta|<0.35$')

# existing_pionminus_pT, existing_pionminus_cross_sec, existing_pionminus_stat_err, existing_pionminus_syst_err=np.loadtxt('Existing PionMinus Data for Cross Sections.txt').T
# # plt.errorbar(existing_pionminus_pT, existing_pionminus_cross_sec, yerr=np.sqrt(existing_pionminus_stat_err**2+existing_pionminus_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{-}$ $|\eta|<0.35$')
# existing_piontotal_cross_sec = (existing_pionplus_cross_sec+existing_pionminus_cross_sec)/2
# plt.plot(existing_pionminus_pT, existing_piontotal_cross_sec,'-', color='black', label='PHENIX $(\pi^{+}+\pi^{-})/2$')

# existing_pionall_pT, existing_pionall_cross_sec, existing_pionall_stat_err, existing_pionall_syst_err = np.loadtxt('Existing Pion Data for Cross Sections (all pT).txt').T
# plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# PYTHIA cross section plotting
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec/2, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '.', color='green', capsize=5)
# plt.plot(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec/2, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE cross section plotting
pionplusminus_xscape_5_15_pT, pionplusminus_xscape_5_15_cross_sec, pionplusminus_xscape_5_15_cross_sec_err = np.loadtxt('pionall_pp_pTHat5_15_cross_sec_v4.txt').T
# plt.errorbar(pionplusminus_xscape_5_15_pT, pionplusminus_xscape_5_15_cross_sec/2, yerr = pionplusminus_xscape_5_15_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pionplusminus_xscape_5_15_pT, pionplusminus_xscape_5_15_cross_sec/2, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

pionplusminus_xscape_15_30_pT, pionplusminus_xscape_15_30_cross_sec, pionplusminus_xscape_15_30_cross_sec_err = np.loadtxt('pionall_pp_pTHat15_30_cross_sec_v4.txt').T
# plt.errorbar(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_15_30_cross_sec/2, yerr = pionplusminus_xscape_15_30_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_15_30_cross_sec/2, '--', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 15-30 $(\pi^{+}+\pi^{-})/2$')

# Combining the PTHAT bins 5-15 and 15-30
# if (np.all(pionplusminus_pythia_5_15_pT==pionplusminus_pythia_15_30_pT)):
#     pionplusminus_pythia_5_30_comb_cross_sec = pionplusminus_pythia_5_15_cross_sec+pionplusminus_pythia_15_30_cross_sec 
#     pionplusminus_pythia_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_pythia_5_15_cross_sec_err**2+pionplusminus_pythia_15_30_cross_sec_err**2)
#     plt.errorbar(pionplusminus_pythia_15_30_pT, pionplusminus_pythia_5_30_comb_cross_sec/2, yerr=pionplusminus_pythia_5_30_comb_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')
if (np.all(pionplusminus_xscape_5_15_pT==pionplusminus_xscape_15_30_pT)):
    pionplusminus_xscape_5_30_comb_cross_sec = (pionplusminus_xscape_5_15_cross_sec/2)+(pionplusminus_xscape_15_30_cross_sec/2)
    pionplusminus_xscape_5_30_comb_cross_sec_err = np.sqrt(pionplusminus_xscape_5_15_cross_sec_err**2+pionplusminus_xscape_15_30_cross_sec_err**2)
    plt.errorbar(pionplusminus_xscape_15_30_pT, pionplusminus_xscape_5_30_comb_cross_sec/2, yerr=pionplusminus_xscape_5_30_comb_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $(\pi^{+}+\pi^{-})/2$')

# Plotting 
plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')
plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()

# %% [markdown]
# ### Neutral Pion Cross Section

# %%
import numpy  as np
import matplotlib.pyplot as plt

# existing_pionplus_pT, existing_pionplus_cross_sec, existing_pionplus_stat_err, existing_pionplus_syst_err=np.loadtxt('Existing PionPlus Data for Cross Sections.txt').T
# # plt.errorbar(existing_pionplus_pT, existing_pionplus_cross_sec, yerr=np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2), fmt='.', color='blue', label='PHENIX $\pi^{+}$ $|\eta|<0.35$')

# existing_pionminus_pT, existing_pionminus_cross_sec, existing_pionminus_stat_err, existing_pionminus_syst_err=np.loadtxt('Existing PionMinus Data for Cross Sections.txt').T
# # plt.errorbar(existing_pionminus_pT, existing_pionminus_cross_sec, yerr=np.sqrt(existing_pionminus_stat_err**2+existing_pionminus_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{-}$ $|\eta|<0.35$')
# existing_piontotal_cross_sec = (existing_pionplus_cross_sec+existing_pionminus_cross_sec)/2
# plt.plot(existing_pionminus_pT, existing_piontotal_cross_sec,'-', color='black', label='PHENIX $(\pi^{+}+\pi^{-})/2$')

# existing_pionall_pT, existing_pionall_cross_sec, existing_pionall_stat_err, existing_pionall_syst_err = np.loadtxt('Existing Pion Data for Cross Sections (all pT).txt').T
# plt.errorbar(existing_pionall_pT, existing_pionall_cross_sec, yerr=np.sqrt(existing_pionall_stat_err**2+existing_pionall_syst_err**2), fmt='-.', color='blue', label='PHENIX $\pi^{0}$ $|\eta|<0.35$')

# PYTHIA cross section plotting
# pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec, pionplusminus_pythia_5_15_cross_sec_err = np.loadtxt('pionall_Pythia_pp_pTHat5_15_cross_sec_v4_1M.txt').T
# plt.errorbar(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec/2, yerr = pionplusminus_pythia_5_15_cross_sec_err, fmt = '.', color='green', capsize=5)
# plt.plot(pionplusminus_pythia_5_15_pT, pionplusminus_pythia_5_15_cross_sec/2, '-', color='green', label='PYTHIA $\hat{p_{T}}$ 5-15 $(\pi^{+}+\pi^{-})/2$')

# XSCAPE cross section plotting
pion0_xscape_5_15_pT, pion0_xscape_5_15_cross_sec, pion0_xscape_5_15_cross_sec_err = np.loadtxt('pi0_pp_pTHat5_15_cross_sec_v4.txt').T
# plt.errorbar(pion0_xscape_5_15_pT, pion0_xscape_5_15_cross_sec, yerr = pion0_xscape_5_15_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pion0_xscape_5_15_pT, pion0_xscape_5_15_cross_sec, '-', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 5-15 $\pi^{0}$')

pion0_xscape_15_30_pT, pion0_xscape_15_30_cross_sec, pion0_xscape_15_30_cross_sec_err = np.loadtxt('pi0_pp_pTHat15_30_cross_sec_v4.txt').T
# plt.errorbar(pion0_xscape_15_30_pT, pion0_xscape_15_30_cross_sec, yerr = pion0_xscape_15_30_cross_sec_err, fmt = '.', color='purple', capsize=5)
# plt.plot(pion0_xscape_15_30_pT, pion0_xscape_15_30_cross_sec, '--', color = 'purple', label = 'XSCAPE $\hat{p_{T}}$ 15-30 $\pi^{0}$')

# Combining the PTHAT bins 5-15 and 15-30
# if (np.all(pion0_pythia_5_15_pT==pion0_pythia_15_30_pT)):
#     pion0_pythia_5_30_comb_cross_sec = pion0_pythia_5_15_cross_sec+pion0_pythia_15_30_cross_sec 
#     pion0_pythia_5_30_comb_cross_sec_err = np.sqrt(pion0_pythia_5_15_cross_sec_err**2+pion0_pythia_15_30_cross_sec_err**2)
#     plt.errorbar(pion0_pythia_15_30_pT, pion0_pythia_5_30_comb_cross_sec/2, yerr=pion0_pythia_5_30_comb_cross_sec_err, fmt='-', color='blue', capsize=5, label='PYTHIA $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')
if (np.all(pion0_xscape_5_15_pT==pion0_xscape_15_30_pT)):
    pion0_xscape_5_30_comb_cross_sec = (pion0_xscape_5_15_cross_sec/2)+(pion0_xscape_15_30_cross_sec/2)
    pion0_xscape_5_30_comb_cross_sec_err = np.sqrt(pion0_xscape_5_15_cross_sec_err**2+pion0_xscape_15_30_cross_sec_err**2)
    plt.errorbar(pion0_xscape_15_30_pT, pion0_xscape_5_30_comb_cross_sec/2, yerr=pion0_xscape_5_30_comb_cross_sec_err, fmt='-', color='red', capsize=5, label='XSCAPE $\hat{p_{T}}$ 5-30 comb $\pi^{0}$')

# Plotting 
plt.ylim(1e-11,1e-3)
plt.xlim(4,21)
plt.yscale('log')
plt.title('Differential Invariant Cross Section of Pions')
plt.xlabel('$p_T$ (GeV/c)',fontsize=12)
plt.ylabel(r'$E \frac{d^3\sigma}{dp^3}$ (mb/GeV$^2$)',fontsize=12)
plt.legend(fontsize=9)
# plt.text(4.3, 0.0000003, 'pp, $\sqrt{s_{NN}} = 200$ GeV', fontsize=12)
# plt.text(4.3, 0.00000015, '$|\eta| < 0.35$, $(\pi^{+}+\pi^{-})/2$', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 21
#       2 import matplotlib.pyplot as plt
#       4 # existing_pionplus_pT, existing_pionplus_cross_sec, existing_pionplus_stat_err, existing_pionplus_syst_err=np.loadtxt('Existing PionPlus Data for Cross Sections.txt').T
#       5 # # plt.errorbar(existing_pionplus_pT, existing_pionplus_cross_sec, yerr=np.sqrt(existing_pionplus_stat_err**2+existing_pionplus_syst_err**2), fmt='.', color='blue', label='PHENIX $\pi^{+}$ $|\eta|<0.35$')
#       6
#    (...)
#      19
#      20 # XSCAPE cross section plotting
# ---> 21 pion0_xscape_5_15_pT, pion0_xscape_5_15_cross_sec, pion0_xscape_5_15_cross_sec_err = np.loadtxt('pi0_pp_pTHat5_15_cross_sec_v4.txt').T
#      22 # plt.errorbar(pion0_xscape_5_15_pT, pion0_xscape_5_15_cross_sec, yerr = pion0_xscape_5_15_cross_sec_err, fmt = '.', color='purple', capsize=5)
# ...
